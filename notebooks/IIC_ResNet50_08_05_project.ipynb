# %% [markdown]
# <a href="https://colab.research.google.com/github/sokdnv/project_1/blob/main/notebooks/IIC_ResNet50_08_05_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Фаза 2 • Неделя 8 • Пятница
# ## Нейронные сети
# ### Распознавание Intel Image Classification на ResNet50

# %%
# !pip -qq install torchutils
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 12.9 MB/s eta 0:00:00

# %%
import torch
import torchvision
import torch.nn as nn
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision import transforms as T

# Для чтения изображений с диска
from torchvision import io # input/output
from torchvision.models import resnet50, ResNet50_Weights
import torchutils as tu
import json
import numpy as np
import matplotlib.pyplot as plt

import zipfile
import os

# %%
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
print(DEVICE)
# Out:
# cuda

# %% [markdown]
# ## Fine Tuning

# %% [markdown]
# Теперь обучим модель под свою задачу – сделаем **fine-tuning**. Возьмем `resnet18` для скорости – он намного меньше.

# %%
# Создаем класс модели нейронки на основе ResNet50

class MyResNet50(nn.Module):
    def __init__(self):
        super().__init__()

        # подгружаем базовую модель ResNet50
        self.model = resnet50(weights=ResNet50_Weights.DEFAULT)
        # заменяем выходной слой - на выходе 6 классов
        self.model.fc = nn.Linear(2048, 6)
        # замораживаем все слои
        for i in self.model.parameters():
            i.requires_grad = False
        # размораживаем последний слой - для обучения
        self.model.fc.weight.requires_grad = True
        self.model.fc.bias.requires_grad = True

    def forward(self, x):
        return self.model(x)


model = MyResNet50()
model.to(DEVICE);

# %%
fake_batch = torch.randn(1, 3, 150, 150, device=DEVICE)
tu.get_model_summary(model, fake_batch)
# Out:
# =============================================================================================================
# Layer                                               Kernel              Output          Params          FLOPs
# =============================================================================================================
# 0_model.Conv2d_conv1                               [3, 64, 7, 7]     [1, 64, 75, 75]       9,408   52,920,000
# 1_model.BatchNorm2d_bn1                                     [64]     [1, 64, 75, 75]         128    1,440,000
# 2_model.ReLU_relu                                              -     [1, 64, 75, 75]           0            0
# 3_model.MaxPool2d_maxpool                                      -     [1, 64, 38, 38]           0            0
# 4_model.layer1.0.Conv2d_conv1                     [64, 64, 1, 1]     [1, 64, 38, 38]       4,096    5,914,624
# 5_model.layer1.0.BatchNorm2d_bn1                            [64]     [1, 64, 38, 38]         128      369,664
# 6_model.layer1.0.ReLU_relu                                     -     [1, 64, 38, 38]           0            0
# 7_model.layer1.0.Conv2d_conv2                     [64, 64, 3, 3]     [1, 64, 38, 38]      36,864   53,231,616
# 8_model.layer1.0.BatchNorm2d_bn2                            [64]     [1, 64, 38, 38]         128      369,664
# 9_model.layer1.0.ReLU_relu                                     -     [1, 64, 38, 38]           0            0
# 10_model.layer1.0.Conv2d_conv3                   [64, 256, 1, 1]    [1, 256, 38, 38]      16,384   23,658,496
# 11_model.layer1.0.BatchNorm2d_bn3                          [256]    [1, 256, 38, 38]         512    1,478,656
# 12_model.layer1.0.downsample.Conv2d_0            [64, 256, 1, 1]    [1, 256, 38, 38]      16,384   23,658,496
# 13_model.layer1.0.downsample.BatchNorm2d_1                 [256]    [1, 256, 38, 38]         512    1,478,656
# 14_model.layer1.0.ReLU_relu                                    -    [1, 256, 38, 38]           0            0
# 15_model.layer1.1.Conv2d_conv1                   [256, 64, 1, 1]     [1, 64, 38, 38]      16,384   23,658,496
# 16_model.layer1.1.BatchNorm2d_bn1                           [64]     [1, 64, 38, 38]         128      369,664
# 17_model.layer1.1.ReLU_relu                                    -     [1, 64, 38, 38]           0            0
# 18_model.layer1.1.Conv2d_conv2                    [64, 64, 3, 3]     [1, 64, 38, 38]      36,864   53,231,616
# 19_model.layer1.1.BatchNorm2d_bn2                           [64]     [1, 64, 38, 38]         128      369,664
# 20_model.layer1.1.ReLU_relu                                    -     [1, 64, 38, 38]           0            0
# 21_model.layer1.1.Conv2d_conv3                   [64, 256, 1, 1]    [1, 256, 38, 38]      16,384   23,658,496
# 22_model.layer1.1.BatchNorm2d_bn3                          [256]    [1, 256, 38, 38]         512    1,478,656
# 23_model.layer1.1.ReLU_relu                                    -    [1, 256, 38, 38]           0            0
# 24_model.layer1.2.Conv2d_conv1                   [256, 64, 1, 1]     [1, 64, 38, 38]      16,384   23,658,496
# 25_model.layer1.2.BatchNorm2d_bn1                           [64]     [1, 64, 38, 38]         128      369,664
# 26_model.layer1.2.ReLU_relu                                    -     [1, 64, 38, 38]           0            0
# 27_model.layer1.2.Conv2d_conv2                    [64, 64, 3, 3]     [1, 64, 38, 38]      36,864   53,231,616
# 28_model.layer1.2.BatchNorm2d_bn2                           [64]     [1, 64, 38, 38]         128      369,664
# 29_model.layer1.2.ReLU_relu                                    -     [1, 64, 38, 38]           0            0
# 30_model.layer1.2.Conv2d_conv3                   [64, 256, 1, 1]    [1, 256, 38, 38]      16,384   23,658,496
# 31_model.layer1.2.BatchNorm2d_bn3                          [256]    [1, 256, 38, 38]         512    1,478,656
# 32_model.layer1.2.ReLU_relu                                    -    [1, 256, 38, 38]           0            0
# 33_model.layer2.0.Conv2d_conv1                  [256, 128, 1, 1]    [1, 128, 38, 38]      32,768   47,316,992
# 34_model.layer2.0.BatchNorm2d_bn1                          [128]    [1, 128, 38, 38]         256      739,328
# 35_model.layer2.0.ReLU_relu                                    -    [1, 128, 38, 38]           0            0
# 36_model.layer2.0.Conv2d_conv2                  [128, 128, 3, 3]    [1, 128, 19, 19]     147,456   53,231,616
# 37_model.layer2.0.BatchNorm2d_bn2                          [128]    [1, 128, 19, 19]         256      184,832
# 38_model.layer2.0.ReLU_relu                                    -    [1, 128, 19, 19]           0            0
# 39_model.layer2.0.Conv2d_conv3                  [128, 512, 1, 1]    [1, 512, 19, 19]      65,536   23,658,496
# 40_model.layer2.0.BatchNorm2d_bn3                          [512]    [1, 512, 19, 19]       1,024      739,328
# 41_model.layer2.0.downsample.Conv2d_0           [256, 512, 1, 1]    [1, 512, 19, 19]     131,072   47,316,992
# 42_model.layer2.0.downsample.BatchNorm2d_1                 [512]    [1, 512, 19, 19]       1,024      739,328
# 43_model.layer2.0.ReLU_relu                                    -    [1, 512, 19, 19]           0            0
# 44_model.layer2.1.Conv2d_conv1                  [512, 128, 1, 1]    [1, 128, 19, 19]      65,536   23,658,496
# 45_model.layer2.1.BatchNorm2d_bn1                          [128]    [1, 128, 19, 19]         256      184,832
# 46_model.layer2.1.ReLU_relu                                    -    [1, 128, 19, 19]           0            0
# 47_model.layer2.1.Conv2d_conv2                  [128, 128, 3, 3]    [1, 128, 19, 19]     147,456   53,231,616
# 48_model.layer2.1.BatchNorm2d_bn2                          [128]    [1, 128, 19, 19]         256      184,832
# 49_model.layer2.1.ReLU_relu                                    -    [1, 128, 19, 19]           0            0
# 50_model.layer2.1.Conv2d_conv3                  [128, 512, 1, 1]    [1, 512, 19, 19]      65,536   23,658,496
# 51_model.layer2.1.BatchNorm2d_bn3                          [512]    [1, 512, 19, 19]       1,024      739,328
# 52_model.layer2.1.ReLU_relu                                    -    [1, 512, 19, 19]           0            0
# 53_model.layer2.2.Conv2d_conv1                  [512, 128, 1, 1]    [1, 128, 19, 19]      65,536   23,658,496
# 54_model.layer2.2.BatchNorm2d_bn1                          [128]    [1, 128, 19, 19]         256      184,832
# 55_model.layer2.2.ReLU_relu                                    -    [1, 128, 19, 19]           0            0
# 56_model.layer2.2.Conv2d_conv2                  [128, 128, 3, 3]    [1, 128, 19, 19]     147,456   53,231,616
# 57_model.layer2.2.BatchNorm2d_bn2                          [128]    [1, 128, 19, 19]         256      184,832
# 58_model.layer2.2.ReLU_relu                                    -    [1, 128, 19, 19]           0            0
# 59_model.layer2.2.Conv2d_conv3                  [128, 512, 1, 1]    [1, 512, 19, 19]      65,536   23,658,496
# 60_model.layer2.2.BatchNorm2d_bn3                          [512]    [1, 512, 19, 19]       1,024      739,328
# 61_model.layer2.2.ReLU_relu                                    -    [1, 512, 19, 19]           0            0
# 62_model.layer2.3.Conv2d_conv1                  [512, 128, 1, 1]    [1, 128, 19, 19]      65,536   23,658,496
# 63_model.layer2.3.BatchNorm2d_bn1                          [128]    [1, 128, 19, 19]         256      184,832
# 64_model.layer2.3.ReLU_relu                                    -    [1, 128, 19, 19]           0            0
# 65_model.layer2.3.Conv2d_conv2                  [128, 128, 3, 3]    [1, 128, 19, 19]     147,456   53,231,616
# 66_model.layer2.3.BatchNorm2d_bn2                          [128]    [1, 128, 19, 19]         256      184,832
# 67_model.layer2.3.ReLU_relu                                    -    [1, 128, 19, 19]           0            0
# 68_model.layer2.3.Conv2d_conv3                  [128, 512, 1, 1]    [1, 512, 19, 19]      65,536   23,658,496
# 69_model.layer2.3.BatchNorm2d_bn3                          [512]    [1, 512, 19, 19]       1,024      739,328
# 70_model.layer2.3.ReLU_relu                                    -    [1, 512, 19, 19]           0            0
# 71_model.layer3.0.Conv2d_conv1                  [512, 256, 1, 1]    [1, 256, 19, 19]     131,072   47,316,992
# 72_model.layer3.0.BatchNorm2d_bn1                          [256]    [1, 256, 19, 19]         512      369,664
# 73_model.layer3.0.ReLU_relu                                    -    [1, 256, 19, 19]           0            0
# 74_model.layer3.0.Conv2d_conv2                  [256, 256, 3, 3]    [1, 256, 10, 10]     589,824   58,982,400
# 75_model.layer3.0.BatchNorm2d_bn2                          [256]    [1, 256, 10, 10]         512      102,400
# 76_model.layer3.0.ReLU_relu                                    -    [1, 256, 10, 10]           0            0
# 77_model.layer3.0.Conv2d_conv3                 [256, 1024, 1, 1]   [1, 1024, 10, 10]     262,144   26,214,400
# 78_model.layer3.0.BatchNorm2d_bn3                         [1024]   [1, 1024, 10, 10]       2,048      409,600
# 79_model.layer3.0.downsample.Conv2d_0          [512, 1024, 1, 1]   [1, 1024, 10, 10]     524,288   52,428,800
# 80_model.layer3.0.downsample.BatchNorm2d_1                [1024]   [1, 1024, 10, 10]       2,048      409,600
# 81_model.layer3.0.ReLU_relu                                    -   [1, 1024, 10, 10]           0            0
# 82_model.layer3.1.Conv2d_conv1                 [1024, 256, 1, 1]    [1, 256, 10, 10]     262,144   26,214,400
# 83_model.layer3.1.BatchNorm2d_bn1                          [256]    [1, 256, 10, 10]         512      102,400
# 84_model.layer3.1.ReLU_relu                                    -    [1, 256, 10, 10]           0            0
# 85_model.layer3.1.Conv2d_conv2                  [256, 256, 3, 3]    [1, 256, 10, 10]     589,824   58,982,400
# 86_model.layer3.1.BatchNorm2d_bn2                          [256]    [1, 256, 10, 10]         512      102,400
# 87_model.layer3.1.ReLU_relu                                    -    [1, 256, 10, 10]           0            0
# 88_model.layer3.1.Conv2d_conv3                 [256, 1024, 1, 1]   [1, 1024, 10, 10]     262,144   26,214,400
# 89_model.layer3.1.BatchNorm2d_bn3                         [1024]   [1, 1024, 10, 10]       2,048      409,600
# 90_model.layer3.1.ReLU_relu                                    -   [1, 1024, 10, 10]           0            0
# 91_model.layer3.2.Conv2d_conv1                 [1024, 256, 1, 1]    [1, 256, 10, 10]     262,144   26,214,400
# 92_model.layer3.2.BatchNorm2d_bn1                          [256]    [1, 256, 10, 10]         512      102,400
# 93_model.layer3.2.ReLU_relu                                    -    [1, 256, 10, 10]           0            0
# 94_model.layer3.2.Conv2d_conv2                  [256, 256, 3, 3]    [1, 256, 10, 10]     589,824   58,982,400
# 95_model.layer3.2.BatchNorm2d_bn2                          [256]    [1, 256, 10, 10]         512      102,400
# 96_model.layer3.2.ReLU_relu                                    -    [1, 256, 10, 10]           0            0
# 97_model.layer3.2.Conv2d_conv3                 [256, 1024, 1, 1]   [1, 1024, 10, 10]     262,144   26,214,400
# 98_model.layer3.2.BatchNorm2d_bn3                         [1024]   [1, 1024, 10, 10]       2,048      409,600
# 99_model.layer3.2.ReLU_relu                                    -   [1, 1024, 10, 10]           0            0
# 100_model.layer3.3.Conv2d_conv1                [1024, 256, 1, 1]    [1, 256, 10, 10]     262,144   26,214,400
# 101_model.layer3.3.BatchNorm2d_bn1                         [256]    [1, 256, 10, 10]         512      102,400
# 102_model.layer3.3.ReLU_relu                                   -    [1, 256, 10, 10]           0            0
# 103_model.layer3.3.Conv2d_conv2                 [256, 256, 3, 3]    [1, 256, 10, 10]     589,824   58,982,400
# 104_model.layer3.3.BatchNorm2d_bn2                         [256]    [1, 256, 10, 10]         512      102,400
# 105_model.layer3.3.ReLU_relu                                   -    [1, 256, 10, 10]           0            0
# 106_model.layer3.3.Conv2d_conv3                [256, 1024, 1, 1]   [1, 1024, 10, 10]     262,144   26,214,400
# 107_model.layer3.3.BatchNorm2d_bn3                        [1024]   [1, 1024, 10, 10]       2,048      409,600
# 108_model.layer3.3.ReLU_relu                                   -   [1, 1024, 10, 10]           0            0
# 109_model.layer3.4.Conv2d_conv1                [1024, 256, 1, 1]    [1, 256, 10, 10]     262,144   26,214,400
# 110_model.layer3.4.BatchNorm2d_bn1                         [256]    [1, 256, 10, 10]         512      102,400
# 111_model.layer3.4.ReLU_relu                                   -    [1, 256, 10, 10]           0            0
# 112_model.layer3.4.Conv2d_conv2                 [256, 256, 3, 3]    [1, 256, 10, 10]     589,824   58,982,400
# 113_model.layer3.4.BatchNorm2d_bn2                         [256]    [1, 256, 10, 10]         512      102,400
# 114_model.layer3.4.ReLU_relu                                   -    [1, 256, 10, 10]           0            0
# 115_model.layer3.4.Conv2d_conv3                [256, 1024, 1, 1]   [1, 1024, 10, 10]     262,144   26,214,400
# 116_model.layer3.4.BatchNorm2d_bn3                        [1024]   [1, 1024, 10, 10]       2,048      409,600
# 117_model.layer3.4.ReLU_relu                                   -   [1, 1024, 10, 10]           0            0
# 118_model.layer3.5.Conv2d_conv1                [1024, 256, 1, 1]    [1, 256, 10, 10]     262,144   26,214,400
# 119_model.layer3.5.BatchNorm2d_bn1                         [256]    [1, 256, 10, 10]         512      102,400
# 120_model.layer3.5.ReLU_relu                                   -    [1, 256, 10, 10]           0            0
# 121_model.layer3.5.Conv2d_conv2                 [256, 256, 3, 3]    [1, 256, 10, 10]     589,824   58,982,400
# 122_model.layer3.5.BatchNorm2d_bn2                         [256]    [1, 256, 10, 10]         512      102,400
# 123_model.layer3.5.ReLU_relu                                   -    [1, 256, 10, 10]           0            0
# 124_model.layer3.5.Conv2d_conv3                [256, 1024, 1, 1]   [1, 1024, 10, 10]     262,144   26,214,400
# 125_model.layer3.5.BatchNorm2d_bn3                        [1024]   [1, 1024, 10, 10]       2,048      409,600
# 126_model.layer3.5.ReLU_relu                                   -   [1, 1024, 10, 10]           0            0
# 127_model.layer4.0.Conv2d_conv1                [1024, 512, 1, 1]    [1, 512, 10, 10]     524,288   52,428,800
# 128_model.layer4.0.BatchNorm2d_bn1                         [512]    [1, 512, 10, 10]       1,024      204,800
# 129_model.layer4.0.ReLU_relu                                   -    [1, 512, 10, 10]           0            0
# 130_model.layer4.0.Conv2d_conv2                 [512, 512, 3, 3]      [1, 512, 5, 5]   2,359,296   58,982,400
# 131_model.layer4.0.BatchNorm2d_bn2                         [512]      [1, 512, 5, 5]       1,024       51,200
# 132_model.layer4.0.ReLU_relu                                   -      [1, 512, 5, 5]           0            0
# 133_model.layer4.0.Conv2d_conv3                [512, 2048, 1, 1]     [1, 2048, 5, 5]   1,048,576   26,214,400
# 134_model.layer4.0.BatchNorm2d_bn3                        [2048]     [1, 2048, 5, 5]       4,096      204,800
# 135_model.layer4.0.downsample.Conv2d_0        [1024, 2048, 1, 1]     [1, 2048, 5, 5]   2,097,152   52,428,800
# 136_model.layer4.0.downsample.BatchNorm2d_1               [2048]     [1, 2048, 5, 5]       4,096      204,800
# 137_model.layer4.0.ReLU_relu                                   -     [1, 2048, 5, 5]           0            0
# 138_model.layer4.1.Conv2d_conv1                [2048, 512, 1, 1]      [1, 512, 5, 5]   1,048,576   26,214,400
# 139_model.layer4.1.BatchNorm2d_bn1                         [512]      [1, 512, 5, 5]       1,024       51,200
# 140_model.layer4.1.ReLU_relu                                   -      [1, 512, 5, 5]           0            0
# 141_model.layer4.1.Conv2d_conv2                 [512, 512, 3, 3]      [1, 512, 5, 5]   2,359,296   58,982,400
# 142_model.layer4.1.BatchNorm2d_bn2                         [512]      [1, 512, 5, 5]       1,024       51,200
# 143_model.layer4.1.ReLU_relu                                   -      [1, 512, 5, 5]           0            0
# 144_model.layer4.1.Conv2d_conv3                [512, 2048, 1, 1]     [1, 2048, 5, 5]   1,048,576   26,214,400
# 145_model.layer4.1.BatchNorm2d_bn3                        [2048]     [1, 2048, 5, 5]       4,096      204,800
# 146_model.layer4.1.ReLU_relu                                   -     [1, 2048, 5, 5]           0            0
# 147_model.layer4.2.Conv2d_conv1                [2048, 512, 1, 1]      [1, 512, 5, 5]   1,048,576   26,214,400
# 148_model.layer4.2.BatchNorm2d_bn1                         [512]      [1, 512, 5, 5]       1,024       51,200
# 149_model.layer4.2.ReLU_relu                                   -      [1, 512, 5, 5]           0            0
# 150_model.layer4.2.Conv2d_conv2                 [512, 512, 3, 3]      [1, 512, 5, 5]   2,359,296   58,982,400
# 151_model.layer4.2.BatchNorm2d_bn2                         [512]      [1, 512, 5, 5]       1,024       51,200
# 152_model.layer4.2.ReLU_relu                                   -      [1, 512, 5, 5]           0            0
# 153_model.layer4.2.Conv2d_conv3                [512, 2048, 1, 1]     [1, 2048, 5, 5]   1,048,576   26,214,400
# 154_model.layer4.2.BatchNorm2d_bn3                        [2048]     [1, 2048, 5, 5]       4,096      204,800
# 155_model.layer4.2.ReLU_relu                                   -     [1, 2048, 5, 5]           0            0
# 156_model.AdaptiveAvgPool2d_avgpool                            -     [1, 2048, 1, 1]           0       53,248
# 157_model.Linear_fc                                    [2048, 6]              [1, 6]      12,294       24,570
# =============================================================================================================
# Total params: 23,520,326
# Trainable params: 12,294
# Non-trainable params: 23,508,032
# Total FLOPs: 2,009,549,242 / 2.01 GFLOPs
# -------------------------------------------------------------------------------------------------------------
# Input size (MB): 0.26
# Forward/backward pass size (MB): 115.17
# Params size (MB): 89.72
# Estimated Total Size (MB): 205.15
# =============================================================================================================

# %%
# Проверка настроек последнего слоя
print(model.model.fc)
print(model.model.fc.bias.requires_grad)
# Out:
# Linear(in_features=2048, out_features=6, bias=True)
# True

# %%
# Распаковываем архив
zip_path = 'iic_archive.zip'
extract_to = './data/'
os.makedirs(extract_to, exist_ok=True)

# !unzip -q {zip_path} -d {extract_to}

# %%
# Делаем трансформации, которые подразумевает модель:
# она обучалась на изображениях такого формата
train_transforms = T.Compose([
    # T.RandomRotation(180),
    # T.RandomHorizontalFlip(p=.5),
    # T.ColorJitter(brightness=.5, contrast=.5, saturation=.5, hue=.5),
    # T.RandomHorizontalFlip(),  # Случайное горизонтальное отражение
    T.Resize((150, 150)),  # Изменение размера изображений
    T.ToTensor(),  # Конвертация изображений в тензоры
    T.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])  # Нормализация
])

# Преобразования для валидационных данных
valid_transforms = T.Compose([
    T.Resize((150, 150)),
    T.ToTensor(),
    T.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# %%
# Про ImageFolder
# читаем тут: https://elbrus-ds-cheatsheets.streamlit.app/PyTorch_Datasets
train_dataset = torchvision.datasets.ImageFolder(
    'data/seg_train/seg_train',
    transform=train_transforms
)
valid_dataset = torchvision.datasets.ImageFolder(
    'data/seg_test/seg_test',
    transform=valid_transforms
)

# %%
train_dataset
# Out:
# Dataset ImageFolder
#     Number of datapoints: 14034
#     Root location: data/seg_train/seg_train
#     StandardTransform
# Transform: Compose(
#                RandomRotation(degrees=[-180.0, 180.0], interpolation=nearest, expand=False, fill=0)
#                RandomHorizontalFlip(p=0.5)
#                ColorJitter(brightness=(0.5, 1.5), contrast=(0.5, 1.5), saturation=(0.5, 1.5), hue=(-0.5, 0.5))
#                Resize(size=(150, 150), interpolation=bilinear, max_size=None, antialias=True)
#                RandomHorizontalFlip(p=0.5)
#                ToTensor()
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )

# %%
train_dataset.class_to_idx
# Out:
# {'buildings': 0,
#  'forest': 1,
#  'glacier': 2,
#  'mountain': 3,
#  'sea': 4,
#  'street': 5}

# %%
# Словарь для определения класса по индексу
idx2class= {j: i for i, j in train_dataset.class_to_idx.items()}
idx2class
# Out:
# {0: 'buildings',
#  1: 'forest',
#  2: 'glacier',
#  3: 'mountain',
#  4: 'sea',
#  5: 'street'}

# %%
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=32, shuffle=True)

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=0.002)
criterion = torch.nn.CrossEntropyLoss()

# %%
n_epochs = 1
train_epoch_acc = []
train_epoch_losses = []
valid_epoch_losses = []
valid_epoch_acc =[]
for epoch in range(n_epochs):
    model.train()
    loss_batch = []
    acc_batch  = []

    for images, labels in train_loader:
        images = images.to(DEVICE)
        labels = labels.to(DEVICE)

        preds = model(images)

        loss = criterion(preds, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        loss_batch.append(loss.item())
        _, predicted = torch.max(preds, 1)
        acc_batch.append((predicted == labels).sum().item() / labels.size(0))

    train_epoch_losses.append(sum(loss_batch) / len(loss_batch))
    train_epoch_acc.append(sum(acc_batch) / len(acc_batch))

    model.eval()
    loss_batch = []
    acc_batch  = []

    with torch.no_grad():
        for images, labels in valid_loader:
            images = images.to(DEVICE)
            labels = labels.to(DEVICE)

            preds = model(images)

            loss = criterion(preds, labels)
            loss_batch.append(loss.item())

            _, predicted = torch.max(preds, 1)
            acc_batch.append((predicted == labels).sum().item() / labels.size(0))

    valid_epoch_losses.append(sum(loss_batch) / len(loss_batch))
    valid_epoch_acc.append(sum(acc_batch) / len(acc_batch))

    print(f'---------- Epoch: {epoch+1} ----------')
    print(f'loss_train: {train_epoch_losses[-1]:.3f}, loss_valid: {valid_epoch_losses[-1]:.3f}')
    print(f'accuracy_train: {train_epoch_acc[-1]:.3f}, accuracy_valid: {valid_epoch_acc[-1]:.3f}')

print("Training complete")
# Out:
# ---------- Epoch: 1 ----------
# loss_train: 0.184, loss_valid: 0.291
# accuracy_train: 0.931, accuracy_valid: 0.893
# Training complete

# %% [markdown]
# ---------- Epoch: 1 ----------
# loss_train: 0.192, loss_valid: 0.289
# accuracy_train: 0.931, accuracy_valid: 0.902
# ---------- Epoch: 2 ----------
# loss_train: 0.187, loss_valid: 0.307
# accuracy_train: 0.929, accuracy_valid: 0.888
# Training complete

# %%
epochs = range(1, len(train_epoch_acc) + 1)

plt.figure(figsize=(12, 5))

# График Loss
plt.subplot(1, 2, 1)
plt.plot(epochs, train_epoch_losses, label='Training Loss')
plt.plot(epochs, valid_epoch_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

# График Accuracy
plt.subplot(1, 2, 2)
plt.plot(epochs, train_epoch_acc, label='Training Accuracy')
plt.plot(epochs, valid_epoch_acc, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

plt.show()

# %%
resize = T.Resize((150, 150))

# %%
img = resize(io.read_image('./data/seg_pred/seg_pred/10292.jpg')/255)  # Убедитесь, что размер изображения соответствует входному размеру модели
plt.imshow(torch.permute(img, (1, 2, 0)))

with torch.inference_mode():
    # pred_class = torch.sigmoid(model(img.unsqueeze(0).to(DEVICE))).round().item()
    preds = model(img.unsqueeze(0).to(DEVICE))
    pred_class = torch.argmax(preds, dim=1).item()

plt.axis('off')
plt.title(idx2class[pred_class]);
plt.show()

# print(f"Predicted class: {idx2class[pred_class]}")

# %% [markdown]
# ## Saving and Loading models

# %%
class Model(nn.Module):
    def __init__(self):
        super().__init__()

        self.fc_1 = nn.Linear(33, 1)
        self.fc_2 = nn.Linear(33, 2)

    def forward(self, x):
        out = self.fc_1(x)
        out = self.fc_2(out)
        return out

# %%
model = Model()

# %%
# fit
# eval
# test

# %%
model.state_dict()
# Out:
# OrderedDict([('model.conv1.weight',
#               tensor([[[[-7.4457e-03, -3.1783e-03,  3.7353e-02,  ...,  4.7936e-02,
#                          -2.0325e-02,  8.8140e-03],
#                         [-5.7435e-02,  4.4709e-02,  7.7509e-02,  ...,  8.8442e-02,
#                           2.9346e-02, -5.8331e-02],
#                         [ 6.8356e-02, -2.7044e-01,  4.0348e-01,  ..., -1.6491e-01,
#                           2.1868e-01, -7.2909e-02],
#                         ...,
#                         [-1.0874e-01,  3.8148e-01, -4.5487e-01,  ...,  6.8366e-01,
#                          -5.7855e-01,  2.2461e-01],
#                         [ 2.5698e-02, -1.7703e-01,  6.4375e-01,  ...,  5.2644e-01,
#                          -4.9317e-02, -6.8082e-02],
#                         [ 4.5281e-02, -1.3072e-01,  1.7864e-02,  ..., -3.5753e-01,
#                           1.8976e-01, -2.2302e-02]],
#
#                        [[ 8.9197e-03,  4.8768e-03, -1.5356e-02,  ...,  8.6949e-02,
#                          -6.5541e-02,  1.6895e-02],
#                         [-3.3543e-02,  3.9067e-02,  8.6565e-02,  ...,  1.1713e-01,
#                           2.1848e-02, -4.4082e-02],
#                         [ 5.5285e-02, -2.6424e-01,  4.2687e-01,  ..., -2.3723e-01,
#                           3.2017e-01, -1.1832e-01],
#                         ...,
#                         [-1.2660e-01,  5.3174e-01, -6.5811e-01,  ...,  9.4231e-01,
#                          -7.8085e-01,  2.3638e-01],
#                         [-2.6184e-02, -1.3307e-01,  7.2071e-01,  ...,  6.7549e-01,
#                          -4.4739e-02, -7.6890e-02],
#                         [ 5.7541e-02, -1.1750e-01,  6.1242e-02,  ..., -4.0917e-01,
#                           2.3303e-01, -5.2932e-02]],
#
#                        [[-4.7779e-04,  1.6238e-02, -3.8104e-02,  ...,  3.9925e-02,
#                          -5.5574e-02,  3.5801e-02],
#                         [-6.5767e-03,  5.8178e-02, -2.4649e-02,  ...,  8.0181e-02,
#                          -2.9761e-02,  1.9528e-02],
#                         [ 4.0737e-02, -1.2987e-01,  2.6059e-01,  ..., -1.3028e-02,
#                           9.7165e-02, -5.8032e-02],
#                         ...,
#                         [-1.0856e-01,  2.4382e-01, -2.0907e-01,  ...,  4.1097e-01,
#                          -4.5273e-01,  1.7489e-01],
#                         [ 4.4207e-02, -2.3403e-01,  4.7400e-01,  ...,  3.1394e-01,
#                          -3.6262e-02, -6.7147e-02],
#                         [ 4.4944e-02, -5.4664e-02, -6.0752e-02,  ..., -2.4463e-01,
#                           1.7754e-01, -3.5430e-02]]],
#
#
#                       [[[-2.7298e-02,  2.0683e-02,  1.6814e-02,  ...,  1.2392e-02,
#                          -1.1840e-03, -3.8390e-02],
#                         [-1.3302e-02, -2.2908e-02, -2.2597e-02,  ...,  8.7192e-03,
#                          -6.2325e-03,  3.0749e-03],
#                         [-3.5025e-02, -1.5756e-01, -2.7429e-01,  ..., -2.4909e-01,
#                          -1.2681e-01, -3.5484e-02],
#                         ...,
#                         [ 1.3155e-01,  4.6084e-01,  6.7895e-01,  ...,  6.3764e-01,
#                           3.3608e-01,  1.5905e-01],
#                         [-1.3717e-01, -4.5196e-01, -7.2624e-01,  ..., -5.9575e-01,
#                          -2.7557e-01, -9.4608e-02],
#                         [-8.6713e-03,  1.7849e-02,  2.5054e-02,  ...,  2.7866e-02,
#                          -3.5109e-02, -4.8400e-02]],
#
#                        [[-1.9661e-02,  1.1200e-02,  1.6908e-02,  ..., -8.5950e-03,
#                           2.0893e-03, -1.9545e-02],
#                         [-8.1260e-03, -2.1539e-02, -2.8773e-02,  ..., -1.5187e-03,
#                          -1.5268e-02,  1.3224e-02],
#                         [-5.5406e-02, -2.0284e-01, -3.2063e-01,  ..., -2.8697e-01,
#                          -1.6450e-01, -5.5894e-02],
#                         ...,
#                         [ 1.9563e-01,  4.7780e-01,  7.2965e-01,  ...,  6.9769e-01,
#                           3.7208e-01,  2.1853e-01],
#                         [-2.0044e-01, -5.6057e-01, -8.4592e-01,  ..., -6.9158e-01,
#                          -3.4235e-01, -1.4602e-01],
#                         [-2.3307e-02,  4.8436e-03,  2.3347e-02,  ...,  2.6427e-02,
#                          -8.9783e-03, -3.9997e-02]],
#
#                        [[-1.6925e-02,  4.0742e-03,  1.5102e-02,  ..., -1.7191e-02,
#                          -8.8521e-04, -9.8120e-04],
#                         [-1.2357e-02, -8.6553e-03, -8.2512e-05,  ...,  1.6604e-02,
#                          -1.2982e-02, -1.3488e-02],
#                         [-2.6519e-03, -7.7707e-02, -1.0403e-01,  ..., -8.4027e-02,
#                          -2.9427e-02,  4.2955e-03],
#                         ...,
#                         [ 3.7737e-02,  1.6211e-01,  3.4347e-01,  ...,  2.5266e-01,
#                           1.0823e-01,  6.2950e-02],
#                         [-5.5844e-02, -2.2892e-01, -3.5122e-01,  ..., -2.8128e-01,
#                          -1.0955e-01, -1.7502e-02],
#                         [-1.4699e-02,  4.8115e-02,  8.5756e-02,  ...,  4.2583e-02,
#                          -1.8420e-02, -5.7847e-02]]],
#
#
#                       [[[ 1.7126e-02, -1.2733e-02, -7.8937e-03,  ..., -2.3523e-03,
#                          -1.7698e-02, -2.4992e-02],
#                         [-1.0023e-02,  1.3238e-03, -1.5017e-02,  ..., -2.4748e-02,
#                          -2.4721e-02, -8.4801e-03],
#                         [-4.7837e-03, -1.9506e-02, -4.0114e-02,  ...,  3.9877e-03,
#                          -4.1784e-02, -5.7540e-02],
#                         ...,
#                         [-2.6159e-02, -3.3338e-02, -6.6218e-03,  ...,  2.1560e-01,
#                           7.6022e-02, -6.5001e-02],
#                         [-3.8019e-03, -2.1788e-02, -3.2171e-02,  ...,  5.4057e-02,
#                           1.0913e-02, -4.3484e-02],
#                         [ 8.6133e-03, -2.3943e-02, -3.7492e-02,  ..., -5.5298e-02,
#                          -6.5949e-02, -7.9387e-02]],
#
#                        [[-4.3164e-02, -1.5270e-02, -4.1200e-02,  ..., -4.0652e-02,
#                          -4.6058e-02, -1.1424e-02],
#                         [-2.4104e-02,  9.5575e-04, -5.1055e-03,  ...,  4.5997e-02,
#                           8.9127e-03,  3.1261e-02],
#                         [-5.1335e-02, -4.0013e-03,  6.3921e-02,  ...,  3.2526e-01,
#                           1.4078e-01,  4.7787e-02],
#                         ...,
#                         [-5.4555e-02,  4.0458e-02,  2.8744e-01,  ...,  8.3143e-01,
#                           4.4492e-01,  1.1609e-01],
#                         [-6.3108e-02, -2.5795e-02,  1.3088e-01,  ...,  4.6688e-01,
#                           1.8354e-01,  2.9379e-02],
#                         [-3.9806e-02,  1.3674e-03,  2.4139e-02,  ...,  1.3434e-01,
#                           1.9910e-02,  3.9052e-02]],
#
#                        [[ 3.1413e-02,  2.9708e-02,  5.0438e-02,  ...,  3.9750e-02,
#                           6.1649e-02,  4.3791e-02],
#                         [ 2.1043e-02, -5.7238e-03,  2.8721e-02,  ..., -1.9446e-02,
#                           2.6292e-02, -1.1900e-02],
#                         [ 6.7626e-02,  2.7595e-02, -1.7378e-03,  ..., -3.3596e-01,
#                          -1.2858e-01,  1.6244e-03],
#                         ...,
#                         [ 7.5840e-02, -1.1334e-02, -3.1348e-01,  ..., -1.0637e+00,
#                          -5.2956e-01, -6.3299e-02],
#                         [ 6.8298e-02,  4.7697e-02, -1.0782e-01,  ..., -5.4628e-01,
#                          -2.0203e-01,  1.2389e-02],
#                         [ 5.0239e-02, -1.3806e-03,  2.3972e-02,  ..., -9.2336e-02,
#                           3.3172e-02,  4.1393e-02]]],
#
#
#                       ...,
#
#
#                       [[[-4.5242e-02,  1.5439e-02,  2.4901e-02,  ...,  8.4793e-02,
#                           2.9544e-02,  3.2270e-02],
#                         [ 4.3449e-02,  2.0282e-01,  3.8691e-01,  ...,  6.1450e-01,
#                           5.1835e-01,  3.3268e-01],
#                         [-9.1034e-03,  1.4293e-01,  3.6977e-01,  ...,  6.8561e-01,
#                           5.6493e-01,  3.2741e-01],
#                         ...,
#                         [-9.2299e-03, -9.1729e-02, -1.7764e-01,  ..., -3.6439e-01,
#                          -3.1720e-01, -2.0399e-01],
#                         [ 2.6140e-02, -1.7652e-01, -3.5698e-01,  ..., -6.8481e-01,
#                          -5.9454e-01, -3.4448e-01],
#                         [-5.4938e-02, -2.3242e-01, -3.9422e-01,  ..., -6.4539e-01,
#                          -5.4939e-01, -3.4680e-01]],
#
#                        [[ 1.7957e-02,  5.1321e-03, -1.3757e-02,  ...,  1.0155e-02,
#                           3.3962e-03, -3.3774e-03],
#                         [-2.4205e-03, -2.2559e-02, -6.3925e-02,  ..., -9.3554e-02,
#                          -7.0935e-02, -5.9948e-02],
#                         [-1.3630e-02, -4.0346e-02, -7.5351e-02,  ..., -6.2276e-02,
#                          -5.2318e-02, -3.9915e-02],
#                         ...,
#                         [ 3.0784e-02,  1.7719e-02,  6.3537e-03,  ...,  2.5095e-02,
#                           6.1286e-03,  4.0245e-02],
#                         [ 1.9218e-02,  3.7630e-02,  6.2122e-02,  ...,  6.1399e-02,
#                           6.3679e-02,  6.3449e-02],
#                         [-2.3705e-03,  4.8930e-02,  4.6112e-02,  ...,  8.6873e-02,
#                           9.1821e-02,  7.7299e-02]],
#
#                        [[ 3.5059e-02, -1.8498e-02, -2.1810e-02,  ..., -5.7483e-02,
#                          -4.6110e-02, -3.5583e-02],
#                         [-4.7142e-02, -1.7807e-01, -2.9826e-01,  ..., -5.3419e-01,
#                          -4.4189e-01, -2.6315e-01],
#                         [ 4.0968e-02, -1.0676e-01, -3.3240e-01,  ..., -5.9356e-01,
#                          -4.8158e-01, -2.7299e-01],
#                         ...,
#                         [-6.6436e-03,  6.9772e-02,  1.7429e-01,  ...,  3.4361e-01,
#                           2.8147e-01,  1.7433e-01],
#                         [-2.9095e-02,  1.4838e-01,  3.2309e-01,  ...,  6.2560e-01,
#                           5.0243e-01,  2.8272e-01],
#                         [ 2.8538e-02,  1.7811e-01,  3.4895e-01,  ...,  5.4221e-01,
#                           4.7017e-01,  2.7781e-01]]],
#
#
#                       [[[-6.0239e-02, -1.8902e-03,  1.6193e-01,  ..., -1.8924e-02,
#                           2.6813e-02, -7.1216e-03],
#                         [ 3.0950e-03,  1.6219e-01,  2.3332e-01,  ..., -7.3886e-02,
#                           6.4485e-02, -4.8061e-02],
#                         [ 1.4639e-01,  2.7670e-01, -1.5717e-01,  ..., -1.7865e-01,
#                           2.7125e-01,  1.3800e-02],
#                         ...,
#                         [-1.9892e-02, -8.3717e-02, -2.0082e-01,  ...,  1.9357e+00,
#                           4.3050e-01, -4.4349e-01],
#                         [ 3.4114e-02,  1.0823e-01,  1.7419e-01,  ...,  5.6241e-01,
#                          -7.4754e-01, -5.7039e-01],
#                         [-2.6851e-02, -2.2847e-02, -1.3294e-03,  ..., -2.6969e-01,
#                          -5.8893e-01,  9.4454e-03]],
#
#                        [[ 4.6211e-02, -3.0009e-02, -2.4232e-02,  ..., -2.0173e-02,
#                          -4.5990e-03,  4.6680e-03],
#                         [-4.7208e-02, -1.1175e-01, -3.4491e-02,  ...,  7.3118e-03,
#                          -2.8632e-02,  6.3057e-03],
#                         [-3.7164e-02, -3.7290e-02,  2.3908e-01,  ...,  6.2615e-02,
#                          -8.7824e-03,  2.8079e-02],
#                         ...,
#                         [-1.6389e-02, -1.2738e-02,  8.5755e-02,  ..., -6.3381e-01,
#                          -1.8132e-01,  4.3537e-02],
#                         [-1.4817e-02, -5.7906e-02,  1.2612e-02,  ..., -1.8440e-01,
#                           1.7522e-01,  1.9263e-01],
#                         [ 1.9851e-02,  8.2573e-03,  5.5312e-02,  ..., -1.4064e-02,
#                           1.8552e-01,  7.3634e-02]],
#
#                        [[ 1.4785e-02,  1.9560e-02, -1.2323e-01,  ...,  3.8017e-02,
#                          -1.7383e-02, -3.4905e-03],
#                         [ 3.8257e-02, -3.3472e-02, -1.9793e-01,  ...,  6.4706e-02,
#                          -3.6185e-02,  4.0668e-02],
#                         [-9.8877e-02, -2.3288e-01, -8.8315e-02,  ...,  1.0060e-01,
#                          -2.3959e-01, -4.9064e-02],
#                         ...,
#                         [ 3.2498e-02,  7.9423e-02,  1.2802e-01,  ..., -1.2784e+00,
#                          -2.3310e-01,  3.7414e-01],
#                         [-1.7935e-02, -5.0338e-02, -1.8478e-01,  ..., -3.4855e-01,
#                           5.5104e-01,  3.8178e-01],
#                         [ 6.3057e-03,  1.7064e-02, -5.0283e-02,  ...,  2.5579e-01,
#                           3.9758e-01, -9.3654e-02]]],
#
#
#                       [[[-4.5319e-03, -3.1884e-03, -1.7744e-02,  ..., -2.9141e-02,
#                          -3.1408e-03,  2.0022e-02],
#                         [ 3.2164e-02,  1.6941e-02,  1.7667e-02,  ...,  7.7592e-02,
#                          -8.5563e-02, -6.5938e-02],
#                         [-2.1352e-02,  1.7603e-02, -1.3540e-01,  ...,  1.9487e-01,
#                           2.6668e-01,  3.6736e-02],
#                         ...,
#                         [ 3.5264e-03, -3.7018e-02,  2.7977e-02,  ...,  3.0237e-01,
#                          -9.3439e-02,  3.5356e-02],
#                         [-1.4690e-02, -1.7275e-02, -1.5557e-01,  ...,  3.9789e-02,
#                           6.9594e-02, -4.9624e-02],
#                         [ 9.9317e-03,  2.5011e-02,  4.3004e-02,  ..., -4.8231e-02,
#                          -3.4277e-02, -1.2353e-03]],
#
#                        [[-2.7902e-02,  1.2299e-02,  9.9426e-02,  ..., -4.0554e-02,
#                          -6.1634e-02, -1.8119e-02],
#                         [-7.0240e-02, -1.2168e-01, -3.5792e-02,  ...,  4.6470e-01,
#                           1.2914e-01, -3.7213e-02],
#                         [-4.2577e-02, -1.1116e-01, -5.7931e-01,  ...,  1.5717e-01,
#                           6.1004e-01,  3.8343e-01],
#                         ...,
#                         [ 7.2609e-02,  7.5998e-02,  3.7690e-01,  ...,  4.8943e-01,
#                          -4.8136e-01, -3.3809e-01],
#                         [-3.6940e-02, -6.7720e-02, -2.0148e-01,  ...,  3.9217e-01,
#                           3.2634e-01, -1.0543e-01],
#                         [-2.9647e-02, -5.1140e-03, -2.5650e-02,  ..., -8.8390e-02,
#                           8.7415e-02,  6.1362e-02]],
#
#                        [[-4.8754e-03,  5.3669e-02,  9.1071e-02,  ..., -8.5725e-02,
#                          -6.2401e-02,  1.0031e-02],
#                         [-7.3206e-02, -1.2176e-01, -1.5381e-02,  ...,  3.2860e-01,
#                          -4.0904e-02, -1.1326e-01],
#                         [-3.6819e-02, -5.9915e-02, -4.3039e-01,  ...,  1.9722e-01,
#                           5.1124e-01,  1.9084e-01],
#                         ...,
#                         [ 6.1925e-02,  2.7069e-03,  1.9578e-01,  ...,  4.0343e-01,
#                          -3.9878e-01, -2.8337e-01],
#                         [-1.6748e-02, -2.1831e-02, -1.7046e-01,  ...,  3.0545e-01,
#                           3.2591e-01, -5.7294e-02],
#                         [-1.8746e-02,  1.8204e-02, -2.2311e-03,  ..., -7.9908e-02,
#                           8.0856e-02,  8.8545e-02]]]], device='cuda:0')),
#              ('model.bn1.weight',
#               tensor([1.5015, 2.3959, 2.4188, 2.1209, 4.6100, 2.0853, 1.6228, 2.1865, 2.7581,
#                       2.0903, 1.7681, 2.1057, 6.8309, 2.6507, 1.9449, 2.3006, 1.7701, 2.2712,
#                       1.6792, 7.5183, 2.3296, 1.7288, 2.3918, 2.2404, 5.9957, 2.2425, 2.5086,
#                       2.2304, 1.5343, 9.4247, 1.7311, 2.0335, 6.2795, 2.2514, 2.3651, 2.1595,
#                       1.7528, 2.0686, 1.7344, 7.1874, 2.2505, 4.7094, 1.8000, 1.7114, 1.8585,
#                       1.6867, 1.7534, 1.8077, 1.5146, 2.0271, 1.4854, 1.4940, 4.4586, 1.5751,
#                       2.6822, 1.9343, 2.1422, 2.4709, 2.5950, 2.4721, 1.6491, 2.3366, 1.4622,
#                       1.7303], device='cuda:0')),
#              ('model.bn1.bias',
#               tensor([ 3.0887,  2.2352,  4.1188,  1.4539, -4.5286,  2.6051,  2.7197,  2.4477,
#                        1.1948,  2.0417,  2.7164,  6.4281, -6.5246,  1.1299,  2.5385,  5.4271,
#                        4.7583, 10.0577,  2.9221, 14.8767,  2.5501,  2.6791,  2.3384,  2.1234,
#                       -8.7308,  2.1236,  4.2243,  1.7238,  3.1940, 23.6385,  2.2945,  2.6236,
#                       -9.8369,  1.7964,  2.5816,  2.6411,  2.5950,  2.2985,  2.6985, 16.0095,
#                        1.8784, -3.1754,  2.6861,  2.8985,  2.6857,  2.7022,  2.3671,  2.5593,
#                        3.1665,  2.7336,  2.8885,  2.9633, -4.3890,  2.6350,  1.3327,  2.2262,
#                        2.2047,  4.0339,  4.9749,  2.6914,  2.6562,  1.9285,  2.8923,  2.7343],
#                      device='cuda:0')),
#              ('model.bn1.running_mean',
#               tensor([ 2.3812e-03, -1.7511e-03, -1.4574e+00,  4.6702e-02, -1.4825e-01,
#                        4.3529e-02, -3.2161e-02,  2.2394e-02,  1.3173e-01,  1.7652e-02,
#                       -1.2182e-02,  1.1158e-01, -1.3581e+00, -1.2353e-01, -1.8251e-03,
#                       -5.1467e-02, -1.7976e-02, -2.5020e-01, -1.1476e-01, -2.1651e-02,
#                       -6.1511e-02,  5.9026e-02,  1.2748e-03,  1.0522e-01, -7.9555e-01,
#                        4.5699e-02,  1.1758e+00,  8.1496e-03,  1.3976e-02,  8.1906e-02,
#                        2.0120e-01, -7.5417e-02,  7.1572e-01,  1.0476e-01,  1.9812e-02,
#                        6.1561e-02, -3.0854e-02, -3.2775e-02,  2.2640e-02,  2.8891e-03,
#                        6.6390e-02,  4.4644e-02,  7.9525e-03,  1.5551e-02, -1.1694e-03,
#                        2.5222e-03, -5.5944e-03, -1.0156e-02,  1.4724e-02,  9.7508e-02,
#                       -4.3919e-03, -7.4838e-02,  1.3847e+00,  1.9092e-02,  1.0326e-02,
#                        4.2969e-03, -1.5022e-02, -1.7807e+00,  1.5501e+00,  2.7783e-03,
#                        2.2916e-02,  2.8734e-02,  1.0426e-02, -3.5576e-02], device='cuda:0')),
#              ('model.bn1.running_var',
#               tensor([4.0376e+00, 1.1728e+01, 1.3880e+01, 9.4735e+00, 3.7867e+00, 9.2560e+00,
#                       5.0227e+00, 1.2383e+01, 2.3235e+01, 1.0139e+01, 6.4203e+00, 1.4629e+00,
#                       2.8722e+01, 2.2406e+01, 6.9891e+00, 1.1314e+01, 6.1854e+00, 3.6841e+00,
#                       1.3426e+00, 7.7260e+01, 9.7958e+00, 4.6954e+00, 1.2239e+01, 2.2850e+00,
#                       6.9189e+00, 1.2340e+01, 9.7451e+00, 1.1773e+01, 4.2999e+00, 1.4577e+02,
#                       1.1064e+00, 3.7961e+00, 7.1941e+00, 2.9243e+00, 5.4142e+00, 1.1035e+01,
#                       5.9053e+00, 9.4847e+00, 5.7087e+00, 5.7754e+01, 2.2271e+00, 9.1499e+00,
#                       6.9829e+00, 6.6959e+00, 7.5940e+00, 5.5240e+00, 6.6027e+00, 6.6095e+00,
#                       4.4097e+00, 2.9956e+00, 3.9272e+00, 1.8514e-01, 1.0372e+01, 4.5931e+00,
#                       1.9230e+01, 7.4661e+00, 1.1401e+01, 7.7879e+00, 6.7769e+00, 1.5429e+01,
#                       5.9173e+00, 2.8773e+00, 1.4222e-01, 6.1721e+00], device='cuda:0')),
#              ('model.bn1.num_batches_tracked',
#               tensor(678545, device='cuda:0')),
#              ('model.layer1.0.conv1.weight',
#               tensor([[[[ 0.0976]],
#
#                        [[ 0.1075]],
#
#                        [[-0.0316]],
#
#                        ...,
#
#                        [[ 0.0260]],
#
#                        [[ 0.0199]],
#
#                        [[ 0.0393]]],
#
#
#                       [[[-0.0191]],
#
#                        [[-0.4422]],
#
#                        [[-0.0103]],
#
#                        ...,
#
#                        [[-0.0138]],
#
#                        [[-0.0162]],
#
#                        [[ 0.0062]]],
#
#
#                       [[[-0.0107]],
#
#                        [[ 0.1030]],
#
#                        [[-0.0029]],
#
#                        ...,
#
#                        [[ 0.0234]],
#
#                        [[ 0.0056]],
#
#                        [[-0.0189]]],
#
#
#                       ...,
#
#
#                       [[[-0.0323]],
#
#                        [[ 0.0705]],
#
#                        [[-0.1449]],
#
#                        ...,
#
#                        [[-0.0385]],
#
#                        [[-0.0579]],
#
#                        [[-0.0958]]],
#
#
#                       [[[-0.0279]],
#
#                        [[ 0.0806]],
#
#                        [[ 0.2023]],
#
#                        ...,
#
#                        [[ 0.0754]],
#
#                        [[ 0.0353]],
#
#                        [[-0.0847]]],
#
#
#                       [[[-0.2519]],
#
#                        [[ 0.0904]],
#
#                        [[ 0.0329]],
#
#                        ...,
#
#                        [[ 0.0355]],
#
#                        [[-0.0453]],
#
#                        [[-0.3437]]]], device='cuda:0')),
#              ('model.layer1.0.bn1.weight',
#               tensor([3.0406, 3.3732, 1.6742, 3.2876, 1.5845, 1.1509, 2.9444, 2.6691, 1.4094,
#                       1.3219, 2.6305, 2.0171, 1.1544, 3.9487, 1.1455, 1.4239, 1.4901, 3.2213,
#                       3.0759, 3.5630, 1.1990, 2.6459, 1.2269, 2.3508, 1.1269, 1.8853, 3.4161,
#                       1.2602, 3.4322, 4.3920, 3.8470, 2.6279, 3.7389, 5.6243, 3.1769, 2.6993,
#                       3.2218, 3.1167, 1.5799, 3.1793, 1.8183, 1.7984, 1.4633, 5.0873, 1.5466,
#                       1.0494, 3.7223, 2.5968, 3.2727, 1.5891, 1.5404, 0.9666, 4.9068, 1.4350,
#                       2.5122, 5.0295, 1.2324, 1.8920, 1.4375, 1.4357, 2.2270, 2.3093, 1.4636,
#                       3.8951], device='cuda:0')),
#              ('model.layer1.0.bn1.bias',
#               tensor([-0.6373, -1.5816, -1.1582, -0.9089, -0.6057,  0.7612, -1.0087, -0.3910,
#                        1.2273,  1.0452, -0.2017,  0.6905,  1.3606, -2.3889,  1.4291,  1.6391,
#                        0.3737, -1.0351, -0.8422, -2.1702,  1.1748,  0.3294,  1.0442,  0.6477,
#                        1.9193,  3.2266, -1.4150,  1.9570, -0.5196, -4.2092,  7.8170, -1.0442,
#                       -1.9579, -7.4013, -0.3562, -0.0310, -0.6147, -1.5703,  0.5152, -2.4993,
#                        0.1724, -1.7276,  1.3592, -2.8751,  1.3825,  1.0876, -1.6173, -0.1868,
#                        7.2670,  0.2519,  0.6297,  1.3271, -2.6530,  1.8387, -2.2425, -5.4275,
#                        0.8016,  0.4660,  1.4305,  1.3802,  3.5124, -1.1995,  1.3597, -1.5195],
#                      device='cuda:0')),
#              ('model.layer1.0.bn1.running_mean',
#               tensor([-10.2409,  -4.6505,  10.5943, -11.0759,   4.4087,  -1.8524,  -9.9408,
#                        -5.8079,  -5.7876,  10.3015, -29.0338,  -3.8745,  -8.4001, -15.2681,
#                        -3.7234,  -2.3406, -12.4334,  -9.3647, -15.3783,   0.4616,  -2.6238,
#                        -7.0442,  -6.5846,  -5.8241,  -3.7599,   4.6617, -13.2198,   1.8959,
#                       -11.8255,  17.5836, -18.3746, -13.7299,  -2.8748,  18.9254, -14.8441,
#                        -6.9256, -12.0566,  -9.6878,  -6.6389,   5.5802,  -5.0958,   9.0661,
#                        -2.0711,  -7.8933,  -7.7468,  -3.1737,  -8.1493,  -4.9061, -29.9213,
#                       -28.4992, -10.8655,  -7.3381, -13.7895,  -5.0129, -20.3699,  12.9977,
#                        -7.0376,  -1.3077,  -6.7670,   0.6433,  47.8249, -30.6366,  23.5856,
#                       -13.2436], device='cuda:0')),
#              ('model.layer1.0.bn1.running_var',
#               tensor([ 26.4836,  22.4085,   7.8054,  29.1764,   3.7464,   2.1822,  17.7953,
#                        11.2114,  10.0503,   6.2598,  12.5097,   6.5522,   2.9854,  37.7733,
#                         4.1809,  12.7389,  16.9843,  27.8179,  27.1656,  24.9061,   2.8520,
#                        20.7399,   3.2060,  14.9160,   3.8006,  28.3924,  18.3200,  12.2164,
#                        39.5309,  73.7946, 492.9874,  20.6174,  27.4985,  68.2953,  28.3753,
#                        27.5777,  29.6002,  17.4574,   6.7207,  52.2681,   6.2052,   4.1266,
#                         4.6888,  47.8102,   7.7978,   3.4086,  21.1888,  17.8846, 299.2489,
#                        37.3828,  37.1409,   2.7795,  58.3294,   7.1715,  11.7746,  79.9812,
#                         2.9888,  35.0689,  10.1157,   8.5875, 155.6774,  18.2809,  30.8426,
#                        32.5540], device='cuda:0')),
#              ('model.layer1.0.bn1.num_batches_tracked',
#               tensor(678545, device='cuda:0')),
#              ('model.layer1.0.conv2.weight',
#               tensor([[[[-2.2696e-02,  2.0703e-02, -1.6046e-02],
#                         [ 3.5861e-02,  1.1924e-01,  4.3285e-02],
#                         [-2.0550e-02,  2.3949e-02, -2.3750e-02]],
#
#                        [[-2.1404e-03, -5.9127e-03, -3.7947e-03],
#                         [-3.1635e-03,  2.9044e-02,  7.4652e-04],
#                         [ 5.3162e-03,  4.0038e-03, -5.4581e-03]],
#
#                        [[ 1.5741e-02,  2.3334e-02,  1.7380e-02],
#                         [-5.0947e-03, -2.4561e-02, -1.6448e-02],
#                         [ 2.5490e-02,  2.2782e-02,  2.7213e-02]],
#
#                        ...,
#
#                        [[-1.6355e-02, -6.2244e-03, -5.4319e-03],
#                         [ 1.2068e-02,  2.6678e-02,  1.9589e-03],
#                         [ 2.8873e-02,  3.0023e-02,  2.2400e-04]],
#
#                        [[ 6.8592e-02, -5.7610e-03,  5.2316e-02],
#                         [-2.5392e-02, -1.5406e-01, -6.6894e-02],
#                         [ 2.6558e-02, -4.2283e-02,  1.6824e-02]],
#
#                        [[ 1.6321e-03,  3.5782e-03, -9.2394e-03],
#                         [ 2.8953e-03,  5.9615e-02,  1.1485e-02],
#                         [-2.2704e-02, -3.8630e-03, -1.4942e-03]]],
#
#
#                       [[[-1.0847e-02,  2.1959e-02,  1.1317e-02],
#                         [-1.8481e-03,  4.5191e-02,  2.5097e-02],
#                         [-1.7031e-02,  2.9865e-02,  5.8603e-03]],
#
#                        [[ 7.0763e-03,  6.7129e-02,  4.0830e-02],
#                         [ 5.2390e-02,  1.8943e-01,  6.6652e-02],
#                         [-1.5760e-02,  5.0816e-02,  1.0229e-03]],
#
#                        [[ 2.1333e-02, -4.1780e-02, -3.6687e-02],
#                         [ 4.5998e-02,  7.6685e-02,  8.0430e-02],
#                         [ 3.5261e-02,  4.5326e-02,  4.2193e-02]],
#
#                        ...,
#
#                        [[ 2.5740e-02,  3.2378e-02,  2.4502e-02],
#                         [ 3.6815e-02,  6.1527e-02,  4.0220e-02],
#                         [ 2.9111e-02,  3.5067e-02,  2.5024e-02]],
#
#                        [[-4.2074e-02, -7.2411e-02, -8.2464e-02],
#                         [-3.6992e-02, -5.5108e-02, -5.5095e-02],
#                         [-2.6648e-02, -3.5078e-02, -5.4804e-02]],
#
#                        [[ 1.7020e-02,  9.1817e-02,  1.7415e-02],
#                         [ 5.5397e-02,  2.6508e-01,  8.6123e-02],
#                         [-1.6850e-03,  7.9764e-02,  8.3084e-03]]],
#
#
#                       [[[-1.7194e-02, -6.0267e-03,  4.3413e-02],
#                         [ 3.6492e-02, -6.6291e-02,  9.1512e-03],
#                         [ 1.6897e-02,  6.2863e-03,  3.3414e-02]],
#
#                        [[-5.2542e-02,  1.9762e-02, -7.7549e-03],
#                         [-3.7920e-02,  4.8231e-02,  2.8764e-02],
#                         [ 2.4744e-03, -5.7839e-03,  3.4371e-03]],
#
#                        [[ 1.4934e-02, -3.9724e-02, -1.9673e-02],
#                         [-4.5706e-02,  9.7120e-02, -4.7337e-02],
#                         [ 3.2237e-02,  6.9850e-02,  2.8454e-02]],
#
#                        ...,
#
#                        [[-1.3458e-02, -4.0675e-03, -1.4522e-02],
#                         [ 4.1757e-02, -5.4401e-02, -4.4992e-03],
#                         [-2.4241e-02,  1.1963e-02, -4.8259e-02]],
#
#                        [[-2.0190e-02, -6.5220e-02, -7.1381e-02],
#                         [-1.1647e-01,  1.7186e-01, -8.8690e-02],
#                         [-1.8354e-02,  4.3690e-03,  6.8441e-03]],
#
#                        [[ 4.0613e-02,  3.1316e-02, -1.8530e-03],
#                         [-9.1553e-03, -3.3222e-02, -3.6320e-02],
#                         [ 2.5885e-02, -1.2632e-04,  2.2993e-02]]],
#
#
#                       ...,
#
#
#                       [[[ 2.9343e-02,  7.4934e-02, -1.3655e-02],
#                         [ 1.3564e-01,  1.0393e-01, -2.8691e-02],
#                         [ 4.2330e-02,  1.7165e-02, -4.1066e-02]],
#
#                        [[-7.1346e-02, -1.9350e-02, -4.1239e-02],
#                         [ 1.6500e-02,  2.5663e-01, -4.3120e-03],
#                         [-1.5905e-02, -4.0887e-02, -3.4962e-02]],
#
#                        [[-5.7157e-03,  6.2881e-03,  4.6416e-02],
#                         [-5.0531e-02, -3.6914e-02, -3.9303e-02],
#                         [ 1.5014e-02, -1.1458e-02, -3.5503e-02]],
#
#                        ...,
#
#                        [[ 4.8398e-02,  4.4439e-02,  4.9545e-02],
#                         [ 2.6063e-02,  7.1815e-02,  2.3241e-02],
#                         [ 1.0676e-02,  7.4726e-03,  7.9151e-03]],
#
#                        [[-1.6248e-03, -5.7271e-02,  1.6854e-02],
#                         [-4.6288e-02, -7.0437e-02, -1.4953e-02],
#                         [ 2.5470e-02,  9.1335e-03,  5.4726e-02]],
#
#                        [[ 4.6029e-02,  2.3245e-02, -5.4083e-02],
#                         [ 4.1902e-03,  2.1067e-01,  4.5466e-02],
#                         [-6.9282e-02, -2.4555e-02,  7.1737e-04]]],
#
#
#                       [[[ 6.2838e-03, -2.5159e-04, -1.5606e-03],
#                         [ 1.8487e-02,  1.1635e-02,  9.0470e-03],
#                         [-1.9930e-02, -4.3356e-03,  1.7037e-02]],
#
#                        [[-1.9521e-02, -2.4992e-03,  1.0325e-02],
#                         [-2.1540e-02,  3.4903e-02,  3.8003e-03],
#                         [ 8.5696e-03,  3.7185e-03, -8.9532e-03]],
#
#                        [[ 1.2828e-02, -1.3679e-02,  2.0258e-02],
#                         [-6.3585e-02, -1.1893e-01, -6.6844e-02],
#                         [ 9.8448e-04,  8.4979e-03,  4.2403e-02]],
#
#                        ...,
#
#                        [[ 3.2422e-03,  1.5143e-02,  1.5035e-02],
#                         [ 1.1480e-02, -1.5712e-02, -1.1711e-02],
#                         [-8.1094e-03, -1.9111e-03, -1.6865e-02]],
#
#                        [[-5.5720e-02, -1.2743e-01, -5.1117e-02],
#                         [-3.3796e-02, -6.2784e-02,  7.2270e-03],
#                         [ 3.0996e-02,  1.7205e-02,  4.2837e-02]],
#
#                        [[-4.1153e-03,  2.0114e-02,  3.2348e-02],
#                         [ 3.6998e-02,  2.2092e-02,  3.0705e-02],
#                         [-2.9327e-02, -2.3453e-02,  9.4919e-03]]],
#
#
#                       [[[ 4.9441e-02, -6.5902e-03,  7.7315e-03],
#                         [ 4.2361e-02, -2.5559e-03,  3.0536e-02],
#                         [ 6.3829e-02,  6.4028e-03,  2.2941e-02]],
#
#                        [[ 8.3658e-03,  6.7766e-03,  1.4346e-02],
#                         [ 3.9610e-02, -6.0965e-03, -2.5761e-02],
#                         [ 2.3710e-02,  2.2762e-02,  1.7125e-03]],
#
#                        [[-1.1927e-02,  2.6756e-03,  6.1179e-04],
#                         [ 7.6416e-02,  1.2598e-03, -3.2025e-02],
#                         [ 2.6111e-02,  1.9802e-03, -1.8904e-03]],
#
#                        ...,
#
#                        [[ 5.5992e-02, -1.2812e-03,  2.0329e-02],
#                         [-9.7940e-03, -2.0039e-02,  2.7651e-02],
#                         [-2.3354e-02, -2.5980e-02,  1.4059e-02]],
#
#                        [[-4.4423e-02, -2.5000e-02,  1.7138e-02],
#                         [-3.3437e-03, -4.3859e-02, -8.3186e-02],
#                         [-6.4188e-02, -4.1732e-02, -3.0868e-02]],
#
#                        [[ 1.5796e-02,  2.4122e-05, -1.8575e-02],
#                         [ 1.5007e-02, -1.4469e-02, -2.6824e-02],
#                         [ 1.7688e-02, -5.2508e-02, -2.1338e-02]]]], device='cuda:0')),
#              ('model.layer1.0.bn2.weight',
#               tensor([1.2269, 4.1933, 4.6160, 1.6200, 0.7223, 0.8939, 1.5098, 1.9120, 5.0028,
#                       3.9994, 1.2766, 2.2722, 0.8034, 2.4575, 0.8202, 1.6219, 1.7967, 2.2346,
#                       1.0197, 0.9169, 0.7588, 0.9879, 1.0668, 1.1104, 1.6642, 1.4793, 1.9041,
#                       1.1312, 1.5163, 0.6898, 1.4890, 2.8467, 1.0816, 2.3665, 0.7117, 1.5362,
#                       1.9098, 0.7117, 0.7684, 0.9326, 3.0926, 3.5288, 4.2159, 1.2289, 1.3678,
#                       1.0890, 1.2380, 0.9371, 1.5377, 0.8209, 0.7027, 1.1581, 0.7018, 2.3900,
#                       0.7304, 1.7567, 1.4494, 1.4574, 1.5377, 0.7463, 0.8541, 1.1179, 1.1707,
#                       1.1830], device='cuda:0')),
#              ('model.layer1.0.bn2.bias',
#               tensor([ -0.5390,  -9.0789,  10.4095,   0.4331,   1.9654,   1.4451,  -2.0570,
#                        -1.4379,  11.6768,  10.7898,   1.2242,  -3.8810,   3.2740,   5.2465,
#                         2.3901,  -0.7278,  -1.4894,  -3.0164,   0.7108,   0.3737,   1.4762,
#                        -0.5088,  -0.8195,   0.6680,   0.3928,  -2.3285,  -2.5298,  -1.0383,
#                         0.5757,   0.9102,   0.6052,   7.1384,   0.7947,  -4.1999,   1.9590,
#                         0.5673,  -3.1922,   2.9005,   3.3264,   0.0963,   7.7079, -15.2104,
#                        10.8061,   0.5018,   0.3526,   0.5310,  -0.1467,   0.6931,  -1.5640,
#                         3.2213,   0.9647,   0.8109,   0.8992,   4.9784,   2.8226,   0.4059,
#                        -1.4396,   0.6812,   0.1798,   2.7428,   3.6935,  -0.5554,   0.8507,
#                         0.2887], device='cuda:0')),
#              ('model.layer1.0.bn2.running_mean',
#               tensor([  5.5017,   3.9398,  -0.7738,   4.3221,   1.7305,   2.0407,   4.1472,
#                         1.4763,   2.8963,   0.0885,  -5.3813,   2.4976,   0.4254,  -9.4626,
#                         1.4241,  -1.3009,  -3.3272, -25.0728,   7.6294,   3.3468,   5.3503,
#                         3.6229,   0.3896,   2.0913,   6.9518,   1.8674,   3.8988,   3.2840,
#                         7.5800,   0.5595,   4.9256,  -1.7741,   2.3402,   0.0674,   1.5272,
#                         7.3015,   0.4176,   4.3174,  -3.1691,   3.6519,  -0.3062, -10.6641,
#                        -8.8239,   3.8581,  -1.4485,   6.3688,  -2.1029,   8.6202,   1.6221,
#                         0.1572,  -0.8648,   4.5112,  -0.0327,  -0.7263,   4.1557,   7.5574,
#                        -4.1168,   7.8902,   7.5000,  -8.0684,   0.7746,   2.4667,   4.2707,
#                         5.1898], device='cuda:0')),
#              ('model.layer1.0.bn2.running_var',
#               tensor([ 10.5911,  18.3151,  84.7011,  53.0181,   6.8294,   3.5359,  11.1063,
#                         7.3843, 224.8750, 168.4487,   6.8733,   7.1347,   3.6594,  41.9987,
#                         4.3867,  10.2167,  13.0796,  14.1069,   8.1606,   3.8299,   2.9251,
#                         8.9402,   6.9282,  14.7605,  58.2256,   4.6632,  12.6787,   6.4890,
#                        29.4149,   9.9575,  38.9552,  28.5134,   7.9080,   6.4405,   2.3383,
#                        34.6561,   6.4758,   8.8090,  10.5365,  11.8910,  33.8874,  20.0520,
#                        81.1755,  13.2951,  26.9798,   7.7535,   9.2658,   9.0181,  12.1404,
#                        10.6069,   8.4576,  14.4877,   5.8999,  22.7130,   8.4647,  40.8087,
#                         3.6570,  26.7942,  36.2961,  19.1630,   7.1736,   7.2019,  17.7153,
#                         9.2330], device='cuda:0')),
#              ('model.layer1.0.bn2.num_batches_tracked',
#               tensor(678545, device='cuda:0')),
#              ('model.layer1.0.conv3.weight',
#               tensor([[[[ 0.0317]],
#
#                        [[-0.0265]],
#
#                        [[ 0.1892]],
#
#                        ...,
#
#                        [[-0.0049]],
#
#                        [[ 0.0235]],
#
#                        [[-0.0032]]],
#
#
#                       [[[-0.0261]],
#
#                        [[ 0.0521]],
#
#                        [[-0.0725]],
#
#                        ...,
#
#                        [[ 0.0468]],
#
#                        [[-0.6060]],
#
#                        [[-0.1119]]],
#
#
#                       [[[-0.0007]],
#
#                        [[ 0.0401]],
#
#                        [[ 0.0942]],
#
#                        ...,
#
#                        [[ 0.0503]],
#
#                        [[-0.0658]],
#
#                        [[-0.0170]]],
#
#
#                       ...,
#
#
#                       [[[ 0.0796]],
#
#                        [[ 0.1535]],
#
#                        [[-0.1949]],
#
#                        ...,
#
#                        [[ 0.0102]],
#
#                        [[-0.0106]],
#
#                        [[ 0.0551]]],
#
#
#                       [[[ 0.0604]],
#
#                        [[-0.0994]],
#
#                        [[ 0.3125]],
#
#                        ...,
#
#                        [[-0.0171]],
#
#                        [[ 0.0087]],
#
#                        [[-0.0379]]],
#
#
#                       [[[-0.1076]],
#
#                        [[-0.0041]],
#
#                        [[ 0.0315]],
#
#                        ...,
#
#                        [[ 0.0349]],
#
#                        [[ 0.0076]],
#
#                        [[ 0.0326]]]], device='cuda:0')),
#              ('model.layer1.0.bn3.weight',
#               tensor([ 6.4419,  3.9721,  1.7028,  1.9866,  2.6503,  5.9643,  2.2052,  5.9483,
#                        2.5845,  3.4929,  2.4497,  4.2847,  2.6170,  3.0898,  3.8286,  3.0642,
#                        2.7014,  5.1815,  3.1125,  2.8116,  2.9901,  5.6894,  3.5639,  4.3949,
#                        3.7836,  4.4207,  2.8963,  1.3910,  3.8321,  4.9710,  3.3606,  2.6988,
#                        2.5898,  4.4270,  1.8947,  3.2962,  3.0982,  1.9232,  1.8222,  2.6614,
#                        5.1762,  2.3007,  1.6194,  5.1709,  2.0336,  0.4956,  0.7527,  1.3634,
#                        3.9108,  0.2527,  3.6181,  1.8896,  4.2696,  5.0926,  6.2690,  1.9067,
#                        2.6618,  1.5983,  1.8794,  5.4458,  1.0902,  4.5144,  6.7515,  2.7004,
#                        4.0939,  6.1341,  3.2104,  0.9863,  2.4774,  4.8952,  0.7974,  3.9876,
#                        1.9198,  2.4433,  3.2113,  2.2925,  1.6229,  5.4968,  1.2367,  4.4492,
#                        4.6296,  0.5987,  0.0105,  3.2723,  2.0057,  5.7669,  2.6538,  3.3809,
#                        3.9991,  6.0748,  1.1859,  3.8381,  1.2024,  2.0456,  2.6808,  2.5001,
#                        2.5678,  1.3251,  2.3349,  3.2175,  1.2316, -1.5706,  3.0250,  3.3350,
#                        2.8152,  5.6962,  2.6919,  2.2594,  1.7059,  1.6210,  5.7426,  4.2494,
#                        1.6914,  6.6098,  2.7324,  2.5051,  6.4100,  4.0339,  2.2065,  0.4303,
#                        2.9098,  2.3763,  3.4524,  2.8186,  6.1539,  5.2903,  5.3093,  0.2180,
#                        2.1067,  3.9253,  3.8505,  3.3256,  5.9915,  2.7116,  8.0500,  2.2609,
#                        2.9730,  4.1113,  6.8310,  3.1194,  2.6852,  4.2493,  4.0351,  1.6496,
#                        2.7520,  2.5625,  5.6339,  5.9420,  3.6034,  3.0915,  4.8820,  3.6869,
#                        1.7914,  4.1906,  6.0103,  2.6587,  1.0377,  0.4566,  3.1752,  3.0544,
#                        2.5824,  6.8451,  4.2297,  4.7651,  1.1906,  1.3770,  6.0312,  0.9013,
#                        3.4281,  6.6567,  0.8196,  4.3253,  4.0066,  1.7570,  2.1773,  3.5264,
#                        3.1743,  0.1622,  2.2325,  0.3921,  5.4405,  1.5259,  3.4520,  2.5017,
#                        1.1454,  4.2158,  4.3063,  2.0048,  6.0572,  3.0989,  2.4665,  5.6535,
#                        2.2782,  3.7408,  2.2586,  2.1733,  0.8133,  6.6338,  5.9590,  6.1409,
#                        2.7515,  3.7994,  7.2114,  2.1814,  3.4010,  6.1610,  0.0623,  3.5045,
#                        3.8673,  3.8847,  3.0302,  3.5143,  5.2357,  4.7971,  3.8154,  2.2320,
#                        3.8069,  5.8749,  0.2254,  3.4810,  3.0600,  4.1883,  1.2046,  4.5856,
#                        1.7564,  2.8061,  6.1894,  5.6083,  3.1785,  3.8147,  5.5631,  2.9062,
#                        0.8812,  4.3251,  6.4441,  2.5458,  2.1781,  2.0992,  5.6290,  1.9592,
#                        3.2345,  1.1125,  1.9743,  5.0261,  2.9921,  3.3731,  3.6084,  1.9804,
#                        4.7733,  6.9238,  0.6604,  2.6084,  3.7706,  6.4487,  4.9229,  3.4423],
#                      device='cuda:0')),
#              ('model.layer1.0.bn3.bias',
#               tensor([ 2.3980e-01, -1.7625e-01,  9.3503e-02, -1.1244e-01,  3.2019e-01,
#                        2.1027e-01, -9.6742e-01,  1.0316e+00, -4.9852e-03, -3.5049e-01,
#                       -3.4234e-01,  3.8156e-01,  7.4295e-01, -1.4642e+00,  2.7678e-01,
#                        1.9456e-01,  4.8922e-01,  1.0685e+00,  4.2008e-01, -5.1202e-02,
#                       -1.6242e-01, -1.7014e-01,  8.4132e-02,  3.9959e-01,  1.0465e-01,
#                        2.2584e-01, -7.3940e-02, -1.1488e-01,  1.9765e-01,  6.7197e-01,
#                       -5.9026e-01,  3.0893e-02, -4.9350e-01,  1.1781e+00,  2.2440e-01,
#                        9.1100e-01,  2.6208e-01,  1.0680e-01, -1.5681e-02,  1.5962e-01,
#                        4.0302e-01,  2.5665e-01, -2.7389e-01, -4.7309e-01,  1.2837e+00,
#                       -1.9280e+00, -1.5804e+00, -7.1203e-02,  1.2819e-01, -4.9163e-01,
#                        3.2072e-01, -3.6701e-01, -7.2561e-01,  3.5197e-01,  1.7407e-01,
#                        2.0031e-01, -2.2363e-02,  5.1762e-01, -1.6495e-02, -3.6835e-01,
#                       -1.0767e+00,  2.5362e+00, -3.8060e-02, -5.3267e-01, -5.7712e-02,
#                       -2.4029e-02, -5.6138e-01, -2.6713e-01,  8.5927e-02,  7.4070e-01,
#                       -1.4316e+00,  4.1862e-01,  2.6781e-02,  1.8170e-01, -1.5793e-01,
#                        5.7194e-01,  6.9469e-02,  4.4784e-01, -2.4443e+00,  1.7501e+00,
#                       -3.5894e-01, -2.1669e-01,  1.5223e+00,  2.6148e-01,  5.4221e-02,
#                        2.1674e-01,  4.2723e-02, -7.3608e-02,  2.4240e-01,  5.8861e-01,
#                        2.2567e-01,  1.8280e-01, -3.1659e-01, -3.8064e-01, -4.0849e-02,
#                       -1.2807e-02,  4.1404e-02, -1.3870e+00,  2.8079e-01, -5.3942e-01,
#                       -2.1108e-01,  7.1341e-01, -1.6325e-01, -2.2058e-01,  2.1506e-01,
#                        7.2337e-01,  3.7361e-02,  5.1152e-01,  4.1494e-01,  6.0949e-02,
#                        1.5670e-02, -1.6978e-01, -8.0444e-02,  6.8545e-01, -6.4799e-01,
#                       -4.3812e-01, -7.0343e-01, -3.0485e-01, -7.9497e-01, -1.8479e+00,
#                       -8.3336e-01,  2.3366e-01, -1.2406e-02, -2.7280e-01, -8.5308e-01,
#                        9.6439e-01, -4.3636e-01, -6.8395e-02, -1.6169e-01, -5.1262e-01,
#                       -9.5181e-02, -1.6732e+00, -7.6989e-02, -3.7757e-01,  1.3993e-01,
#                        1.9046e-01,  5.7294e-01, -8.6982e-01, -4.4415e-01,  4.1325e-01,
#                       -2.6757e-01,  2.2436e+00,  5.5901e-01, -9.2627e-01, -3.3460e+00,
#                       -6.6899e-02,  4.0004e-02, -1.0428e+00, -6.3208e-01,  5.8665e-02,
#                        5.2350e-01,  3.9883e-02,  1.1756e-01, -2.8955e-01,  3.6388e-01,
#                        2.8651e-01, -6.8304e-01, -8.5593e-01,  1.0768e-02, -1.1257e-01,
#                       -1.2103e-01, -6.5926e-01,  1.6618e-01,  9.0096e-03, -1.2434e+00,
#                        9.9711e-02,  6.5413e-01, -4.5623e-01,  8.4852e-01, -1.8844e-01,
#                       -1.2765e+00, -5.8315e-01, -5.8546e-01,  1.3928e-01,  2.8544e-01,
#                        1.5217e-01,  4.8522e-01, -6.0183e-01,  1.8481e-01, -4.9689e-01,
#                       -5.8935e-03, -2.4353e+00,  9.9720e-01,  7.3340e-01,  2.9633e-01,
#                        4.1490e-01, -4.1921e-01,  2.8352e-01,  3.9701e-01, -2.6718e-01,
#                        1.0804e+00,  4.3501e-01,  5.3895e-02, -1.9069e-01, -1.4807e+00,
#                        4.3540e-02, -9.0657e-01,  1.5317e-03,  4.4362e-01, -5.9766e-02,
#                       -6.8094e-01,  1.6951e-01, -6.9694e-01, -2.8988e-01,  1.5599e+00,
#                       -2.9914e-01, -4.4443e-01,  4.7647e-01,  5.4596e-01, -4.4031e-01,
#                        4.3686e-01,  2.2413e-01, -6.5422e-01, -5.0078e-02,  1.0315e+00,
#                        1.6745e-01, -3.7763e-01, -2.6220e-01, -6.7942e-01, -2.9397e-01,
#                        2.8053e-01, -3.3203e-01, -1.3618e+00,  1.4592e-01,  8.9562e-01,
#                        1.5926e-01, -6.0961e-01, -7.0801e-03,  1.7245e-01,  1.0367e-01,
#                       -6.6311e-01, -6.9514e-02, -7.3432e-01, -9.6245e-01,  3.0890e-01,
#                       -3.8449e-01, -7.8724e-02,  1.3819e+00, -6.3451e-02, -3.5228e+00,
#                        6.3449e-01,  2.1885e+00, -2.1925e-02,  9.1832e-02,  1.0659e-02,
#                        8.2815e-01,  2.3935e-02, -5.4867e-01, -6.4794e-01, -3.1689e-01,
#                        5.8400e-01,  4.6558e-01,  2.3600e-01, -1.1357e-01,  8.4795e-01,
#                       -2.4270e+00], device='cuda:0')),
#              ('model.layer1.0.bn3.running_mean',
#               tensor([-5.4118e+00,  1.7752e+00,  2.1359e+00,  5.6095e-01,  2.9744e+00,
#                       -1.8668e+00, -3.7583e+00,  5.1446e-01, -6.2221e-01, -1.7695e+00,
#                        2.3214e+00,  1.6096e-01,  1.0970e+01, -1.6965e+00, -6.6377e-01,
#                       -4.4015e+00, -4.0315e+00, -6.8360e-01, -1.9421e+00,  1.7176e-01,
#                       -2.0350e+00,  1.6608e+00, -4.4769e+00,  5.6042e+00, -5.6765e+00,
#                       -2.1774e-01,  1.1505e+00, -1.3801e+00,  1.9130e+00, -1.7538e+00,
#                        4.3877e+00,  1.0295e+00,  9.2574e-01,  8.0764e+00,  1.9811e+00,
#                       -6.1214e+00, -1.4182e+00,  4.2978e+00,  3.5377e+00, -1.2229e+00,
#                       -7.8325e+00,  1.5510e+00,  9.1556e-01,  1.9312e+00, -5.7892e+00,
#                        1.6946e+00,  6.3141e-01,  1.5298e+00, -2.3145e-01, -1.0926e-01,
#                        4.7517e+00, -2.0953e+00, -1.1730e+00,  1.6772e+00, -4.0904e-01,
#                        1.0362e+00,  1.5901e+00, -2.0192e+00,  1.0229e-01,  2.8118e+00,
# ...
#               tensor([-0.4419, -0.5201, -0.3217, -0.6408, -0.3095, -0.5224, -0.3669, -0.2530,
#                       -0.4191, -0.4705, -0.3132, -0.3600, -0.2782, -0.4813, -0.2848, -0.3501,
#                       -0.4628, -0.3426, -0.4374, -0.3400, -0.5783, -0.4092, -0.1803, -0.4063,
#                       -0.5689, -0.4817, -0.3742, -0.3347, -0.3948, -0.7453, -0.3340, -0.5456,
#                       -0.4362, -0.4192, -0.2296, -1.1228, -0.4817, -0.3999, -0.3172, -0.1556,
#                       -0.4376, -0.5378, -0.1208, -0.2318, -0.5323, -0.3049, -0.4014, -0.5131,
#                       -0.4658, -0.5134, -0.5137, -0.4448, -0.6258, -0.3352, -0.7280, -0.3016,
#                       -0.5861, -0.4968, -0.1716, -0.4166, -0.4698, -0.6761, -0.4306,  0.0600,
#                       -0.1876, -0.4961, -0.2009, -0.3838, -0.3519, -0.3656, -0.4079, -0.4051,
#                       -0.5617, -0.1113, -0.5541, -0.4883, -0.5899, -0.4213, -0.4809, -0.3500,
#                       -0.2690, -0.2193, -0.4892, -0.2902, -0.4406, -0.2531, -0.2019, -0.1803,
#                       -0.1716, -0.3151, -0.4443, -0.6743, -0.3651, -0.3699, -0.1507, -0.4856,
#                       -0.5773, -0.5277, -0.2721, -0.2852, -0.4172, -0.4013, -0.4781, -0.4654,
#                       -0.2901, -0.4816, -0.2627, -0.6269, -0.3298, -0.4332, -0.5674, -0.4370,
#                       -0.3819, -0.5254, -0.7391, -0.2805, -0.3043, -0.4053, -0.2212, -0.4832,
#                       -0.6852, -0.4857, -0.4971, -0.6031, -0.3173, -0.3554, -0.5798, -0.4429,
#                       -0.6530, -0.4336, -0.3464, -0.4031, -0.3439, -0.4215, -0.4367, -0.6964,
#                       -0.6390, -0.4380, -0.2137, -0.3391, -0.4006, -0.3337, -0.3228, -0.1792,
#                       -0.4826, -0.1764, -0.2582, -0.3588, -0.4936, -0.5347, -0.3122, -0.2856,
#                       -0.5166, -0.4637, -0.4055, -0.2542, -0.2849, -0.5744, -1.0633, -0.3151,
#                       -0.4617, -0.4704, -0.1958, -0.1941, -0.6314, -0.5403, -0.2531, -0.4430,
#                       -0.1389, -0.3192, -0.3622, -0.1651, -0.3417, -0.4740, -0.5717, -0.4922,
#                       -0.3447, -0.4873, -0.1648, -0.4032, -0.6178, -0.4414, -0.3074, -0.5075,
#                       -0.6849, -0.4459, -0.4524,  0.0819, -0.3432, -0.2636, -0.3537, -0.6452,
#                       -0.2063, -0.5491, -0.4208, -0.2972, -0.2820,  0.7299, -0.2335, -0.4437,
#                       -0.4886, -0.3255, -0.4825, -0.5997, -0.2205, -0.3612, -0.5205, -0.2438,
#                       -1.4355, -0.1690, -0.4433, -0.6218, -0.4163, -0.4217, -0.4773, -0.3872,
#                       -0.4926, -0.5813, -0.2680, -0.2254, -0.6056, -0.4489,  0.3872, -0.3606,
#                       -0.2555, -0.7753, -0.1894, -0.7878, -0.4649, -0.4557, -0.2492, -0.5715,
#                       -0.0656, -0.4441, -0.3466, -0.2259, -0.2401, -0.2402, -0.3444, -0.1371,
#                       -1.1692, -0.4416, -0.5026, -0.1977, -0.2624, -0.4487, -0.4767, -0.4565,
#                       -0.3345, -0.2374, -0.2214, -0.2947, -0.2404, -0.5435, -0.2545, -0.5053,
#                       -0.4883, -0.3103, -0.3405, -0.3059, -0.3641, -0.5342, -0.1775, -0.2600,
#                       -0.3854, -0.2626, -0.3355, -0.4754, -0.3369, -0.5379, -0.5255, -0.2423,
#                       -0.4007, -0.2249, -0.5596, -0.2313, -0.3025, -0.3296, -0.5395, -0.5319,
#                       -0.4095, -0.4128, -0.1765, -0.3427, -0.1070, -0.4061, -0.2900, -0.3240,
#                       -0.4327, -0.6526, -0.5590, -0.3505, -0.1804, -0.4921, -0.3895, -0.3362,
#                       -0.7905, -0.4335, -0.2516, -0.4219, -0.4627, -0.4781, -0.6475, -0.4180,
#                       -0.3410, -0.2902, -0.5347, -0.4160, -0.1718, -2.1461, -0.3723, -0.0792,
#                       -0.5876, -0.4699, -0.3438, -0.5798, -0.3991, -0.5116, -0.5887, -0.3375,
#                       -0.6248, -0.6269, -0.3395, -0.4336, -0.5677, -0.3194, -0.3617, -0.2445,
#                       -0.2140, -0.3950, -0.0710, -0.4189, -0.1717, -0.3314, -0.4327, -0.4556,
#                       -0.4463, -0.5509, -0.2670, -0.2635, -0.4714, -0.3660, -0.3073, -0.4700,
#                       -0.3502, -0.5056, -0.4397, -0.5998, -0.2939, -0.4076, -0.4728, -0.5342,
#                       -0.7331, -0.5458, -0.6171, -0.4059, -0.5750, -0.3518, -0.7600, -1.5536,
#                       -0.5315, -0.3057, -0.2951, -0.3613, -0.1844, -0.4449, -0.5513, -0.3930,
#                       -0.6318, -0.4617, -0.5624, -0.3718, -0.7591, -0.6783, -0.3142, -0.3857,
#                       -0.3429, -0.1712, -0.4476, -0.5051, -0.5394, -0.4253, -0.3023, -0.4670,
#                       -0.5845, -0.3947, -0.6640, -0.5135, -0.3691, -0.4345, -0.1130, -0.4780,
#                       -0.3692, -0.6044, -0.5494, -0.3987, -0.5510, -0.2893, -0.2305, -0.3774,
#                       -0.5036, -0.0783, -0.3970, -0.0918, -0.3962, -0.4954, -0.0426, -0.4255,
#                       -0.4076, -0.3332, -0.5306, -0.3354, -0.0453, -0.3990, -0.3535, -0.5171,
#                       -0.3301, -0.3181, -0.5632, -0.3940, -0.2914, -0.5823, -0.5121, -0.5513,
#                       -0.3356, -0.2115, -0.7203, -0.1115, -0.2064, -0.4544, -0.3321, -0.4322,
#                       -0.4130, -0.2371, -0.7334, -0.4109, -0.6738, -0.3740, -0.2209, -0.6795,
#                       -0.4859, -0.3451, -0.3157, -0.2643, -0.5811, -0.5032,  1.1850, -0.9623,
#                       -0.5959, -0.3337, -0.2833, -0.5678, -0.5086, -0.3610, -0.5232, -0.2430,
#                       -0.4585, -0.5024, -0.5656, -0.4169, -0.5951, -0.3640, -0.6531, -0.5759,
#                       -0.4591, -0.3809, -0.3763, -0.3325, -0.5314, -0.2542, -0.3495, -0.6705,
#                       -0.5366, -0.3477, -0.5786, -0.3830, -0.2548, -0.4580, -0.3820, -0.5043,
#                       -0.4581, -0.3571, -0.2412, -0.3836, -0.4254, -0.5424, -0.5131, -0.4662,
#                       -0.5101, -0.5667, -0.4989, -0.0835, -0.5178, -0.4660, -0.3502, -0.3838,
#                       -0.4210, -0.2561, -0.3929, -0.1897, -0.4639, -0.7769, -0.5705, -0.5589,
#                       -1.1588, -0.2134, -0.4179, -0.4083, -0.2961, -0.2551, -0.2946, -0.2853],
#                      device='cuda:0')),
#              ('model.layer4.2.bn2.running_var',
#               tensor([ 0.1838,  0.2643,  0.5398,  0.2948,  0.2683,  0.7989,  0.3782,  0.2566,
#                        0.3175,  0.2235,  0.2680,  0.3444,  0.1690,  0.4742,  0.1876,  0.4452,
#                        0.2416,  0.2099,  0.6346,  0.4051,  0.2633,  0.2538,  0.4938,  0.2430,
#                        0.4949,  0.2679,  0.2116,  0.3182,  0.4052,  0.5151,  0.4808,  0.2094,
#                        0.4882,  0.2467,  0.2343,  1.1086,  0.2952,  0.2797,  0.4244,  0.4305,
#                        0.2315,  0.2331,  0.4538,  0.3604,  0.2618,  0.3364,  0.3910,  0.3590,
#                        0.2336,  0.1974,  0.2586,  0.2224,  0.6987,  0.2405,  0.2379,  0.2880,
#                        0.2296,  0.1976,  0.3086,  0.4370,  0.2403,  0.3008,  0.3412,  0.3192,
#                        0.2219,  0.4591,  0.3417,  0.2266,  0.2176,  0.1966,  0.2316,  0.2102,
#                        0.2372,  0.2453,  0.2858,  0.5702,  0.1985,  0.2911,  0.2607,  0.3075,
#                        0.4021,  0.2430,  0.7429,  0.4876,  0.2109,  0.2122,  0.4532,  0.5173,
#                        0.2944,  0.2984,  0.2636,  0.3423,  0.2243,  0.3052,  0.3489,  0.2201,
#                        0.2578,  0.3810,  0.6323,  0.2694,  0.2488,  1.6853,  0.3705,  0.4342,
#                        0.3772,  0.2314,  0.2933,  0.3194,  0.2307,  0.4045,  0.2665,  0.1534,
#                        0.3104,  0.2139,  0.2932,  0.2372,  0.2423,  0.4741,  0.4497,  0.2410,
#                        0.3513,  0.2101,  0.2797,  0.2907,  0.4542,  0.2793,  0.2410,  0.2946,
#                        0.4974,  0.1387,  0.2212,  0.1971,  0.1687,  0.3744,  0.4213,  0.6604,
#                        0.6158,  0.3356,  0.2154,  0.3397,  0.4644,  0.2622,  0.1957,  0.5487,
#                        0.2385,  0.7785,  0.4658,  0.3466,  0.2248,  0.2281,  0.1974,  0.5118,
#                        0.2180,  0.2794,  0.2034,  0.3121,  0.3352,  0.2777,  0.6646,  0.2405,
#                        0.2868,  0.2918,  1.1321,  0.2412,  0.2559,  0.2798,  0.3776,  0.5162,
#                        0.2379,  0.2176,  0.2490,  0.2609,  0.2292,  0.1852,  0.2477,  0.2723,
#                        0.2148,  0.2836,  0.3118,  0.2629,  0.3437,  0.3473,  0.1964,  0.2384,
#                        0.3183,  0.2907,  0.2664,  1.5721,  0.2547,  0.2149,  0.2257,  0.2901,
#                        0.4113,  0.1816,  0.4821,  0.3811,  0.2605,  2.7492,  0.4552,  0.2022,
#                        0.2000,  0.2488,  0.2324,  0.2610,  0.3417,  0.2133,  0.2301,  0.4068,
#                        3.0080,  0.4258,  0.1831,  0.3019,  0.1950,  0.3281,  0.4463,  0.2994,
#                        0.2455,  0.2723,  0.3434,  0.2186,  0.2466,  0.2006,  0.7256,  0.2510,
#                        0.2238,  0.2948,  0.3986,  0.2128,  0.2297,  0.2563,  0.5171,  0.2007,
#                        0.5240,  0.3044,  0.2278,  0.7629,  0.1989,  0.8428,  0.5164,  0.3178,
#                        1.1785,  0.2393,  0.1910,  0.2916,  0.2008,  0.3641,  0.4299,  0.2088,
#                        0.1959,  0.2263,  0.4754,  0.2526,  0.8462,  0.2485,  0.2901,  0.2252,
#                        0.2044,  0.5409,  0.4309,  0.1807,  0.5858,  0.2153,  0.7548,  0.3010,
#                        0.4237,  0.2257,  0.2667,  0.4688,  0.8318,  0.1963,  0.2529,  0.2444,
#                        0.2509,  0.6359,  0.3920,  0.5489,  0.3778,  0.4249,  0.3249,  0.2718,
#                        0.3627,  0.4556,  0.5769,  0.2967,  0.6212,  0.1866,  0.5454,  0.4765,
#                        0.2459,  0.4519,  0.4010,  0.2181,  0.2076,  0.2161,  0.2105,  0.2598,
#                        0.4388,  0.4910,  0.2941,  0.2626,  0.3253,  0.2744,  0.2927,  0.2855,
#                        0.2887,  0.2259,  0.3587,  0.3403,  0.5587, 13.4609,  0.3744,  0.1508,
#                        0.3129,  0.2657,  0.4874,  1.0635,  0.2457,  0.3324,  0.2561,  1.0520,
#                        0.2840,  0.2650,  0.3811,  0.2599,  0.3273,  0.1598,  0.2271,  0.3003,
#                        1.3189,  0.3369,  0.2633,  0.1607,  0.4456,  0.3170,  0.2703,  0.2763,
#                        0.3594,  0.2321,  0.2625,  0.3380,  0.4249,  0.3138,  0.3325,  0.2721,
#                        0.2164,  0.2272,  0.5691,  0.2353,  0.2293,  0.2272,  0.2033,  0.3781,
#                        0.2644,  0.2155,  0.2841,  0.2214,  0.2700,  0.2215,  0.6345,  0.9346,
#                        0.2209,  0.4507,  0.2992,  0.4534,  0.2759,  0.2405,  0.2534,  0.2986,
#                        0.2474,  0.1684,  0.2798,  0.4532,  0.3316,  0.4064,  0.1949,  0.2509,
#                        0.2441,  0.5877,  0.3340,  0.2120,  0.3746,  0.1577,  0.2850,  0.4815,
#                        0.2187,  0.2464,  0.2410,  0.2550,  0.3368,  0.3186,  0.5387,  0.3312,
#                        0.2377,  0.2291,  0.2545,  0.4090,  0.2618,  0.3316,  0.4202,  0.2352,
#                        0.4423,  0.3048,  0.3933,  0.4376,  0.3349,  0.3759,  1.2694,  0.3380,
#                        0.2705,  0.4473,  0.2115,  0.5254,  0.4131,  0.4648,  0.1776,  0.3628,
#                        0.1759,  0.2348,  0.2765,  0.2447,  0.2559,  0.2292,  0.2637,  0.2092,
#                        0.1998,  0.2824,  0.2623,  0.4942,  0.5010,  0.2054,  0.1686,  0.2795,
#                        0.3632,  0.3642,  0.3639,  0.2554,  0.2533,  0.5849,  0.2199,  0.3492,
#                        0.2348,  0.2839,  0.2154,  0.2127,  0.2025,  0.2367,  0.5625,  1.5832,
#                        0.2069,  0.4346,  0.4076,  0.2216,  0.2755,  0.2138,  0.2263,  0.2204,
#                        0.6116,  0.2880,  0.3071,  0.2856,  0.2043,  0.2532,  0.2698,  0.2682,
#                        0.6070,  0.5779,  0.3727,  0.2736,  0.3569,  0.1897,  0.2537,  0.3107,
#                        0.4632,  0.3652,  0.2127,  0.2057,  0.1841,  0.2301,  0.3829,  0.2578,
#                        0.2097,  0.2680,  0.5308,  0.2573,  0.1952,  0.2295,  0.2327,  0.3789,
#                        0.5703,  0.3044,  0.2885,  0.2954,  0.2549,  0.4203,  0.2634,  0.1931,
#                        0.7305,  0.2513,  0.2653,  1.2844,  0.2204,  0.2389,  0.4724,  0.2105,
#                        0.6323,  0.3382,  0.4091,  0.2055,  0.2572,  0.3051,  0.2915,  0.2072],
#                      device='cuda:0')),
#              ('model.layer4.2.bn2.num_batches_tracked',
#               tensor(678545, device='cuda:0')),
#              ('model.layer4.2.conv3.weight',
#               tensor([[[[-0.0284]],
#
#                        [[-0.0099]],
#
#                        [[-0.0002]],
#
#                        ...,
#
#                        [[-0.0283]],
#
#                        [[ 0.0080]],
#
#                        [[ 0.0054]]],
#
#
#                       [[[ 0.0303]],
#
#                        [[ 0.0102]],
#
#                        [[ 0.0264]],
#
#                        ...,
#
#                        [[-0.0151]],
#
#                        [[ 0.0057]],
#
#                        [[ 0.0129]]],
#
#
#                       [[[-0.0216]],
#
#                        [[-0.0119]],
#
#                        [[ 0.0115]],
#
#                        ...,
#
#                        [[-0.0429]],
#
#                        [[-0.0080]],
#
#                        [[ 0.0300]]],
#
#
#                       ...,
#
#
#                       [[[-0.0450]],
#
#                        [[-0.0485]],
#
#                        [[ 0.0071]],
#
#                        ...,
#
#                        [[-0.0243]],
#
#                        [[ 0.0038]],
#
#                        [[ 0.0124]]],
#
#
#                       [[[ 0.0007]],
#
#                        [[ 0.0268]],
#
#                        [[ 0.0668]],
#
#                        ...,
#
#                        [[-0.0050]],
#
#                        [[ 0.0193]],
#
#                        [[-0.0932]]],
#
#
#                       [[[ 0.0138]],
#
#                        [[ 0.0012]],
#
#                        [[ 0.0188]],
#
#                        ...,
#
#                        [[-0.0324]],
#
#                        [[-0.0358]],
#
#                        [[-0.0401]]]], device='cuda:0')),
#              ('model.layer4.2.bn3.weight',
#               tensor([1.8266, 2.7907, 2.2187,  ..., 2.0884, 3.0293, 2.8027], device='cuda:0')),
#              ('model.layer4.2.bn3.bias',
#               tensor([-2.9957, -4.1531, -3.2789,  ..., -3.1428, -4.7102, -4.3754],
#                      device='cuda:0')),
#              ('model.layer4.2.bn3.running_mean',
#               tensor([-0.4160, -0.1746, -0.3492,  ..., -0.3222, -0.5908, -0.3451],
#                      device='cuda:0')),
#              ('model.layer4.2.bn3.running_var',
#               tensor([0.1033, 0.1639, 0.1722,  ..., 0.1502, 0.2515, 0.1556], device='cuda:0')),
#              ('model.layer4.2.bn3.num_batches_tracked',
#               tensor(678545, device='cuda:0')),
#              ('model.fc.weight',
#               tensor([[ 0.1172,  0.1196,  0.1138,  ...,  0.0566,  0.0387,  0.0521],
#                       [-0.0642,  0.2547,  0.1235,  ..., -0.0772, -0.0368,  0.2440],
#                       [-0.0913, -0.1336, -0.1126,  ..., -0.1825, -0.0269,  0.0409],
#                       [ 0.0789, -0.1560, -0.0857,  ..., -0.0356, -0.0495, -0.0474],
#                       [ 0.0246, -0.0392,  0.0684,  ..., -0.2361, -0.0803, -0.0851],
#                       [-0.1122, -0.1058, -0.1238,  ...,  0.1495,  0.1669, -0.1752]],
#                      device='cuda:0')),
#              ('model.fc.bias',
#               tensor([ 0.0746,  0.0871,  0.0414, -0.0407,  0.0172, -0.2287], device='cuda:0'))])

# %%
torch.save(model.state_dict(), 'weights.pt')

# %%
class Model(nn.Module):
    def __init__(self):
        super().__init__()

        self.fc_1 = nn.Linear(32, 1)
        self.fc_2 = nn.Linear(33, 2)

    def forward(self, x):
        out = self.fc_1(x)
        out = self.fc_2(out)
        return out

model = Model()

# %%
model.load_state_dict(torch.load('weights.pt'))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-75-22a84179d060> in <cell line: 1>()
# ----> 1 model.load_state_dict(torch.load('weights.pt'))
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in load_state_dict(self, state_dict, strict, assign)
#    2187
#    2188         if len(error_msgs) > 0:
# -> 2189             raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
#    2190                                self.__class__.__name__, "\n\t".join(error_msgs)))
#    2191         return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for Model:
# 	size mismatch for fc_1.weight: copying a param with shape torch.Size([1, 33]) from checkpoint, the shape in current model is torch.Size([1, 32]).

# %%
model.state_dict()
# Out:
# OrderedDict([('fc_1.weight',
#               tensor([[ 0.0227,  0.1136, -0.0866,  0.0430,  0.0083, -0.1334,  0.1403,  0.1227,
#                        -0.0929,  0.0042, -0.1311,  0.0808, -0.0992, -0.1009, -0.0477, -0.0237,
#                        -0.0250,  0.1005, -0.0146, -0.1253, -0.0449,  0.1402,  0.0257,  0.0096,
#                        -0.1062, -0.0928,  0.0714, -0.1473,  0.1518,  0.1081,  0.1480,  0.1619,
#                        -0.1129]])),
#              ('fc_1.bias', tensor([0.0803])),
#              ('fc_2.weight',
#               tensor([[-0.1323,  0.0147, -0.0850, -0.0103, -0.0205,  0.1216, -0.1073,  0.1660,
#                        -0.1730,  0.0032,  0.1019,  0.1479, -0.0664,  0.1189,  0.0306,  0.1615,
#                         0.1403,  0.0437,  0.1213,  0.1699,  0.0656,  0.0407, -0.1497,  0.0773,
#                         0.1435, -0.1050, -0.0976, -0.1487,  0.0012, -0.0013, -0.0105,  0.0534,
#                        -0.1547],
#                       [-0.1573, -0.0901,  0.1206, -0.0951, -0.0844,  0.0143,  0.0062, -0.0606,
#                         0.0521, -0.0967, -0.0705, -0.1008,  0.0095,  0.0229,  0.0944, -0.1360,
#                        -0.0889,  0.1210, -0.0054, -0.1174,  0.0611,  0.1257,  0.0279,  0.0314,
#                         0.1550,  0.0701,  0.1338, -0.0329, -0.0778,  0.1179, -0.1527, -0.1372,
#                         0.1584]])),
#              ('fc_2.bias', tensor([0.1554, 0.0092]))])

# %%
def preprocess_model():
    mob_model = mobilenet_v3_small()
    mob_model.classifier[3] = nn.Linear(1024, 1)
    mob_model.load_state_dict(...)
    mob_model.eval()
    return mob_model

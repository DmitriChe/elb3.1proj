# %%
import torch
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision import transforms as T
from torch.nn import functional as F
import torchvision

import numpy as np
import torchutils as tu

import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('https://github.com/dhaitz/matplotlib-stylesheets/raw/master/pitayasmoothie-dark.mplstyle')

# %%
# !kaggle datasets download -d fanconic/skin-cancer-malignant-vs-benign
# Out:
# Dataset URL: https://www.kaggle.com/datasets/fanconic/skin-cancer-malignant-vs-benign
# License(s): unknown
# skin-cancer-malignant-vs-benign.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !unzip skin-cancer-malignant-vs-benign.zip
# Out:
# Archive:  skin-cancer-malignant-vs-benign.zip
# replace data/test/benign/1.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: ^C

# %%
trnsfrms = T.Compose(
    [
        T.Resize((224, 224)),
        T.ToTensor(),
        T.RandomResizedCrop(224, scale=(0.8, 1.0)),
        T.RandomHorizontalFlip(),
        T.RandomVerticalFlip(),
        T.RandomRotation(degrees=30),
        T.RandomAffine(degrees=0, translate=(0.1, 0.1), scale=(0.9, 1.1)),
        T.RandomErasing(p=0.5, scale=(0.02, 0.2), ratio=(0.3, 3.3)),
    ]
)

# %%
train_dataset = torchvision.datasets.ImageFolder(
    'train',
    transform=trnsfrms
)
valid_dataset = torchvision.datasets.ImageFolder(
    'test',
    transform=T.Compose(
    [
        T.Resize((224, 224)),
        T.ToTensor(),]
))

# %%
DEVICE = 'cuda'
BATCH_SIZE = 512
fake_batch = torch.randn(4, 3, 224, 224, device=DEVICE)

# %%
from torchvision.models import resnet152, ResNet152_Weights

# %%
class MyResNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.model = resnet152(weights=ResNet152_Weights.DEFAULT)
        self.model.fc = nn.Linear(2048, 1)
        for i in self.model.parameters():
            i.requires_grad = False
        self.model.fc.weight.requires_grad = True
        self.model.fc.bias.requires_grad = True

    def forward(self, x):
        x = self.model(x)
        return torch.sigmoid(x)

# %%
idx2class= {j: i for i, j in train_dataset.class_to_idx.items()}

# %%
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=BATCH_SIZE, shuffle=True)

# %%
model = MyResNet()

# %%
model.to(DEVICE)
criterion = nn.BCELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
def plot_history(history, grid=True):
    fig, ax = plt.subplots(1,2, figsize=(14,5))
    
    ax[0].plot(history['train_losses'], label='train loss')
    ax[0].plot(history['valid_losses'], label='valid loss')
    ax[0].set_title(f'Loss on epoch {len(history["train_losses"])}')
    ax[0].grid(grid)
    ax[0].legend()
    
    ax[1].plot(history['train_accs'], label='train acc')
    ax[1].plot(history['valid_accs'], label='valid acc')
    ax[1].set_title(f'Accuracy on epoch {len(history["train_losses"])}')
    ax[1].grid(grid)
    ax[1].legend()
    
    plt.show()

# %%
def fit_model(
        model: nn.Module, 
        epochs: int, 
        optimizer: torch.optim.Optimizer, 
        history = None
        ) -> dict:
    '''
    model: pytorch model - model to train
    epochs: int          - number of epochs
    plot_every: int      - plot every N iterations
    '''
    
    # будем сохранять значения точности и лосса в history
    history = history or {
        'train_accs': [],
        'train_losses': [],
        'valid_accs': [],
        'valid_losses': [],
    }

    # определяем текущую эпоху обучения
    start_epoch = len(history['train_accs'])
    for epoch in range(start_epoch+1, start_epoch+epochs+1):
        print(f'{"-"*13} Epoch {epoch} {"-"*13}')

        model.train()
        batch_accs = []
        batch_losses = [] 
        for samples, labels in train_loader: 
            
            samples = samples.to(DEVICE)
            labels = labels.view(-1, 1).float().to(DEVICE)
            
            y_pred = model(samples)
            
            # Считаем лосс: передаем в функцию потерь предсказания и 
            # настоящие метки классов
            # иногда надо переводить между long() и float(), 
            # об этом pytorch предупредит

            loss = criterion(y_pred, labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            batch_losses.append(loss.item())
            # print(f'Predictions: {y_pred}')
            # сравниваем предсказания с таргетом и добавляем в 
            # список значение точности
            # BATCH_SIZE x N_CLASSES = 64 X 10 -> argmax -> 64 x 1

            batch_accs.append((y_pred.round() == labels).cpu().numpy().mean())

        history['train_losses'].append(np.mean(batch_losses))
        history['train_accs'].append(np.mean(batch_accs))

        # Validation
        model.eval()
    
        batch_accs = []
        batch_losses = []
        for samples, labels in valid_loader:
            with torch.no_grad():
                y_pred = model(samples.to(DEVICE))
            labels = labels.view(-1, 1).float().to(DEVICE)
            loss = criterion(y_pred, labels.to(DEVICE))
            batch_losses.append(loss.item())
            batch_accs.append((y_pred.round() == labels).cpu().numpy().mean())
        history['valid_accs'].append(np.mean(batch_accs))
        history['valid_losses'].append(np.mean(batch_losses))
        
        
        # печатаем результат
        
        print(
            f'train: accuracy {history["train_accs"][-1]:.4f}, loss {history["train_losses"][-1]:.4f}\n'
            f'valid: accuracy {history["valid_accs"][-1]:.4f}, loss {history["valid_losses"][-1]:.4f}'
        )
        print(f'{"-"*35}')
        print()
    
    # печатаем графики
    plot_history(history)

    return history

# %%
tu.get_model_summary(model, fake_batch)
torch.cuda.empty_cache()
# Out:
# ==============================================================================================================
# Layer                                               Kernel              Output          Params           FLOPs
# ==============================================================================================================
# 0_model.Conv2d_conv1                               [3, 64, 7, 7]   [4, 64, 112, 112]       9,408   472,055,808
# 1_model.BatchNorm2d_bn1                                     [64]   [4, 64, 112, 112]         128    12,845,056
# 2_model.ReLU_relu                                              -   [4, 64, 112, 112]           0             0
# 3_model.MaxPool2d_maxpool                                      -     [4, 64, 56, 56]           0             0
# 4_model.layer1.0.Conv2d_conv1                     [64, 64, 1, 1]     [4, 64, 56, 56]       4,096    51,380,224
# 5_model.layer1.0.BatchNorm2d_bn1                            [64]     [4, 64, 56, 56]         128     3,211,264
# 6_model.layer1.0.ReLU_relu                                     -     [4, 64, 56, 56]           0             0
# 7_model.layer1.0.Conv2d_conv2                     [64, 64, 3, 3]     [4, 64, 56, 56]      36,864   462,422,016
# 8_model.layer1.0.BatchNorm2d_bn2                            [64]     [4, 64, 56, 56]         128     3,211,264
# 9_model.layer1.0.ReLU_relu                                     -     [4, 64, 56, 56]           0             0
# 10_model.layer1.0.Conv2d_conv3                   [64, 256, 1, 1]    [4, 256, 56, 56]      16,384   205,520,896
# 11_model.layer1.0.BatchNorm2d_bn3                          [256]    [4, 256, 56, 56]         512    12,845,056
# 12_model.layer1.0.downsample.Conv2d_0            [64, 256, 1, 1]    [4, 256, 56, 56]      16,384   205,520,896
# 13_model.layer1.0.downsample.BatchNorm2d_1                 [256]    [4, 256, 56, 56]         512    12,845,056
# 14_model.layer1.0.ReLU_relu                                    -    [4, 256, 56, 56]           0             0
# 15_model.layer1.1.Conv2d_conv1                   [256, 64, 1, 1]     [4, 64, 56, 56]      16,384   205,520,896
# 16_model.layer1.1.BatchNorm2d_bn1                           [64]     [4, 64, 56, 56]         128     3,211,264
# 17_model.layer1.1.ReLU_relu                                    -     [4, 64, 56, 56]           0             0
# 18_model.layer1.1.Conv2d_conv2                    [64, 64, 3, 3]     [4, 64, 56, 56]      36,864   462,422,016
# 19_model.layer1.1.BatchNorm2d_bn2                           [64]     [4, 64, 56, 56]         128     3,211,264
# 20_model.layer1.1.ReLU_relu                                    -     [4, 64, 56, 56]           0             0
# 21_model.layer1.1.Conv2d_conv3                   [64, 256, 1, 1]    [4, 256, 56, 56]      16,384   205,520,896
# 22_model.layer1.1.BatchNorm2d_bn3                          [256]    [4, 256, 56, 56]         512    12,845,056
# 23_model.layer1.1.ReLU_relu                                    -    [4, 256, 56, 56]           0             0
# 24_model.layer1.2.Conv2d_conv1                   [256, 64, 1, 1]     [4, 64, 56, 56]      16,384   205,520,896
# 25_model.layer1.2.BatchNorm2d_bn1                           [64]     [4, 64, 56, 56]         128     3,211,264
# 26_model.layer1.2.ReLU_relu                                    -     [4, 64, 56, 56]           0             0
# 27_model.layer1.2.Conv2d_conv2                    [64, 64, 3, 3]     [4, 64, 56, 56]      36,864   462,422,016
# 28_model.layer1.2.BatchNorm2d_bn2                           [64]     [4, 64, 56, 56]         128     3,211,264
# 29_model.layer1.2.ReLU_relu                                    -     [4, 64, 56, 56]           0             0
# 30_model.layer1.2.Conv2d_conv3                   [64, 256, 1, 1]    [4, 256, 56, 56]      16,384   205,520,896
# 31_model.layer1.2.BatchNorm2d_bn3                          [256]    [4, 256, 56, 56]         512    12,845,056
# 32_model.layer1.2.ReLU_relu                                    -    [4, 256, 56, 56]           0             0
# 33_model.layer2.0.Conv2d_conv1                  [256, 128, 1, 1]    [4, 128, 56, 56]      32,768   411,041,792
# 34_model.layer2.0.BatchNorm2d_bn1                          [128]    [4, 128, 56, 56]         256     6,422,528
# 35_model.layer2.0.ReLU_relu                                    -    [4, 128, 56, 56]           0             0
# 36_model.layer2.0.Conv2d_conv2                  [128, 128, 3, 3]    [4, 128, 28, 28]     147,456   462,422,016
# 37_model.layer2.0.BatchNorm2d_bn2                          [128]    [4, 128, 28, 28]         256     1,605,632
# 38_model.layer2.0.ReLU_relu                                    -    [4, 128, 28, 28]           0             0
# 39_model.layer2.0.Conv2d_conv3                  [128, 512, 1, 1]    [4, 512, 28, 28]      65,536   205,520,896
# 40_model.layer2.0.BatchNorm2d_bn3                          [512]    [4, 512, 28, 28]       1,024     6,422,528
# 41_model.layer2.0.downsample.Conv2d_0           [256, 512, 1, 1]    [4, 512, 28, 28]     131,072   411,041,792
# 42_model.layer2.0.downsample.BatchNorm2d_1                 [512]    [4, 512, 28, 28]       1,024     6,422,528
# 43_model.layer2.0.ReLU_relu                                    -    [4, 512, 28, 28]           0             0
# 44_model.layer2.1.Conv2d_conv1                  [512, 128, 1, 1]    [4, 128, 28, 28]      65,536   205,520,896
# 45_model.layer2.1.BatchNorm2d_bn1                          [128]    [4, 128, 28, 28]         256     1,605,632
# 46_model.layer2.1.ReLU_relu                                    -    [4, 128, 28, 28]           0             0
# 47_model.layer2.1.Conv2d_conv2                  [128, 128, 3, 3]    [4, 128, 28, 28]     147,456   462,422,016
# 48_model.layer2.1.BatchNorm2d_bn2                          [128]    [4, 128, 28, 28]         256     1,605,632
# 49_model.layer2.1.ReLU_relu                                    -    [4, 128, 28, 28]           0             0
# 50_model.layer2.1.Conv2d_conv3                  [128, 512, 1, 1]    [4, 512, 28, 28]      65,536   205,520,896
# 51_model.layer2.1.BatchNorm2d_bn3                          [512]    [4, 512, 28, 28]       1,024     6,422,528
# 52_model.layer2.1.ReLU_relu                                    -    [4, 512, 28, 28]           0             0
# 53_model.layer2.2.Conv2d_conv1                  [512, 128, 1, 1]    [4, 128, 28, 28]      65,536   205,520,896
# 54_model.layer2.2.BatchNorm2d_bn1                          [128]    [4, 128, 28, 28]         256     1,605,632
# 55_model.layer2.2.ReLU_relu                                    -    [4, 128, 28, 28]           0             0
# 56_model.layer2.2.Conv2d_conv2                  [128, 128, 3, 3]    [4, 128, 28, 28]     147,456   462,422,016
# 57_model.layer2.2.BatchNorm2d_bn2                          [128]    [4, 128, 28, 28]         256     1,605,632
# 58_model.layer2.2.ReLU_relu                                    -    [4, 128, 28, 28]           0             0
# 59_model.layer2.2.Conv2d_conv3                  [128, 512, 1, 1]    [4, 512, 28, 28]      65,536   205,520,896
# 60_model.layer2.2.BatchNorm2d_bn3                          [512]    [4, 512, 28, 28]       1,024     6,422,528
# 61_model.layer2.2.ReLU_relu                                    -    [4, 512, 28, 28]           0             0
# 62_model.layer2.3.Conv2d_conv1                  [512, 128, 1, 1]    [4, 128, 28, 28]      65,536   205,520,896
# 63_model.layer2.3.BatchNorm2d_bn1                          [128]    [4, 128, 28, 28]         256     1,605,632
# 64_model.layer2.3.ReLU_relu                                    -    [4, 128, 28, 28]           0             0
# 65_model.layer2.3.Conv2d_conv2                  [128, 128, 3, 3]    [4, 128, 28, 28]     147,456   462,422,016
# 66_model.layer2.3.BatchNorm2d_bn2                          [128]    [4, 128, 28, 28]         256     1,605,632
# 67_model.layer2.3.ReLU_relu                                    -    [4, 128, 28, 28]           0             0
# 68_model.layer2.3.Conv2d_conv3                  [128, 512, 1, 1]    [4, 512, 28, 28]      65,536   205,520,896
# 69_model.layer2.3.BatchNorm2d_bn3                          [512]    [4, 512, 28, 28]       1,024     6,422,528
# 70_model.layer2.3.ReLU_relu                                    -    [4, 512, 28, 28]           0             0
# 71_model.layer2.4.Conv2d_conv1                  [512, 128, 1, 1]    [4, 128, 28, 28]      65,536   205,520,896
# 72_model.layer2.4.BatchNorm2d_bn1                          [128]    [4, 128, 28, 28]         256     1,605,632
# 73_model.layer2.4.ReLU_relu                                    -    [4, 128, 28, 28]           0             0
# 74_model.layer2.4.Conv2d_conv2                  [128, 128, 3, 3]    [4, 128, 28, 28]     147,456   462,422,016
# 75_model.layer2.4.BatchNorm2d_bn2                          [128]    [4, 128, 28, 28]         256     1,605,632
# 76_model.layer2.4.ReLU_relu                                    -    [4, 128, 28, 28]           0             0
# 77_model.layer2.4.Conv2d_conv3                  [128, 512, 1, 1]    [4, 512, 28, 28]      65,536   205,520,896
# 78_model.layer2.4.BatchNorm2d_bn3                          [512]    [4, 512, 28, 28]       1,024     6,422,528
# 79_model.layer2.4.ReLU_relu                                    -    [4, 512, 28, 28]           0             0
# 80_model.layer2.5.Conv2d_conv1                  [512, 128, 1, 1]    [4, 128, 28, 28]      65,536   205,520,896
# 81_model.layer2.5.BatchNorm2d_bn1                          [128]    [4, 128, 28, 28]         256     1,605,632
# 82_model.layer2.5.ReLU_relu                                    -    [4, 128, 28, 28]           0             0
# 83_model.layer2.5.Conv2d_conv2                  [128, 128, 3, 3]    [4, 128, 28, 28]     147,456   462,422,016
# 84_model.layer2.5.BatchNorm2d_bn2                          [128]    [4, 128, 28, 28]         256     1,605,632
# 85_model.layer2.5.ReLU_relu                                    -    [4, 128, 28, 28]           0             0
# 86_model.layer2.5.Conv2d_conv3                  [128, 512, 1, 1]    [4, 512, 28, 28]      65,536   205,520,896
# 87_model.layer2.5.BatchNorm2d_bn3                          [512]    [4, 512, 28, 28]       1,024     6,422,528
# 88_model.layer2.5.ReLU_relu                                    -    [4, 512, 28, 28]           0             0
# 89_model.layer2.6.Conv2d_conv1                  [512, 128, 1, 1]    [4, 128, 28, 28]      65,536   205,520,896
# 90_model.layer2.6.BatchNorm2d_bn1                          [128]    [4, 128, 28, 28]         256     1,605,632
# 91_model.layer2.6.ReLU_relu                                    -    [4, 128, 28, 28]           0             0
# 92_model.layer2.6.Conv2d_conv2                  [128, 128, 3, 3]    [4, 128, 28, 28]     147,456   462,422,016
# 93_model.layer2.6.BatchNorm2d_bn2                          [128]    [4, 128, 28, 28]         256     1,605,632
# 94_model.layer2.6.ReLU_relu                                    -    [4, 128, 28, 28]           0             0
# 95_model.layer2.6.Conv2d_conv3                  [128, 512, 1, 1]    [4, 512, 28, 28]      65,536   205,520,896
# 96_model.layer2.6.BatchNorm2d_bn3                          [512]    [4, 512, 28, 28]       1,024     6,422,528
# 97_model.layer2.6.ReLU_relu                                    -    [4, 512, 28, 28]           0             0
# 98_model.layer2.7.Conv2d_conv1                  [512, 128, 1, 1]    [4, 128, 28, 28]      65,536   205,520,896
# 99_model.layer2.7.BatchNorm2d_bn1                          [128]    [4, 128, 28, 28]         256     1,605,632
# 100_model.layer2.7.ReLU_relu                                   -    [4, 128, 28, 28]           0             0
# 101_model.layer2.7.Conv2d_conv2                 [128, 128, 3, 3]    [4, 128, 28, 28]     147,456   462,422,016
# 102_model.layer2.7.BatchNorm2d_bn2                         [128]    [4, 128, 28, 28]         256     1,605,632
# 103_model.layer2.7.ReLU_relu                                   -    [4, 128, 28, 28]           0             0
# 104_model.layer2.7.Conv2d_conv3                 [128, 512, 1, 1]    [4, 512, 28, 28]      65,536   205,520,896
# 105_model.layer2.7.BatchNorm2d_bn3                         [512]    [4, 512, 28, 28]       1,024     6,422,528
# 106_model.layer2.7.ReLU_relu                                   -    [4, 512, 28, 28]           0             0
# 107_model.layer3.0.Conv2d_conv1                 [512, 256, 1, 1]    [4, 256, 28, 28]     131,072   411,041,792
# 108_model.layer3.0.BatchNorm2d_bn1                         [256]    [4, 256, 28, 28]         512     3,211,264
# 109_model.layer3.0.ReLU_relu                                   -    [4, 256, 28, 28]           0             0
# 110_model.layer3.0.Conv2d_conv2                 [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 111_model.layer3.0.BatchNorm2d_bn2                         [256]    [4, 256, 14, 14]         512       802,816
# 112_model.layer3.0.ReLU_relu                                   -    [4, 256, 14, 14]           0             0
# 113_model.layer3.0.Conv2d_conv3                [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 114_model.layer3.0.BatchNorm2d_bn3                        [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 115_model.layer3.0.downsample.Conv2d_0         [512, 1024, 1, 1]   [4, 1024, 14, 14]     524,288   411,041,792
# 116_model.layer3.0.downsample.BatchNorm2d_1               [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 117_model.layer3.0.ReLU_relu                                   -   [4, 1024, 14, 14]           0             0
# 118_model.layer3.1.Conv2d_conv1                [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 119_model.layer3.1.BatchNorm2d_bn1                         [256]    [4, 256, 14, 14]         512       802,816
# 120_model.layer3.1.ReLU_relu                                   -    [4, 256, 14, 14]           0             0
# 121_model.layer3.1.Conv2d_conv2                 [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 122_model.layer3.1.BatchNorm2d_bn2                         [256]    [4, 256, 14, 14]         512       802,816
# 123_model.layer3.1.ReLU_relu                                   -    [4, 256, 14, 14]           0             0
# 124_model.layer3.1.Conv2d_conv3                [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 125_model.layer3.1.BatchNorm2d_bn3                        [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 126_model.layer3.1.ReLU_relu                                   -   [4, 1024, 14, 14]           0             0
# 127_model.layer3.2.Conv2d_conv1                [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 128_model.layer3.2.BatchNorm2d_bn1                         [256]    [4, 256, 14, 14]         512       802,816
# 129_model.layer3.2.ReLU_relu                                   -    [4, 256, 14, 14]           0             0
# 130_model.layer3.2.Conv2d_conv2                 [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 131_model.layer3.2.BatchNorm2d_bn2                         [256]    [4, 256, 14, 14]         512       802,816
# 132_model.layer3.2.ReLU_relu                                   -    [4, 256, 14, 14]           0             0
# 133_model.layer3.2.Conv2d_conv3                [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 134_model.layer3.2.BatchNorm2d_bn3                        [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 135_model.layer3.2.ReLU_relu                                   -   [4, 1024, 14, 14]           0             0
# 136_model.layer3.3.Conv2d_conv1                [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 137_model.layer3.3.BatchNorm2d_bn1                         [256]    [4, 256, 14, 14]         512       802,816
# 138_model.layer3.3.ReLU_relu                                   -    [4, 256, 14, 14]           0             0
# 139_model.layer3.3.Conv2d_conv2                 [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 140_model.layer3.3.BatchNorm2d_bn2                         [256]    [4, 256, 14, 14]         512       802,816
# 141_model.layer3.3.ReLU_relu                                   -    [4, 256, 14, 14]           0             0
# 142_model.layer3.3.Conv2d_conv3                [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 143_model.layer3.3.BatchNorm2d_bn3                        [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 144_model.layer3.3.ReLU_relu                                   -   [4, 1024, 14, 14]           0             0
# 145_model.layer3.4.Conv2d_conv1                [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 146_model.layer3.4.BatchNorm2d_bn1                         [256]    [4, 256, 14, 14]         512       802,816
# 147_model.layer3.4.ReLU_relu                                   -    [4, 256, 14, 14]           0             0
# 148_model.layer3.4.Conv2d_conv2                 [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 149_model.layer3.4.BatchNorm2d_bn2                         [256]    [4, 256, 14, 14]         512       802,816
# 150_model.layer3.4.ReLU_relu                                   -    [4, 256, 14, 14]           0             0
# 151_model.layer3.4.Conv2d_conv3                [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 152_model.layer3.4.BatchNorm2d_bn3                        [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 153_model.layer3.4.ReLU_relu                                   -   [4, 1024, 14, 14]           0             0
# 154_model.layer3.5.Conv2d_conv1                [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 155_model.layer3.5.BatchNorm2d_bn1                         [256]    [4, 256, 14, 14]         512       802,816
# 156_model.layer3.5.ReLU_relu                                   -    [4, 256, 14, 14]           0             0
# 157_model.layer3.5.Conv2d_conv2                 [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 158_model.layer3.5.BatchNorm2d_bn2                         [256]    [4, 256, 14, 14]         512       802,816
# 159_model.layer3.5.ReLU_relu                                   -    [4, 256, 14, 14]           0             0
# 160_model.layer3.5.Conv2d_conv3                [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 161_model.layer3.5.BatchNorm2d_bn3                        [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 162_model.layer3.5.ReLU_relu                                   -   [4, 1024, 14, 14]           0             0
# 163_model.layer3.6.Conv2d_conv1                [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 164_model.layer3.6.BatchNorm2d_bn1                         [256]    [4, 256, 14, 14]         512       802,816
# 165_model.layer3.6.ReLU_relu                                   -    [4, 256, 14, 14]           0             0
# 166_model.layer3.6.Conv2d_conv2                 [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 167_model.layer3.6.BatchNorm2d_bn2                         [256]    [4, 256, 14, 14]         512       802,816
# 168_model.layer3.6.ReLU_relu                                   -    [4, 256, 14, 14]           0             0
# 169_model.layer3.6.Conv2d_conv3                [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 170_model.layer3.6.BatchNorm2d_bn3                        [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 171_model.layer3.6.ReLU_relu                                   -   [4, 1024, 14, 14]           0             0
# 172_model.layer3.7.Conv2d_conv1                [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 173_model.layer3.7.BatchNorm2d_bn1                         [256]    [4, 256, 14, 14]         512       802,816
# 174_model.layer3.7.ReLU_relu                                   -    [4, 256, 14, 14]           0             0
# 175_model.layer3.7.Conv2d_conv2                 [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 176_model.layer3.7.BatchNorm2d_bn2                         [256]    [4, 256, 14, 14]         512       802,816
# 177_model.layer3.7.ReLU_relu                                   -    [4, 256, 14, 14]           0             0
# 178_model.layer3.7.Conv2d_conv3                [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 179_model.layer3.7.BatchNorm2d_bn3                        [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 180_model.layer3.7.ReLU_relu                                   -   [4, 1024, 14, 14]           0             0
# 181_model.layer3.8.Conv2d_conv1                [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 182_model.layer3.8.BatchNorm2d_bn1                         [256]    [4, 256, 14, 14]         512       802,816
# 183_model.layer3.8.ReLU_relu                                   -    [4, 256, 14, 14]           0             0
# 184_model.layer3.8.Conv2d_conv2                 [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 185_model.layer3.8.BatchNorm2d_bn2                         [256]    [4, 256, 14, 14]         512       802,816
# 186_model.layer3.8.ReLU_relu                                   -    [4, 256, 14, 14]           0             0
# 187_model.layer3.8.Conv2d_conv3                [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 188_model.layer3.8.BatchNorm2d_bn3                        [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 189_model.layer3.8.ReLU_relu                                   -   [4, 1024, 14, 14]           0             0
# 190_model.layer3.9.Conv2d_conv1                [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 191_model.layer3.9.BatchNorm2d_bn1                         [256]    [4, 256, 14, 14]         512       802,816
# 192_model.layer3.9.ReLU_relu                                   -    [4, 256, 14, 14]           0             0
# 193_model.layer3.9.Conv2d_conv2                 [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 194_model.layer3.9.BatchNorm2d_bn2                         [256]    [4, 256, 14, 14]         512       802,816
# 195_model.layer3.9.ReLU_relu                                   -    [4, 256, 14, 14]           0             0
# 196_model.layer3.9.Conv2d_conv3                [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 197_model.layer3.9.BatchNorm2d_bn3                        [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 198_model.layer3.9.ReLU_relu                                   -   [4, 1024, 14, 14]           0             0
# 199_model.layer3.10.Conv2d_conv1               [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 200_model.layer3.10.BatchNorm2d_bn1                        [256]    [4, 256, 14, 14]         512       802,816
# 201_model.layer3.10.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 202_model.layer3.10.Conv2d_conv2                [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 203_model.layer3.10.BatchNorm2d_bn2                        [256]    [4, 256, 14, 14]         512       802,816
# 204_model.layer3.10.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 205_model.layer3.10.Conv2d_conv3               [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 206_model.layer3.10.BatchNorm2d_bn3                       [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 207_model.layer3.10.ReLU_relu                                  -   [4, 1024, 14, 14]           0             0
# 208_model.layer3.11.Conv2d_conv1               [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 209_model.layer3.11.BatchNorm2d_bn1                        [256]    [4, 256, 14, 14]         512       802,816
# 210_model.layer3.11.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 211_model.layer3.11.Conv2d_conv2                [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 212_model.layer3.11.BatchNorm2d_bn2                        [256]    [4, 256, 14, 14]         512       802,816
# 213_model.layer3.11.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 214_model.layer3.11.Conv2d_conv3               [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 215_model.layer3.11.BatchNorm2d_bn3                       [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 216_model.layer3.11.ReLU_relu                                  -   [4, 1024, 14, 14]           0             0
# 217_model.layer3.12.Conv2d_conv1               [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 218_model.layer3.12.BatchNorm2d_bn1                        [256]    [4, 256, 14, 14]         512       802,816
# 219_model.layer3.12.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 220_model.layer3.12.Conv2d_conv2                [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 221_model.layer3.12.BatchNorm2d_bn2                        [256]    [4, 256, 14, 14]         512       802,816
# 222_model.layer3.12.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 223_model.layer3.12.Conv2d_conv3               [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 224_model.layer3.12.BatchNorm2d_bn3                       [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 225_model.layer3.12.ReLU_relu                                  -   [4, 1024, 14, 14]           0             0
# 226_model.layer3.13.Conv2d_conv1               [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 227_model.layer3.13.BatchNorm2d_bn1                        [256]    [4, 256, 14, 14]         512       802,816
# 228_model.layer3.13.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 229_model.layer3.13.Conv2d_conv2                [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 230_model.layer3.13.BatchNorm2d_bn2                        [256]    [4, 256, 14, 14]         512       802,816
# 231_model.layer3.13.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 232_model.layer3.13.Conv2d_conv3               [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 233_model.layer3.13.BatchNorm2d_bn3                       [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 234_model.layer3.13.ReLU_relu                                  -   [4, 1024, 14, 14]           0             0
# 235_model.layer3.14.Conv2d_conv1               [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 236_model.layer3.14.BatchNorm2d_bn1                        [256]    [4, 256, 14, 14]         512       802,816
# 237_model.layer3.14.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 238_model.layer3.14.Conv2d_conv2                [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 239_model.layer3.14.BatchNorm2d_bn2                        [256]    [4, 256, 14, 14]         512       802,816
# 240_model.layer3.14.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 241_model.layer3.14.Conv2d_conv3               [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 242_model.layer3.14.BatchNorm2d_bn3                       [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 243_model.layer3.14.ReLU_relu                                  -   [4, 1024, 14, 14]           0             0
# 244_model.layer3.15.Conv2d_conv1               [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 245_model.layer3.15.BatchNorm2d_bn1                        [256]    [4, 256, 14, 14]         512       802,816
# 246_model.layer3.15.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 247_model.layer3.15.Conv2d_conv2                [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 248_model.layer3.15.BatchNorm2d_bn2                        [256]    [4, 256, 14, 14]         512       802,816
# 249_model.layer3.15.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 250_model.layer3.15.Conv2d_conv3               [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 251_model.layer3.15.BatchNorm2d_bn3                       [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 252_model.layer3.15.ReLU_relu                                  -   [4, 1024, 14, 14]           0             0
# 253_model.layer3.16.Conv2d_conv1               [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 254_model.layer3.16.BatchNorm2d_bn1                        [256]    [4, 256, 14, 14]         512       802,816
# 255_model.layer3.16.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 256_model.layer3.16.Conv2d_conv2                [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 257_model.layer3.16.BatchNorm2d_bn2                        [256]    [4, 256, 14, 14]         512       802,816
# 258_model.layer3.16.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 259_model.layer3.16.Conv2d_conv3               [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 260_model.layer3.16.BatchNorm2d_bn3                       [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 261_model.layer3.16.ReLU_relu                                  -   [4, 1024, 14, 14]           0             0
# 262_model.layer3.17.Conv2d_conv1               [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 263_model.layer3.17.BatchNorm2d_bn1                        [256]    [4, 256, 14, 14]         512       802,816
# 264_model.layer3.17.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 265_model.layer3.17.Conv2d_conv2                [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 266_model.layer3.17.BatchNorm2d_bn2                        [256]    [4, 256, 14, 14]         512       802,816
# 267_model.layer3.17.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 268_model.layer3.17.Conv2d_conv3               [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 269_model.layer3.17.BatchNorm2d_bn3                       [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 270_model.layer3.17.ReLU_relu                                  -   [4, 1024, 14, 14]           0             0
# 271_model.layer3.18.Conv2d_conv1               [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 272_model.layer3.18.BatchNorm2d_bn1                        [256]    [4, 256, 14, 14]         512       802,816
# 273_model.layer3.18.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 274_model.layer3.18.Conv2d_conv2                [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 275_model.layer3.18.BatchNorm2d_bn2                        [256]    [4, 256, 14, 14]         512       802,816
# 276_model.layer3.18.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 277_model.layer3.18.Conv2d_conv3               [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 278_model.layer3.18.BatchNorm2d_bn3                       [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 279_model.layer3.18.ReLU_relu                                  -   [4, 1024, 14, 14]           0             0
# 280_model.layer3.19.Conv2d_conv1               [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 281_model.layer3.19.BatchNorm2d_bn1                        [256]    [4, 256, 14, 14]         512       802,816
# 282_model.layer3.19.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 283_model.layer3.19.Conv2d_conv2                [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 284_model.layer3.19.BatchNorm2d_bn2                        [256]    [4, 256, 14, 14]         512       802,816
# 285_model.layer3.19.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 286_model.layer3.19.Conv2d_conv3               [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 287_model.layer3.19.BatchNorm2d_bn3                       [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 288_model.layer3.19.ReLU_relu                                  -   [4, 1024, 14, 14]           0             0
# 289_model.layer3.20.Conv2d_conv1               [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 290_model.layer3.20.BatchNorm2d_bn1                        [256]    [4, 256, 14, 14]         512       802,816
# 291_model.layer3.20.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 292_model.layer3.20.Conv2d_conv2                [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 293_model.layer3.20.BatchNorm2d_bn2                        [256]    [4, 256, 14, 14]         512       802,816
# 294_model.layer3.20.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 295_model.layer3.20.Conv2d_conv3               [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 296_model.layer3.20.BatchNorm2d_bn3                       [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 297_model.layer3.20.ReLU_relu                                  -   [4, 1024, 14, 14]           0             0
# 298_model.layer3.21.Conv2d_conv1               [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 299_model.layer3.21.BatchNorm2d_bn1                        [256]    [4, 256, 14, 14]         512       802,816
# 300_model.layer3.21.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 301_model.layer3.21.Conv2d_conv2                [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 302_model.layer3.21.BatchNorm2d_bn2                        [256]    [4, 256, 14, 14]         512       802,816
# 303_model.layer3.21.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 304_model.layer3.21.Conv2d_conv3               [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 305_model.layer3.21.BatchNorm2d_bn3                       [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 306_model.layer3.21.ReLU_relu                                  -   [4, 1024, 14, 14]           0             0
# 307_model.layer3.22.Conv2d_conv1               [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 308_model.layer3.22.BatchNorm2d_bn1                        [256]    [4, 256, 14, 14]         512       802,816
# 309_model.layer3.22.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 310_model.layer3.22.Conv2d_conv2                [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 311_model.layer3.22.BatchNorm2d_bn2                        [256]    [4, 256, 14, 14]         512       802,816
# 312_model.layer3.22.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 313_model.layer3.22.Conv2d_conv3               [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 314_model.layer3.22.BatchNorm2d_bn3                       [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 315_model.layer3.22.ReLU_relu                                  -   [4, 1024, 14, 14]           0             0
# 316_model.layer3.23.Conv2d_conv1               [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 317_model.layer3.23.BatchNorm2d_bn1                        [256]    [4, 256, 14, 14]         512       802,816
# 318_model.layer3.23.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 319_model.layer3.23.Conv2d_conv2                [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 320_model.layer3.23.BatchNorm2d_bn2                        [256]    [4, 256, 14, 14]         512       802,816
# 321_model.layer3.23.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 322_model.layer3.23.Conv2d_conv3               [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 323_model.layer3.23.BatchNorm2d_bn3                       [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 324_model.layer3.23.ReLU_relu                                  -   [4, 1024, 14, 14]           0             0
# 325_model.layer3.24.Conv2d_conv1               [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 326_model.layer3.24.BatchNorm2d_bn1                        [256]    [4, 256, 14, 14]         512       802,816
# 327_model.layer3.24.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 328_model.layer3.24.Conv2d_conv2                [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 329_model.layer3.24.BatchNorm2d_bn2                        [256]    [4, 256, 14, 14]         512       802,816
# 330_model.layer3.24.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 331_model.layer3.24.Conv2d_conv3               [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 332_model.layer3.24.BatchNorm2d_bn3                       [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 333_model.layer3.24.ReLU_relu                                  -   [4, 1024, 14, 14]           0             0
# 334_model.layer3.25.Conv2d_conv1               [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 335_model.layer3.25.BatchNorm2d_bn1                        [256]    [4, 256, 14, 14]         512       802,816
# 336_model.layer3.25.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 337_model.layer3.25.Conv2d_conv2                [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 338_model.layer3.25.BatchNorm2d_bn2                        [256]    [4, 256, 14, 14]         512       802,816
# 339_model.layer3.25.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 340_model.layer3.25.Conv2d_conv3               [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 341_model.layer3.25.BatchNorm2d_bn3                       [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 342_model.layer3.25.ReLU_relu                                  -   [4, 1024, 14, 14]           0             0
# 343_model.layer3.26.Conv2d_conv1               [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 344_model.layer3.26.BatchNorm2d_bn1                        [256]    [4, 256, 14, 14]         512       802,816
# 345_model.layer3.26.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 346_model.layer3.26.Conv2d_conv2                [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 347_model.layer3.26.BatchNorm2d_bn2                        [256]    [4, 256, 14, 14]         512       802,816
# 348_model.layer3.26.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 349_model.layer3.26.Conv2d_conv3               [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 350_model.layer3.26.BatchNorm2d_bn3                       [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 351_model.layer3.26.ReLU_relu                                  -   [4, 1024, 14, 14]           0             0
# 352_model.layer3.27.Conv2d_conv1               [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 353_model.layer3.27.BatchNorm2d_bn1                        [256]    [4, 256, 14, 14]         512       802,816
# 354_model.layer3.27.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 355_model.layer3.27.Conv2d_conv2                [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 356_model.layer3.27.BatchNorm2d_bn2                        [256]    [4, 256, 14, 14]         512       802,816
# 357_model.layer3.27.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 358_model.layer3.27.Conv2d_conv3               [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 359_model.layer3.27.BatchNorm2d_bn3                       [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 360_model.layer3.27.ReLU_relu                                  -   [4, 1024, 14, 14]           0             0
# 361_model.layer3.28.Conv2d_conv1               [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 362_model.layer3.28.BatchNorm2d_bn1                        [256]    [4, 256, 14, 14]         512       802,816
# 363_model.layer3.28.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 364_model.layer3.28.Conv2d_conv2                [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 365_model.layer3.28.BatchNorm2d_bn2                        [256]    [4, 256, 14, 14]         512       802,816
# 366_model.layer3.28.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 367_model.layer3.28.Conv2d_conv3               [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 368_model.layer3.28.BatchNorm2d_bn3                       [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 369_model.layer3.28.ReLU_relu                                  -   [4, 1024, 14, 14]           0             0
# 370_model.layer3.29.Conv2d_conv1               [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 371_model.layer3.29.BatchNorm2d_bn1                        [256]    [4, 256, 14, 14]         512       802,816
# 372_model.layer3.29.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 373_model.layer3.29.Conv2d_conv2                [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 374_model.layer3.29.BatchNorm2d_bn2                        [256]    [4, 256, 14, 14]         512       802,816
# 375_model.layer3.29.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 376_model.layer3.29.Conv2d_conv3               [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 377_model.layer3.29.BatchNorm2d_bn3                       [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 378_model.layer3.29.ReLU_relu                                  -   [4, 1024, 14, 14]           0             0
# 379_model.layer3.30.Conv2d_conv1               [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 380_model.layer3.30.BatchNorm2d_bn1                        [256]    [4, 256, 14, 14]         512       802,816
# 381_model.layer3.30.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 382_model.layer3.30.Conv2d_conv2                [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 383_model.layer3.30.BatchNorm2d_bn2                        [256]    [4, 256, 14, 14]         512       802,816
# 384_model.layer3.30.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 385_model.layer3.30.Conv2d_conv3               [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 386_model.layer3.30.BatchNorm2d_bn3                       [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 387_model.layer3.30.ReLU_relu                                  -   [4, 1024, 14, 14]           0             0
# 388_model.layer3.31.Conv2d_conv1               [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 389_model.layer3.31.BatchNorm2d_bn1                        [256]    [4, 256, 14, 14]         512       802,816
# 390_model.layer3.31.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 391_model.layer3.31.Conv2d_conv2                [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 392_model.layer3.31.BatchNorm2d_bn2                        [256]    [4, 256, 14, 14]         512       802,816
# 393_model.layer3.31.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 394_model.layer3.31.Conv2d_conv3               [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 395_model.layer3.31.BatchNorm2d_bn3                       [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 396_model.layer3.31.ReLU_relu                                  -   [4, 1024, 14, 14]           0             0
# 397_model.layer3.32.Conv2d_conv1               [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 398_model.layer3.32.BatchNorm2d_bn1                        [256]    [4, 256, 14, 14]         512       802,816
# 399_model.layer3.32.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 400_model.layer3.32.Conv2d_conv2                [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 401_model.layer3.32.BatchNorm2d_bn2                        [256]    [4, 256, 14, 14]         512       802,816
# 402_model.layer3.32.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 403_model.layer3.32.Conv2d_conv3               [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 404_model.layer3.32.BatchNorm2d_bn3                       [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 405_model.layer3.32.ReLU_relu                                  -   [4, 1024, 14, 14]           0             0
# 406_model.layer3.33.Conv2d_conv1               [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 407_model.layer3.33.BatchNorm2d_bn1                        [256]    [4, 256, 14, 14]         512       802,816
# 408_model.layer3.33.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 409_model.layer3.33.Conv2d_conv2                [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 410_model.layer3.33.BatchNorm2d_bn2                        [256]    [4, 256, 14, 14]         512       802,816
# 411_model.layer3.33.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 412_model.layer3.33.Conv2d_conv3               [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 413_model.layer3.33.BatchNorm2d_bn3                       [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 414_model.layer3.33.ReLU_relu                                  -   [4, 1024, 14, 14]           0             0
# 415_model.layer3.34.Conv2d_conv1               [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 416_model.layer3.34.BatchNorm2d_bn1                        [256]    [4, 256, 14, 14]         512       802,816
# 417_model.layer3.34.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 418_model.layer3.34.Conv2d_conv2                [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 419_model.layer3.34.BatchNorm2d_bn2                        [256]    [4, 256, 14, 14]         512       802,816
# 420_model.layer3.34.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 421_model.layer3.34.Conv2d_conv3               [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 422_model.layer3.34.BatchNorm2d_bn3                       [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 423_model.layer3.34.ReLU_relu                                  -   [4, 1024, 14, 14]           0             0
# 424_model.layer3.35.Conv2d_conv1               [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 425_model.layer3.35.BatchNorm2d_bn1                        [256]    [4, 256, 14, 14]         512       802,816
# 426_model.layer3.35.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 427_model.layer3.35.Conv2d_conv2                [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 428_model.layer3.35.BatchNorm2d_bn2                        [256]    [4, 256, 14, 14]         512       802,816
# 429_model.layer3.35.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 430_model.layer3.35.Conv2d_conv3               [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 431_model.layer3.35.BatchNorm2d_bn3                       [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 432_model.layer3.35.ReLU_relu                                  -   [4, 1024, 14, 14]           0             0
# 433_model.layer4.0.Conv2d_conv1                [1024, 512, 1, 1]    [4, 512, 14, 14]     524,288   411,041,792
# 434_model.layer4.0.BatchNorm2d_bn1                         [512]    [4, 512, 14, 14]       1,024     1,605,632
# 435_model.layer4.0.ReLU_relu                                   -    [4, 512, 14, 14]           0             0
# 436_model.layer4.0.Conv2d_conv2                 [512, 512, 3, 3]      [4, 512, 7, 7]   2,359,296   462,422,016
# 437_model.layer4.0.BatchNorm2d_bn2                         [512]      [4, 512, 7, 7]       1,024       401,408
# 438_model.layer4.0.ReLU_relu                                   -      [4, 512, 7, 7]           0             0
# 439_model.layer4.0.Conv2d_conv3                [512, 2048, 1, 1]     [4, 2048, 7, 7]   1,048,576   205,520,896
# 440_model.layer4.0.BatchNorm2d_bn3                        [2048]     [4, 2048, 7, 7]       4,096     1,605,632
# 441_model.layer4.0.downsample.Conv2d_0        [1024, 2048, 1, 1]     [4, 2048, 7, 7]   2,097,152   411,041,792
# 442_model.layer4.0.downsample.BatchNorm2d_1               [2048]     [4, 2048, 7, 7]       4,096     1,605,632
# 443_model.layer4.0.ReLU_relu                                   -     [4, 2048, 7, 7]           0             0
# 444_model.layer4.1.Conv2d_conv1                [2048, 512, 1, 1]      [4, 512, 7, 7]   1,048,576   205,520,896
# 445_model.layer4.1.BatchNorm2d_bn1                         [512]      [4, 512, 7, 7]       1,024       401,408
# 446_model.layer4.1.ReLU_relu                                   -      [4, 512, 7, 7]           0             0
# 447_model.layer4.1.Conv2d_conv2                 [512, 512, 3, 3]      [4, 512, 7, 7]   2,359,296   462,422,016
# 448_model.layer4.1.BatchNorm2d_bn2                         [512]      [4, 512, 7, 7]       1,024       401,408
# 449_model.layer4.1.ReLU_relu                                   -      [4, 512, 7, 7]           0             0
# 450_model.layer4.1.Conv2d_conv3                [512, 2048, 1, 1]     [4, 2048, 7, 7]   1,048,576   205,520,896
# 451_model.layer4.1.BatchNorm2d_bn3                        [2048]     [4, 2048, 7, 7]       4,096     1,605,632
# 452_model.layer4.1.ReLU_relu                                   -     [4, 2048, 7, 7]           0             0
# 453_model.layer4.2.Conv2d_conv1                [2048, 512, 1, 1]      [4, 512, 7, 7]   1,048,576   205,520,896
# 454_model.layer4.2.BatchNorm2d_bn1                         [512]      [4, 512, 7, 7]       1,024       401,408
# 455_model.layer4.2.ReLU_relu                                   -      [4, 512, 7, 7]           0             0
# 456_model.layer4.2.Conv2d_conv2                 [512, 512, 3, 3]      [4, 512, 7, 7]   2,359,296   462,422,016
# 457_model.layer4.2.BatchNorm2d_bn2                         [512]      [4, 512, 7, 7]       1,024       401,408
# 458_model.layer4.2.ReLU_relu                                   -      [4, 512, 7, 7]           0             0
# 459_model.layer4.2.Conv2d_conv3                [512, 2048, 1, 1]     [4, 2048, 7, 7]   1,048,576   205,520,896
# 460_model.layer4.2.BatchNorm2d_bn3                        [2048]     [4, 2048, 7, 7]       4,096     1,605,632
# 461_model.layer4.2.ReLU_relu                                   -     [4, 2048, 7, 7]           0             0
# 462_model.AdaptiveAvgPool2d_avgpool                            -     [4, 2048, 1, 1]           0       409,600
# 463_model.Linear_fc                                    [2048, 1]              [4, 1]       2,049        16,380
# ==============================================================================================================
# Total params: 58,145,857
# Trainable params: 2,049
# Non-trainable params: 58,143,808
# Total FLOPs: 46,407,606,268 / 46.41 GFLOPs
# --------------------------------------------------------------------------------------------------------------
# Input size (MB): 2.30
# Forward/backward pass size (MB): 2025.14
# Params size (MB): 221.81
# Estimated Total Size (MB): 2249.25
# ==============================================================================================================

# %%
logs = fit_model(model, 20, optimizer)
# Out:
# ------------- Epoch 1 -------------
# train: accuracy 0.6207, loss 0.6500
# valid: accuracy 0.6098, loss 0.6599
# -----------------------------------
#
# ------------- Epoch 2 -------------
# train: accuracy 0.7621, loss 0.5807
# valid: accuracy 0.7247, loss 0.5959
# -----------------------------------
#
# ------------- Epoch 3 -------------
# train: accuracy 0.8003, loss 0.5306
# valid: accuracy 0.7612, loss 0.5453
# -----------------------------------
#
# ------------- Epoch 4 -------------
# train: accuracy 0.7973, loss 0.4966
# valid: accuracy 0.7535, loss 0.5230
# -----------------------------------
#
# ------------- Epoch 5 -------------
# train: accuracy 0.8030, loss 0.4701
# valid: accuracy 0.7889, loss 0.4918
# -----------------------------------
#
# ------------- Epoch 6 -------------
# train: accuracy 0.8200, loss 0.4439
# valid: accuracy 0.8063, loss 0.4634
# -----------------------------------
#
# ------------- Epoch 7 -------------
# train: accuracy 0.8100, loss 0.4378
# valid: accuracy 0.8314, loss 0.4472
# -----------------------------------
#
# ------------- Epoch 8 -------------
# train: accuracy 0.8074, loss 0.4348
# valid: accuracy 0.7954, loss 0.4626
# -----------------------------------
#
# ------------- Epoch 9 -------------
# train: accuracy 0.8076, loss 0.4236
# valid: accuracy 0.8301, loss 0.4310
# -----------------------------------
#
# ------------- Epoch 10 -------------
# train: accuracy 0.8235, loss 0.4107
# valid: accuracy 0.8465, loss 0.4264
# -----------------------------------
#
# ------------- Epoch 11 -------------
# train: accuracy 0.8256, loss 0.4022
# valid: accuracy 0.8451, loss 0.4126
# -----------------------------------
#
# ------------- Epoch 12 -------------
# train: accuracy 0.8232, loss 0.4008
# valid: accuracy 0.8312, loss 0.4184
# -----------------------------------
#
# ------------- Epoch 13 -------------
# train: accuracy 0.8266, loss 0.4032
# valid: accuracy 0.8562, loss 0.3862
# -----------------------------------
#
# ------------- Epoch 14 -------------
# train: accuracy 0.8334, loss 0.3825
# valid: accuracy 0.8587, loss 0.3909
# -----------------------------------
#
# ------------- Epoch 15 -------------
# train: accuracy 0.8299, loss 0.3831
# valid: accuracy 0.8534, loss 0.3940
# -----------------------------------
#
# ------------- Epoch 16 -------------
# train: accuracy 0.8266, loss 0.3824
# valid: accuracy 0.8712, loss 0.3785
# -----------------------------------
#
# ------------- Epoch 17 -------------
# train: accuracy 0.8421, loss 0.3750
# valid: accuracy 0.8650, loss 0.3718
# -----------------------------------
#
# ------------- Epoch 18 -------------
# train: accuracy 0.8368, loss 0.3760
# valid: accuracy 0.8582, loss 0.3755
# -----------------------------------
#
# ------------- Epoch 19 -------------
# train: accuracy 0.8364, loss 0.3804
# valid: accuracy 0.8621, loss 0.3822
# -----------------------------------
#
# ------------- Epoch 20 -------------
# train: accuracy 0.8399, loss 0.3744
# valid: accuracy 0.8491, loss 0.3766
# -----------------------------------

# %%
class MyResNet_2(nn.Module):
    def __init__(self):
        super().__init__()
        self.model = resnet152(weights=ResNet152_Weights.DEFAULT)
        self.model.fc = nn.Linear(2048, 1)
        for i in self.model.parameters():
            i.requires_grad = False

        for param in self.model.layer4.parameters():
            param.requires_grad = True

        for param in self.model.fc.parameters():
            param.requires_grad = True
        
    def forward(self, x):
        x = self.model(x)
        return torch.sigmoid(x)

# %%
model_2 = MyResNet_2()
model_2.to(DEVICE)
torch.cuda.empty_cache()

# %%
tu.get_model_summary(model_2, fake_batch)
torch.cuda.empty_cache()
# Out:
# ==============================================================================================================
# Layer                                               Kernel              Output          Params           FLOPs
# ==============================================================================================================
# 0_model.Conv2d_conv1                               [3, 64, 7, 7]   [4, 64, 112, 112]       9,408   472,055,808
# 1_model.BatchNorm2d_bn1                                     [64]   [4, 64, 112, 112]         128    12,845,056
# 2_model.ReLU_relu                                              -   [4, 64, 112, 112]           0             0
# 3_model.MaxPool2d_maxpool                                      -     [4, 64, 56, 56]           0             0
# 4_model.layer1.0.Conv2d_conv1                     [64, 64, 1, 1]     [4, 64, 56, 56]       4,096    51,380,224
# 5_model.layer1.0.BatchNorm2d_bn1                            [64]     [4, 64, 56, 56]         128     3,211,264
# 6_model.layer1.0.ReLU_relu                                     -     [4, 64, 56, 56]           0             0
# 7_model.layer1.0.Conv2d_conv2                     [64, 64, 3, 3]     [4, 64, 56, 56]      36,864   462,422,016
# 8_model.layer1.0.BatchNorm2d_bn2                            [64]     [4, 64, 56, 56]         128     3,211,264
# 9_model.layer1.0.ReLU_relu                                     -     [4, 64, 56, 56]           0             0
# 10_model.layer1.0.Conv2d_conv3                   [64, 256, 1, 1]    [4, 256, 56, 56]      16,384   205,520,896
# 11_model.layer1.0.BatchNorm2d_bn3                          [256]    [4, 256, 56, 56]         512    12,845,056
# 12_model.layer1.0.downsample.Conv2d_0            [64, 256, 1, 1]    [4, 256, 56, 56]      16,384   205,520,896
# 13_model.layer1.0.downsample.BatchNorm2d_1                 [256]    [4, 256, 56, 56]         512    12,845,056
# 14_model.layer1.0.ReLU_relu                                    -    [4, 256, 56, 56]           0             0
# 15_model.layer1.1.Conv2d_conv1                   [256, 64, 1, 1]     [4, 64, 56, 56]      16,384   205,520,896
# 16_model.layer1.1.BatchNorm2d_bn1                           [64]     [4, 64, 56, 56]         128     3,211,264
# 17_model.layer1.1.ReLU_relu                                    -     [4, 64, 56, 56]           0             0
# 18_model.layer1.1.Conv2d_conv2                    [64, 64, 3, 3]     [4, 64, 56, 56]      36,864   462,422,016
# 19_model.layer1.1.BatchNorm2d_bn2                           [64]     [4, 64, 56, 56]         128     3,211,264
# 20_model.layer1.1.ReLU_relu                                    -     [4, 64, 56, 56]           0             0
# 21_model.layer1.1.Conv2d_conv3                   [64, 256, 1, 1]    [4, 256, 56, 56]      16,384   205,520,896
# 22_model.layer1.1.BatchNorm2d_bn3                          [256]    [4, 256, 56, 56]         512    12,845,056
# 23_model.layer1.1.ReLU_relu                                    -    [4, 256, 56, 56]           0             0
# 24_model.layer1.2.Conv2d_conv1                   [256, 64, 1, 1]     [4, 64, 56, 56]      16,384   205,520,896
# 25_model.layer1.2.BatchNorm2d_bn1                           [64]     [4, 64, 56, 56]         128     3,211,264
# 26_model.layer1.2.ReLU_relu                                    -     [4, 64, 56, 56]           0             0
# 27_model.layer1.2.Conv2d_conv2                    [64, 64, 3, 3]     [4, 64, 56, 56]      36,864   462,422,016
# 28_model.layer1.2.BatchNorm2d_bn2                           [64]     [4, 64, 56, 56]         128     3,211,264
# 29_model.layer1.2.ReLU_relu                                    -     [4, 64, 56, 56]           0             0
# 30_model.layer1.2.Conv2d_conv3                   [64, 256, 1, 1]    [4, 256, 56, 56]      16,384   205,520,896
# 31_model.layer1.2.BatchNorm2d_bn3                          [256]    [4, 256, 56, 56]         512    12,845,056
# 32_model.layer1.2.ReLU_relu                                    -    [4, 256, 56, 56]           0             0
# 33_model.layer2.0.Conv2d_conv1                  [256, 128, 1, 1]    [4, 128, 56, 56]      32,768   411,041,792
# 34_model.layer2.0.BatchNorm2d_bn1                          [128]    [4, 128, 56, 56]         256     6,422,528
# 35_model.layer2.0.ReLU_relu                                    -    [4, 128, 56, 56]           0             0
# 36_model.layer2.0.Conv2d_conv2                  [128, 128, 3, 3]    [4, 128, 28, 28]     147,456   462,422,016
# 37_model.layer2.0.BatchNorm2d_bn2                          [128]    [4, 128, 28, 28]         256     1,605,632
# 38_model.layer2.0.ReLU_relu                                    -    [4, 128, 28, 28]           0             0
# 39_model.layer2.0.Conv2d_conv3                  [128, 512, 1, 1]    [4, 512, 28, 28]      65,536   205,520,896
# 40_model.layer2.0.BatchNorm2d_bn3                          [512]    [4, 512, 28, 28]       1,024     6,422,528
# 41_model.layer2.0.downsample.Conv2d_0           [256, 512, 1, 1]    [4, 512, 28, 28]     131,072   411,041,792
# 42_model.layer2.0.downsample.BatchNorm2d_1                 [512]    [4, 512, 28, 28]       1,024     6,422,528
# 43_model.layer2.0.ReLU_relu                                    -    [4, 512, 28, 28]           0             0
# 44_model.layer2.1.Conv2d_conv1                  [512, 128, 1, 1]    [4, 128, 28, 28]      65,536   205,520,896
# 45_model.layer2.1.BatchNorm2d_bn1                          [128]    [4, 128, 28, 28]         256     1,605,632
# 46_model.layer2.1.ReLU_relu                                    -    [4, 128, 28, 28]           0             0
# 47_model.layer2.1.Conv2d_conv2                  [128, 128, 3, 3]    [4, 128, 28, 28]     147,456   462,422,016
# 48_model.layer2.1.BatchNorm2d_bn2                          [128]    [4, 128, 28, 28]         256     1,605,632
# 49_model.layer2.1.ReLU_relu                                    -    [4, 128, 28, 28]           0             0
# 50_model.layer2.1.Conv2d_conv3                  [128, 512, 1, 1]    [4, 512, 28, 28]      65,536   205,520,896
# 51_model.layer2.1.BatchNorm2d_bn3                          [512]    [4, 512, 28, 28]       1,024     6,422,528
# 52_model.layer2.1.ReLU_relu                                    -    [4, 512, 28, 28]           0             0
# 53_model.layer2.2.Conv2d_conv1                  [512, 128, 1, 1]    [4, 128, 28, 28]      65,536   205,520,896
# 54_model.layer2.2.BatchNorm2d_bn1                          [128]    [4, 128, 28, 28]         256     1,605,632
# 55_model.layer2.2.ReLU_relu                                    -    [4, 128, 28, 28]           0             0
# 56_model.layer2.2.Conv2d_conv2                  [128, 128, 3, 3]    [4, 128, 28, 28]     147,456   462,422,016
# 57_model.layer2.2.BatchNorm2d_bn2                          [128]    [4, 128, 28, 28]         256     1,605,632
# 58_model.layer2.2.ReLU_relu                                    -    [4, 128, 28, 28]           0             0
# 59_model.layer2.2.Conv2d_conv3                  [128, 512, 1, 1]    [4, 512, 28, 28]      65,536   205,520,896
# 60_model.layer2.2.BatchNorm2d_bn3                          [512]    [4, 512, 28, 28]       1,024     6,422,528
# 61_model.layer2.2.ReLU_relu                                    -    [4, 512, 28, 28]           0             0
# 62_model.layer2.3.Conv2d_conv1                  [512, 128, 1, 1]    [4, 128, 28, 28]      65,536   205,520,896
# 63_model.layer2.3.BatchNorm2d_bn1                          [128]    [4, 128, 28, 28]         256     1,605,632
# 64_model.layer2.3.ReLU_relu                                    -    [4, 128, 28, 28]           0             0
# 65_model.layer2.3.Conv2d_conv2                  [128, 128, 3, 3]    [4, 128, 28, 28]     147,456   462,422,016
# 66_model.layer2.3.BatchNorm2d_bn2                          [128]    [4, 128, 28, 28]         256     1,605,632
# 67_model.layer2.3.ReLU_relu                                    -    [4, 128, 28, 28]           0             0
# 68_model.layer2.3.Conv2d_conv3                  [128, 512, 1, 1]    [4, 512, 28, 28]      65,536   205,520,896
# 69_model.layer2.3.BatchNorm2d_bn3                          [512]    [4, 512, 28, 28]       1,024     6,422,528
# 70_model.layer2.3.ReLU_relu                                    -    [4, 512, 28, 28]           0             0
# 71_model.layer2.4.Conv2d_conv1                  [512, 128, 1, 1]    [4, 128, 28, 28]      65,536   205,520,896
# 72_model.layer2.4.BatchNorm2d_bn1                          [128]    [4, 128, 28, 28]         256     1,605,632
# 73_model.layer2.4.ReLU_relu                                    -    [4, 128, 28, 28]           0             0
# 74_model.layer2.4.Conv2d_conv2                  [128, 128, 3, 3]    [4, 128, 28, 28]     147,456   462,422,016
# 75_model.layer2.4.BatchNorm2d_bn2                          [128]    [4, 128, 28, 28]         256     1,605,632
# 76_model.layer2.4.ReLU_relu                                    -    [4, 128, 28, 28]           0             0
# 77_model.layer2.4.Conv2d_conv3                  [128, 512, 1, 1]    [4, 512, 28, 28]      65,536   205,520,896
# 78_model.layer2.4.BatchNorm2d_bn3                          [512]    [4, 512, 28, 28]       1,024     6,422,528
# 79_model.layer2.4.ReLU_relu                                    -    [4, 512, 28, 28]           0             0
# 80_model.layer2.5.Conv2d_conv1                  [512, 128, 1, 1]    [4, 128, 28, 28]      65,536   205,520,896
# 81_model.layer2.5.BatchNorm2d_bn1                          [128]    [4, 128, 28, 28]         256     1,605,632
# 82_model.layer2.5.ReLU_relu                                    -    [4, 128, 28, 28]           0             0
# 83_model.layer2.5.Conv2d_conv2                  [128, 128, 3, 3]    [4, 128, 28, 28]     147,456   462,422,016
# 84_model.layer2.5.BatchNorm2d_bn2                          [128]    [4, 128, 28, 28]         256     1,605,632
# 85_model.layer2.5.ReLU_relu                                    -    [4, 128, 28, 28]           0             0
# 86_model.layer2.5.Conv2d_conv3                  [128, 512, 1, 1]    [4, 512, 28, 28]      65,536   205,520,896
# 87_model.layer2.5.BatchNorm2d_bn3                          [512]    [4, 512, 28, 28]       1,024     6,422,528
# 88_model.layer2.5.ReLU_relu                                    -    [4, 512, 28, 28]           0             0
# 89_model.layer2.6.Conv2d_conv1                  [512, 128, 1, 1]    [4, 128, 28, 28]      65,536   205,520,896
# 90_model.layer2.6.BatchNorm2d_bn1                          [128]    [4, 128, 28, 28]         256     1,605,632
# 91_model.layer2.6.ReLU_relu                                    -    [4, 128, 28, 28]           0             0
# 92_model.layer2.6.Conv2d_conv2                  [128, 128, 3, 3]    [4, 128, 28, 28]     147,456   462,422,016
# 93_model.layer2.6.BatchNorm2d_bn2                          [128]    [4, 128, 28, 28]         256     1,605,632
# 94_model.layer2.6.ReLU_relu                                    -    [4, 128, 28, 28]           0             0
# 95_model.layer2.6.Conv2d_conv3                  [128, 512, 1, 1]    [4, 512, 28, 28]      65,536   205,520,896
# 96_model.layer2.6.BatchNorm2d_bn3                          [512]    [4, 512, 28, 28]       1,024     6,422,528
# 97_model.layer2.6.ReLU_relu                                    -    [4, 512, 28, 28]           0             0
# 98_model.layer2.7.Conv2d_conv1                  [512, 128, 1, 1]    [4, 128, 28, 28]      65,536   205,520,896
# 99_model.layer2.7.BatchNorm2d_bn1                          [128]    [4, 128, 28, 28]         256     1,605,632
# 100_model.layer2.7.ReLU_relu                                   -    [4, 128, 28, 28]           0             0
# 101_model.layer2.7.Conv2d_conv2                 [128, 128, 3, 3]    [4, 128, 28, 28]     147,456   462,422,016
# 102_model.layer2.7.BatchNorm2d_bn2                         [128]    [4, 128, 28, 28]         256     1,605,632
# 103_model.layer2.7.ReLU_relu                                   -    [4, 128, 28, 28]           0             0
# 104_model.layer2.7.Conv2d_conv3                 [128, 512, 1, 1]    [4, 512, 28, 28]      65,536   205,520,896
# 105_model.layer2.7.BatchNorm2d_bn3                         [512]    [4, 512, 28, 28]       1,024     6,422,528
# 106_model.layer2.7.ReLU_relu                                   -    [4, 512, 28, 28]           0             0
# 107_model.layer3.0.Conv2d_conv1                 [512, 256, 1, 1]    [4, 256, 28, 28]     131,072   411,041,792
# 108_model.layer3.0.BatchNorm2d_bn1                         [256]    [4, 256, 28, 28]         512     3,211,264
# 109_model.layer3.0.ReLU_relu                                   -    [4, 256, 28, 28]           0             0
# 110_model.layer3.0.Conv2d_conv2                 [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 111_model.layer3.0.BatchNorm2d_bn2                         [256]    [4, 256, 14, 14]         512       802,816
# 112_model.layer3.0.ReLU_relu                                   -    [4, 256, 14, 14]           0             0
# 113_model.layer3.0.Conv2d_conv3                [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 114_model.layer3.0.BatchNorm2d_bn3                        [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 115_model.layer3.0.downsample.Conv2d_0         [512, 1024, 1, 1]   [4, 1024, 14, 14]     524,288   411,041,792
# 116_model.layer3.0.downsample.BatchNorm2d_1               [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 117_model.layer3.0.ReLU_relu                                   -   [4, 1024, 14, 14]           0             0
# 118_model.layer3.1.Conv2d_conv1                [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 119_model.layer3.1.BatchNorm2d_bn1                         [256]    [4, 256, 14, 14]         512       802,816
# 120_model.layer3.1.ReLU_relu                                   -    [4, 256, 14, 14]           0             0
# 121_model.layer3.1.Conv2d_conv2                 [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 122_model.layer3.1.BatchNorm2d_bn2                         [256]    [4, 256, 14, 14]         512       802,816
# 123_model.layer3.1.ReLU_relu                                   -    [4, 256, 14, 14]           0             0
# 124_model.layer3.1.Conv2d_conv3                [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 125_model.layer3.1.BatchNorm2d_bn3                        [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 126_model.layer3.1.ReLU_relu                                   -   [4, 1024, 14, 14]           0             0
# 127_model.layer3.2.Conv2d_conv1                [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 128_model.layer3.2.BatchNorm2d_bn1                         [256]    [4, 256, 14, 14]         512       802,816
# 129_model.layer3.2.ReLU_relu                                   -    [4, 256, 14, 14]           0             0
# 130_model.layer3.2.Conv2d_conv2                 [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 131_model.layer3.2.BatchNorm2d_bn2                         [256]    [4, 256, 14, 14]         512       802,816
# 132_model.layer3.2.ReLU_relu                                   -    [4, 256, 14, 14]           0             0
# 133_model.layer3.2.Conv2d_conv3                [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 134_model.layer3.2.BatchNorm2d_bn3                        [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 135_model.layer3.2.ReLU_relu                                   -   [4, 1024, 14, 14]           0             0
# 136_model.layer3.3.Conv2d_conv1                [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 137_model.layer3.3.BatchNorm2d_bn1                         [256]    [4, 256, 14, 14]         512       802,816
# 138_model.layer3.3.ReLU_relu                                   -    [4, 256, 14, 14]           0             0
# 139_model.layer3.3.Conv2d_conv2                 [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 140_model.layer3.3.BatchNorm2d_bn2                         [256]    [4, 256, 14, 14]         512       802,816
# 141_model.layer3.3.ReLU_relu                                   -    [4, 256, 14, 14]           0             0
# 142_model.layer3.3.Conv2d_conv3                [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 143_model.layer3.3.BatchNorm2d_bn3                        [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 144_model.layer3.3.ReLU_relu                                   -   [4, 1024, 14, 14]           0             0
# 145_model.layer3.4.Conv2d_conv1                [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 146_model.layer3.4.BatchNorm2d_bn1                         [256]    [4, 256, 14, 14]         512       802,816
# 147_model.layer3.4.ReLU_relu                                   -    [4, 256, 14, 14]           0             0
# 148_model.layer3.4.Conv2d_conv2                 [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 149_model.layer3.4.BatchNorm2d_bn2                         [256]    [4, 256, 14, 14]         512       802,816
# 150_model.layer3.4.ReLU_relu                                   -    [4, 256, 14, 14]           0             0
# 151_model.layer3.4.Conv2d_conv3                [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 152_model.layer3.4.BatchNorm2d_bn3                        [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 153_model.layer3.4.ReLU_relu                                   -   [4, 1024, 14, 14]           0             0
# 154_model.layer3.5.Conv2d_conv1                [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 155_model.layer3.5.BatchNorm2d_bn1                         [256]    [4, 256, 14, 14]         512       802,816
# 156_model.layer3.5.ReLU_relu                                   -    [4, 256, 14, 14]           0             0
# 157_model.layer3.5.Conv2d_conv2                 [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 158_model.layer3.5.BatchNorm2d_bn2                         [256]    [4, 256, 14, 14]         512       802,816
# 159_model.layer3.5.ReLU_relu                                   -    [4, 256, 14, 14]           0             0
# 160_model.layer3.5.Conv2d_conv3                [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 161_model.layer3.5.BatchNorm2d_bn3                        [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 162_model.layer3.5.ReLU_relu                                   -   [4, 1024, 14, 14]           0             0
# 163_model.layer3.6.Conv2d_conv1                [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 164_model.layer3.6.BatchNorm2d_bn1                         [256]    [4, 256, 14, 14]         512       802,816
# 165_model.layer3.6.ReLU_relu                                   -    [4, 256, 14, 14]           0             0
# 166_model.layer3.6.Conv2d_conv2                 [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 167_model.layer3.6.BatchNorm2d_bn2                         [256]    [4, 256, 14, 14]         512       802,816
# 168_model.layer3.6.ReLU_relu                                   -    [4, 256, 14, 14]           0             0
# 169_model.layer3.6.Conv2d_conv3                [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 170_model.layer3.6.BatchNorm2d_bn3                        [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 171_model.layer3.6.ReLU_relu                                   -   [4, 1024, 14, 14]           0             0
# 172_model.layer3.7.Conv2d_conv1                [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 173_model.layer3.7.BatchNorm2d_bn1                         [256]    [4, 256, 14, 14]         512       802,816
# 174_model.layer3.7.ReLU_relu                                   -    [4, 256, 14, 14]           0             0
# 175_model.layer3.7.Conv2d_conv2                 [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 176_model.layer3.7.BatchNorm2d_bn2                         [256]    [4, 256, 14, 14]         512       802,816
# 177_model.layer3.7.ReLU_relu                                   -    [4, 256, 14, 14]           0             0
# 178_model.layer3.7.Conv2d_conv3                [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 179_model.layer3.7.BatchNorm2d_bn3                        [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 180_model.layer3.7.ReLU_relu                                   -   [4, 1024, 14, 14]           0             0
# 181_model.layer3.8.Conv2d_conv1                [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 182_model.layer3.8.BatchNorm2d_bn1                         [256]    [4, 256, 14, 14]         512       802,816
# 183_model.layer3.8.ReLU_relu                                   -    [4, 256, 14, 14]           0             0
# 184_model.layer3.8.Conv2d_conv2                 [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 185_model.layer3.8.BatchNorm2d_bn2                         [256]    [4, 256, 14, 14]         512       802,816
# 186_model.layer3.8.ReLU_relu                                   -    [4, 256, 14, 14]           0             0
# 187_model.layer3.8.Conv2d_conv3                [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 188_model.layer3.8.BatchNorm2d_bn3                        [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 189_model.layer3.8.ReLU_relu                                   -   [4, 1024, 14, 14]           0             0
# 190_model.layer3.9.Conv2d_conv1                [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 191_model.layer3.9.BatchNorm2d_bn1                         [256]    [4, 256, 14, 14]         512       802,816
# 192_model.layer3.9.ReLU_relu                                   -    [4, 256, 14, 14]           0             0
# 193_model.layer3.9.Conv2d_conv2                 [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 194_model.layer3.9.BatchNorm2d_bn2                         [256]    [4, 256, 14, 14]         512       802,816
# 195_model.layer3.9.ReLU_relu                                   -    [4, 256, 14, 14]           0             0
# 196_model.layer3.9.Conv2d_conv3                [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 197_model.layer3.9.BatchNorm2d_bn3                        [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 198_model.layer3.9.ReLU_relu                                   -   [4, 1024, 14, 14]           0             0
# 199_model.layer3.10.Conv2d_conv1               [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 200_model.layer3.10.BatchNorm2d_bn1                        [256]    [4, 256, 14, 14]         512       802,816
# 201_model.layer3.10.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 202_model.layer3.10.Conv2d_conv2                [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 203_model.layer3.10.BatchNorm2d_bn2                        [256]    [4, 256, 14, 14]         512       802,816
# 204_model.layer3.10.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 205_model.layer3.10.Conv2d_conv3               [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 206_model.layer3.10.BatchNorm2d_bn3                       [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 207_model.layer3.10.ReLU_relu                                  -   [4, 1024, 14, 14]           0             0
# 208_model.layer3.11.Conv2d_conv1               [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 209_model.layer3.11.BatchNorm2d_bn1                        [256]    [4, 256, 14, 14]         512       802,816
# 210_model.layer3.11.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 211_model.layer3.11.Conv2d_conv2                [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 212_model.layer3.11.BatchNorm2d_bn2                        [256]    [4, 256, 14, 14]         512       802,816
# 213_model.layer3.11.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 214_model.layer3.11.Conv2d_conv3               [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 215_model.layer3.11.BatchNorm2d_bn3                       [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 216_model.layer3.11.ReLU_relu                                  -   [4, 1024, 14, 14]           0             0
# 217_model.layer3.12.Conv2d_conv1               [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 218_model.layer3.12.BatchNorm2d_bn1                        [256]    [4, 256, 14, 14]         512       802,816
# 219_model.layer3.12.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 220_model.layer3.12.Conv2d_conv2                [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 221_model.layer3.12.BatchNorm2d_bn2                        [256]    [4, 256, 14, 14]         512       802,816
# 222_model.layer3.12.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 223_model.layer3.12.Conv2d_conv3               [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 224_model.layer3.12.BatchNorm2d_bn3                       [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 225_model.layer3.12.ReLU_relu                                  -   [4, 1024, 14, 14]           0             0
# 226_model.layer3.13.Conv2d_conv1               [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 227_model.layer3.13.BatchNorm2d_bn1                        [256]    [4, 256, 14, 14]         512       802,816
# 228_model.layer3.13.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 229_model.layer3.13.Conv2d_conv2                [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 230_model.layer3.13.BatchNorm2d_bn2                        [256]    [4, 256, 14, 14]         512       802,816
# 231_model.layer3.13.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 232_model.layer3.13.Conv2d_conv3               [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 233_model.layer3.13.BatchNorm2d_bn3                       [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 234_model.layer3.13.ReLU_relu                                  -   [4, 1024, 14, 14]           0             0
# 235_model.layer3.14.Conv2d_conv1               [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 236_model.layer3.14.BatchNorm2d_bn1                        [256]    [4, 256, 14, 14]         512       802,816
# 237_model.layer3.14.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 238_model.layer3.14.Conv2d_conv2                [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 239_model.layer3.14.BatchNorm2d_bn2                        [256]    [4, 256, 14, 14]         512       802,816
# 240_model.layer3.14.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 241_model.layer3.14.Conv2d_conv3               [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 242_model.layer3.14.BatchNorm2d_bn3                       [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 243_model.layer3.14.ReLU_relu                                  -   [4, 1024, 14, 14]           0             0
# 244_model.layer3.15.Conv2d_conv1               [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 245_model.layer3.15.BatchNorm2d_bn1                        [256]    [4, 256, 14, 14]         512       802,816
# 246_model.layer3.15.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 247_model.layer3.15.Conv2d_conv2                [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 248_model.layer3.15.BatchNorm2d_bn2                        [256]    [4, 256, 14, 14]         512       802,816
# 249_model.layer3.15.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 250_model.layer3.15.Conv2d_conv3               [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 251_model.layer3.15.BatchNorm2d_bn3                       [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 252_model.layer3.15.ReLU_relu                                  -   [4, 1024, 14, 14]           0             0
# 253_model.layer3.16.Conv2d_conv1               [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 254_model.layer3.16.BatchNorm2d_bn1                        [256]    [4, 256, 14, 14]         512       802,816
# 255_model.layer3.16.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 256_model.layer3.16.Conv2d_conv2                [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 257_model.layer3.16.BatchNorm2d_bn2                        [256]    [4, 256, 14, 14]         512       802,816
# 258_model.layer3.16.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 259_model.layer3.16.Conv2d_conv3               [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 260_model.layer3.16.BatchNorm2d_bn3                       [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 261_model.layer3.16.ReLU_relu                                  -   [4, 1024, 14, 14]           0             0
# 262_model.layer3.17.Conv2d_conv1               [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 263_model.layer3.17.BatchNorm2d_bn1                        [256]    [4, 256, 14, 14]         512       802,816
# 264_model.layer3.17.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 265_model.layer3.17.Conv2d_conv2                [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 266_model.layer3.17.BatchNorm2d_bn2                        [256]    [4, 256, 14, 14]         512       802,816
# 267_model.layer3.17.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 268_model.layer3.17.Conv2d_conv3               [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 269_model.layer3.17.BatchNorm2d_bn3                       [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 270_model.layer3.17.ReLU_relu                                  -   [4, 1024, 14, 14]           0             0
# 271_model.layer3.18.Conv2d_conv1               [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 272_model.layer3.18.BatchNorm2d_bn1                        [256]    [4, 256, 14, 14]         512       802,816
# 273_model.layer3.18.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 274_model.layer3.18.Conv2d_conv2                [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 275_model.layer3.18.BatchNorm2d_bn2                        [256]    [4, 256, 14, 14]         512       802,816
# 276_model.layer3.18.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 277_model.layer3.18.Conv2d_conv3               [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 278_model.layer3.18.BatchNorm2d_bn3                       [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 279_model.layer3.18.ReLU_relu                                  -   [4, 1024, 14, 14]           0             0
# 280_model.layer3.19.Conv2d_conv1               [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 281_model.layer3.19.BatchNorm2d_bn1                        [256]    [4, 256, 14, 14]         512       802,816
# 282_model.layer3.19.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 283_model.layer3.19.Conv2d_conv2                [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 284_model.layer3.19.BatchNorm2d_bn2                        [256]    [4, 256, 14, 14]         512       802,816
# 285_model.layer3.19.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 286_model.layer3.19.Conv2d_conv3               [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 287_model.layer3.19.BatchNorm2d_bn3                       [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 288_model.layer3.19.ReLU_relu                                  -   [4, 1024, 14, 14]           0             0
# 289_model.layer3.20.Conv2d_conv1               [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 290_model.layer3.20.BatchNorm2d_bn1                        [256]    [4, 256, 14, 14]         512       802,816
# 291_model.layer3.20.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 292_model.layer3.20.Conv2d_conv2                [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 293_model.layer3.20.BatchNorm2d_bn2                        [256]    [4, 256, 14, 14]         512       802,816
# 294_model.layer3.20.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 295_model.layer3.20.Conv2d_conv3               [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 296_model.layer3.20.BatchNorm2d_bn3                       [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 297_model.layer3.20.ReLU_relu                                  -   [4, 1024, 14, 14]           0             0
# 298_model.layer3.21.Conv2d_conv1               [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 299_model.layer3.21.BatchNorm2d_bn1                        [256]    [4, 256, 14, 14]         512       802,816
# 300_model.layer3.21.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 301_model.layer3.21.Conv2d_conv2                [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 302_model.layer3.21.BatchNorm2d_bn2                        [256]    [4, 256, 14, 14]         512       802,816
# 303_model.layer3.21.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 304_model.layer3.21.Conv2d_conv3               [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 305_model.layer3.21.BatchNorm2d_bn3                       [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 306_model.layer3.21.ReLU_relu                                  -   [4, 1024, 14, 14]           0             0
# 307_model.layer3.22.Conv2d_conv1               [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 308_model.layer3.22.BatchNorm2d_bn1                        [256]    [4, 256, 14, 14]         512       802,816
# 309_model.layer3.22.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 310_model.layer3.22.Conv2d_conv2                [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 311_model.layer3.22.BatchNorm2d_bn2                        [256]    [4, 256, 14, 14]         512       802,816
# 312_model.layer3.22.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 313_model.layer3.22.Conv2d_conv3               [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 314_model.layer3.22.BatchNorm2d_bn3                       [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 315_model.layer3.22.ReLU_relu                                  -   [4, 1024, 14, 14]           0             0
# 316_model.layer3.23.Conv2d_conv1               [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 317_model.layer3.23.BatchNorm2d_bn1                        [256]    [4, 256, 14, 14]         512       802,816
# 318_model.layer3.23.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 319_model.layer3.23.Conv2d_conv2                [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 320_model.layer3.23.BatchNorm2d_bn2                        [256]    [4, 256, 14, 14]         512       802,816
# 321_model.layer3.23.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 322_model.layer3.23.Conv2d_conv3               [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 323_model.layer3.23.BatchNorm2d_bn3                       [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 324_model.layer3.23.ReLU_relu                                  -   [4, 1024, 14, 14]           0             0
# 325_model.layer3.24.Conv2d_conv1               [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 326_model.layer3.24.BatchNorm2d_bn1                        [256]    [4, 256, 14, 14]         512       802,816
# 327_model.layer3.24.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 328_model.layer3.24.Conv2d_conv2                [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 329_model.layer3.24.BatchNorm2d_bn2                        [256]    [4, 256, 14, 14]         512       802,816
# 330_model.layer3.24.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 331_model.layer3.24.Conv2d_conv3               [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 332_model.layer3.24.BatchNorm2d_bn3                       [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 333_model.layer3.24.ReLU_relu                                  -   [4, 1024, 14, 14]           0             0
# 334_model.layer3.25.Conv2d_conv1               [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 335_model.layer3.25.BatchNorm2d_bn1                        [256]    [4, 256, 14, 14]         512       802,816
# 336_model.layer3.25.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 337_model.layer3.25.Conv2d_conv2                [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 338_model.layer3.25.BatchNorm2d_bn2                        [256]    [4, 256, 14, 14]         512       802,816
# 339_model.layer3.25.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 340_model.layer3.25.Conv2d_conv3               [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 341_model.layer3.25.BatchNorm2d_bn3                       [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 342_model.layer3.25.ReLU_relu                                  -   [4, 1024, 14, 14]           0             0
# 343_model.layer3.26.Conv2d_conv1               [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 344_model.layer3.26.BatchNorm2d_bn1                        [256]    [4, 256, 14, 14]         512       802,816
# 345_model.layer3.26.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 346_model.layer3.26.Conv2d_conv2                [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 347_model.layer3.26.BatchNorm2d_bn2                        [256]    [4, 256, 14, 14]         512       802,816
# 348_model.layer3.26.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 349_model.layer3.26.Conv2d_conv3               [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 350_model.layer3.26.BatchNorm2d_bn3                       [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 351_model.layer3.26.ReLU_relu                                  -   [4, 1024, 14, 14]           0             0
# 352_model.layer3.27.Conv2d_conv1               [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 353_model.layer3.27.BatchNorm2d_bn1                        [256]    [4, 256, 14, 14]         512       802,816
# 354_model.layer3.27.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 355_model.layer3.27.Conv2d_conv2                [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 356_model.layer3.27.BatchNorm2d_bn2                        [256]    [4, 256, 14, 14]         512       802,816
# 357_model.layer3.27.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 358_model.layer3.27.Conv2d_conv3               [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 359_model.layer3.27.BatchNorm2d_bn3                       [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 360_model.layer3.27.ReLU_relu                                  -   [4, 1024, 14, 14]           0             0
# 361_model.layer3.28.Conv2d_conv1               [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 362_model.layer3.28.BatchNorm2d_bn1                        [256]    [4, 256, 14, 14]         512       802,816
# 363_model.layer3.28.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 364_model.layer3.28.Conv2d_conv2                [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 365_model.layer3.28.BatchNorm2d_bn2                        [256]    [4, 256, 14, 14]         512       802,816
# 366_model.layer3.28.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 367_model.layer3.28.Conv2d_conv3               [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 368_model.layer3.28.BatchNorm2d_bn3                       [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 369_model.layer3.28.ReLU_relu                                  -   [4, 1024, 14, 14]           0             0
# 370_model.layer3.29.Conv2d_conv1               [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 371_model.layer3.29.BatchNorm2d_bn1                        [256]    [4, 256, 14, 14]         512       802,816
# 372_model.layer3.29.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 373_model.layer3.29.Conv2d_conv2                [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 374_model.layer3.29.BatchNorm2d_bn2                        [256]    [4, 256, 14, 14]         512       802,816
# 375_model.layer3.29.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 376_model.layer3.29.Conv2d_conv3               [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 377_model.layer3.29.BatchNorm2d_bn3                       [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 378_model.layer3.29.ReLU_relu                                  -   [4, 1024, 14, 14]           0             0
# 379_model.layer3.30.Conv2d_conv1               [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 380_model.layer3.30.BatchNorm2d_bn1                        [256]    [4, 256, 14, 14]         512       802,816
# 381_model.layer3.30.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 382_model.layer3.30.Conv2d_conv2                [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 383_model.layer3.30.BatchNorm2d_bn2                        [256]    [4, 256, 14, 14]         512       802,816
# 384_model.layer3.30.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 385_model.layer3.30.Conv2d_conv3               [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 386_model.layer3.30.BatchNorm2d_bn3                       [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 387_model.layer3.30.ReLU_relu                                  -   [4, 1024, 14, 14]           0             0
# 388_model.layer3.31.Conv2d_conv1               [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 389_model.layer3.31.BatchNorm2d_bn1                        [256]    [4, 256, 14, 14]         512       802,816
# 390_model.layer3.31.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 391_model.layer3.31.Conv2d_conv2                [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 392_model.layer3.31.BatchNorm2d_bn2                        [256]    [4, 256, 14, 14]         512       802,816
# 393_model.layer3.31.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 394_model.layer3.31.Conv2d_conv3               [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 395_model.layer3.31.BatchNorm2d_bn3                       [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 396_model.layer3.31.ReLU_relu                                  -   [4, 1024, 14, 14]           0             0
# 397_model.layer3.32.Conv2d_conv1               [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 398_model.layer3.32.BatchNorm2d_bn1                        [256]    [4, 256, 14, 14]         512       802,816
# 399_model.layer3.32.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 400_model.layer3.32.Conv2d_conv2                [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 401_model.layer3.32.BatchNorm2d_bn2                        [256]    [4, 256, 14, 14]         512       802,816
# 402_model.layer3.32.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 403_model.layer3.32.Conv2d_conv3               [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 404_model.layer3.32.BatchNorm2d_bn3                       [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 405_model.layer3.32.ReLU_relu                                  -   [4, 1024, 14, 14]           0             0
# 406_model.layer3.33.Conv2d_conv1               [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 407_model.layer3.33.BatchNorm2d_bn1                        [256]    [4, 256, 14, 14]         512       802,816
# 408_model.layer3.33.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 409_model.layer3.33.Conv2d_conv2                [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 410_model.layer3.33.BatchNorm2d_bn2                        [256]    [4, 256, 14, 14]         512       802,816
# 411_model.layer3.33.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 412_model.layer3.33.Conv2d_conv3               [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 413_model.layer3.33.BatchNorm2d_bn3                       [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 414_model.layer3.33.ReLU_relu                                  -   [4, 1024, 14, 14]           0             0
# 415_model.layer3.34.Conv2d_conv1               [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 416_model.layer3.34.BatchNorm2d_bn1                        [256]    [4, 256, 14, 14]         512       802,816
# 417_model.layer3.34.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 418_model.layer3.34.Conv2d_conv2                [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 419_model.layer3.34.BatchNorm2d_bn2                        [256]    [4, 256, 14, 14]         512       802,816
# 420_model.layer3.34.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 421_model.layer3.34.Conv2d_conv3               [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 422_model.layer3.34.BatchNorm2d_bn3                       [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 423_model.layer3.34.ReLU_relu                                  -   [4, 1024, 14, 14]           0             0
# 424_model.layer3.35.Conv2d_conv1               [1024, 256, 1, 1]    [4, 256, 14, 14]     262,144   205,520,896
# 425_model.layer3.35.BatchNorm2d_bn1                        [256]    [4, 256, 14, 14]         512       802,816
# 426_model.layer3.35.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 427_model.layer3.35.Conv2d_conv2                [256, 256, 3, 3]    [4, 256, 14, 14]     589,824   462,422,016
# 428_model.layer3.35.BatchNorm2d_bn2                        [256]    [4, 256, 14, 14]         512       802,816
# 429_model.layer3.35.ReLU_relu                                  -    [4, 256, 14, 14]           0             0
# 430_model.layer3.35.Conv2d_conv3               [256, 1024, 1, 1]   [4, 1024, 14, 14]     262,144   205,520,896
# 431_model.layer3.35.BatchNorm2d_bn3                       [1024]   [4, 1024, 14, 14]       2,048     3,211,264
# 432_model.layer3.35.ReLU_relu                                  -   [4, 1024, 14, 14]           0             0
# 433_model.layer4.0.Conv2d_conv1                [1024, 512, 1, 1]    [4, 512, 14, 14]     524,288   411,041,792
# 434_model.layer4.0.BatchNorm2d_bn1                         [512]    [4, 512, 14, 14]       1,024     1,605,632
# 435_model.layer4.0.ReLU_relu                                   -    [4, 512, 14, 14]           0             0
# 436_model.layer4.0.Conv2d_conv2                 [512, 512, 3, 3]      [4, 512, 7, 7]   2,359,296   462,422,016
# 437_model.layer4.0.BatchNorm2d_bn2                         [512]      [4, 512, 7, 7]       1,024       401,408
# 438_model.layer4.0.ReLU_relu                                   -      [4, 512, 7, 7]           0             0
# 439_model.layer4.0.Conv2d_conv3                [512, 2048, 1, 1]     [4, 2048, 7, 7]   1,048,576   205,520,896
# 440_model.layer4.0.BatchNorm2d_bn3                        [2048]     [4, 2048, 7, 7]       4,096     1,605,632
# 441_model.layer4.0.downsample.Conv2d_0        [1024, 2048, 1, 1]     [4, 2048, 7, 7]   2,097,152   411,041,792
# 442_model.layer4.0.downsample.BatchNorm2d_1               [2048]     [4, 2048, 7, 7]       4,096     1,605,632
# 443_model.layer4.0.ReLU_relu                                   -     [4, 2048, 7, 7]           0             0
# 444_model.layer4.1.Conv2d_conv1                [2048, 512, 1, 1]      [4, 512, 7, 7]   1,048,576   205,520,896
# 445_model.layer4.1.BatchNorm2d_bn1                         [512]      [4, 512, 7, 7]       1,024       401,408
# 446_model.layer4.1.ReLU_relu                                   -      [4, 512, 7, 7]           0             0
# 447_model.layer4.1.Conv2d_conv2                 [512, 512, 3, 3]      [4, 512, 7, 7]   2,359,296   462,422,016
# 448_model.layer4.1.BatchNorm2d_bn2                         [512]      [4, 512, 7, 7]       1,024       401,408
# 449_model.layer4.1.ReLU_relu                                   -      [4, 512, 7, 7]           0             0
# 450_model.layer4.1.Conv2d_conv3                [512, 2048, 1, 1]     [4, 2048, 7, 7]   1,048,576   205,520,896
# 451_model.layer4.1.BatchNorm2d_bn3                        [2048]     [4, 2048, 7, 7]       4,096     1,605,632
# 452_model.layer4.1.ReLU_relu                                   -     [4, 2048, 7, 7]           0             0
# 453_model.layer4.2.Conv2d_conv1                [2048, 512, 1, 1]      [4, 512, 7, 7]   1,048,576   205,520,896
# 454_model.layer4.2.BatchNorm2d_bn1                         [512]      [4, 512, 7, 7]       1,024       401,408
# 455_model.layer4.2.ReLU_relu                                   -      [4, 512, 7, 7]           0             0
# 456_model.layer4.2.Conv2d_conv2                 [512, 512, 3, 3]      [4, 512, 7, 7]   2,359,296   462,422,016
# 457_model.layer4.2.BatchNorm2d_bn2                         [512]      [4, 512, 7, 7]       1,024       401,408
# 458_model.layer4.2.ReLU_relu                                   -      [4, 512, 7, 7]           0             0
# 459_model.layer4.2.Conv2d_conv3                [512, 2048, 1, 1]     [4, 2048, 7, 7]   1,048,576   205,520,896
# 460_model.layer4.2.BatchNorm2d_bn3                        [2048]     [4, 2048, 7, 7]       4,096     1,605,632
# 461_model.layer4.2.ReLU_relu                                   -     [4, 2048, 7, 7]           0             0
# 462_model.AdaptiveAvgPool2d_avgpool                            -     [4, 2048, 1, 1]           0       409,600
# 463_model.Linear_fc                                    [2048, 1]              [4, 1]       2,049        16,380
# ==============================================================================================================
# Total params: 58,145,857
# Trainable params: 14,966,785
# Non-trainable params: 43,179,072
# Total FLOPs: 46,407,606,268 / 46.41 GFLOPs
# --------------------------------------------------------------------------------------------------------------
# Input size (MB): 2.30
# Forward/backward pass size (MB): 2025.14
# Params size (MB): 221.81
# Estimated Total Size (MB): 2249.25
# ==============================================================================================================

# %%
optimizer = torch.optim.Adam(model_2.parameters(), lr=0.001)
criterion = nn.BCELoss()

# %%
logs_new = fit_model(model_2, 20, optimizer)
# Out:
# ------------- Epoch 1 -------------
# train: accuracy 0.7593, loss 0.4803
# valid: accuracy 0.6479, loss 2.0866
# -----------------------------------
#
# ------------- Epoch 2 -------------
# train: accuracy 0.8818, loss 0.2698
# valid: accuracy 0.8402, loss 2.2468
# -----------------------------------
#
# ------------- Epoch 3 -------------
# train: accuracy 0.8990, loss 0.2272
# valid: accuracy 0.8376, loss 3.5968
# -----------------------------------
#
# ------------- Epoch 4 -------------
# train: accuracy 0.8998, loss 0.2077
# valid: accuracy 0.8108, loss 1.8489
# -----------------------------------
#
# ------------- Epoch 5 -------------
# train: accuracy 0.9114, loss 0.2018
# valid: accuracy 0.8242, loss 1.0892
# -----------------------------------
#
# ------------- Epoch 6 -------------
# train: accuracy 0.9295, loss 0.1543
# valid: accuracy 0.8815, loss 0.4252
# -----------------------------------
#
# ------------- Epoch 7 -------------
# train: accuracy 0.9346, loss 0.1588
# valid: accuracy 0.8736, loss 0.4037
# -----------------------------------
#
# ------------- Epoch 8 -------------
# train: accuracy 0.9381, loss 0.1387
# valid: accuracy 0.8768, loss 0.3194
# -----------------------------------
#
# ------------- Epoch 9 -------------
# train: accuracy 0.9428, loss 0.1286
# valid: accuracy 0.9086, loss 0.3249
# -----------------------------------
#
# ------------- Epoch 10 -------------
# train: accuracy 0.9511, loss 0.1247
# valid: accuracy 0.8679, loss 0.5292
# -----------------------------------
#
# ------------- Epoch 11 -------------
# train: accuracy 0.9414, loss 0.1314
# valid: accuracy 0.9015, loss 0.3157
# -----------------------------------
#
# ------------- Epoch 12 -------------
# train: accuracy 0.9452, loss 0.1255
# valid: accuracy 0.8899, loss 0.2999
# -----------------------------------
#
# ------------- Epoch 13 -------------
# train: accuracy 0.9665, loss 0.0881
# valid: accuracy 0.9212, loss 0.2481
# -----------------------------------
#
# ------------- Epoch 14 -------------
# train: accuracy 0.9642, loss 0.0842
# valid: accuracy 0.8875, loss 0.3127
# -----------------------------------
#
# ------------- Epoch 15 -------------
# train: accuracy 0.9660, loss 0.0789
# valid: accuracy 0.9058, loss 0.3129
# -----------------------------------
#
# ------------- Epoch 16 -------------
# train: accuracy 0.9624, loss 0.1041
# valid: accuracy 0.9005, loss 0.3037
# -----------------------------------
#
# ------------- Epoch 17 -------------
# train: accuracy 0.9645, loss 0.0868
# valid: accuracy 0.9126, loss 0.3551
# -----------------------------------
#
# ------------- Epoch 18 -------------
# train: accuracy 0.9701, loss 0.0825
# valid: accuracy 0.9090, loss 0.2742
# -----------------------------------
#
# ------------- Epoch 19 -------------
# train: accuracy 0.9765, loss 0.0589
# valid: accuracy 0.9160, loss 0.2743
# -----------------------------------
#
# ------------- Epoch 20 -------------
# train: accuracy 0.9790, loss 0.0538
# valid: accuracy 0.9073, loss 0.2886
# -----------------------------------

# %%
results = {
    'fine_tune' : logs,
    'unfreeze' : logs_new
}

# %%
def prepare_data(data, metric):
    rows = []
    for model, values in data.items():
        train_key = f'train_{metric}es' if metric == 'loss' else f'train_{metric}s'
        valid_key = f'valid_{metric}es' if metric == 'loss' else f'valid_{metric}s'
        for i, (train_val, valid_val) in enumerate(zip(values[train_key], values[valid_key])):
            rows.append({'Epoch': i+1, 'Value': train_val, 'Metric': f'Train {metric.capitalize()}', 'Model': model})
            rows.append({'Epoch': i+1, 'Value': valid_val, 'Metric': f'Valid {metric.capitalize()}', 'Model': model})
    return pd.DataFrame(rows)

acc_data = prepare_data(results, 'acc')
loss_data = prepare_data(results, 'loss')

plt.figure(figsize=(14, 7))
sns.lineplot(x='Epoch', y='Value', hue='Model', style='Metric', data=acc_data, markers=True, dashes=False)
plt.title('Accuracy')

plt.figure(figsize=(14, 7))
sns.lineplot(x='Epoch', y='Value', hue='Model', style='Metric', data=loss_data, markers=True, dashes=False)
plt.title('Loss');

# %%
from sklearn.metrics import roc_auc_score, roc_curve
import matplotlib.pyplot as plt

batch_precisions = []
batch_accs = []
batch_recalls = []
all_labels = []
all_preds = []

for samples, labels in valid_loader:
    with torch.no_grad():
        y_pred = model_2(samples.to(DEVICE))
    labels = labels.view(-1, 1).float().to(DEVICE)
    batch_accs.append((y_pred.round() == labels).cpu().numpy().mean())
    
    true_positives = ((y_pred.round() == 1) & (labels == 1)).sum().item()
    false_negatives = ((y_pred.round() == 0) & (labels == 1)).sum().item()
    false_positives = ((y_pred.round() == 1) & (labels == 0)).sum().item()
    
    recall = true_positives / (true_positives + false_negatives)
    precision = true_positives / (true_positives + false_positives)
    
    batch_precisions.append(precision)
    batch_recalls.append(recall)
    
    all_labels.append(labels.cpu().numpy())
    all_preds.append(y_pred.cpu().numpy())

all_labels = np.concatenate(all_labels)
all_preds = np.concatenate(all_preds)

roc_auc = roc_auc_score(all_labels, all_preds)
fpr, tpr, _ = roc_curve(all_labels, all_preds)

print(f'acc: {np.mean(batch_accs)}')
print(f'recall: {np.mean(batch_recalls)}')
print(f'precisions: {np.mean(batch_precisions)}')
print(f'ROC AUC: {roc_auc}')
# Out:
# acc: 0.9048511402027026
# recall: 0.8949166164356037
# precisions: 0.8926572494669509
# ROC AUC: 0.9734999999999999

# %%
plt.figure(figsize=(16, 8))
sns.lineplot(x=fpr, y=tpr, lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
sns.lineplot(x=[0, 1], y=[0, 1], color='red', lw=2, linestyle='--')

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=14)
plt.ylabel('True Positive Rate', fontsize=14)
plt.title('(ROC) Curve', fontsize=16)
plt.legend(loc="lower right", fontsize=12)
plt.grid(True)

# %%
from sklearn.metrics import fbeta_score

beta = 3

fbeta_scores = []
for threshold in thresholds:
    # Бинаризуем предсказания на основе текущего порога
    y_pred_binary = (all_preds >= threshold).astype(int)
    fbeta = fbeta_score(all_labels, y_pred_binary, beta=beta)
    fbeta_scores.append(fbeta)

# Находим индекс порога с максимальной F-бета мерой
best_threshold_index = np.argmax(fbeta_scores)
optimal_threshold = thresholds[best_threshold_index]

print(f'Optimal threshold for maximum F-beta score (beta={beta}): {optimal_threshold}')
print(f'Maximum F-beta score: {fbeta_scores[best_threshold_index]}')
# Out:
# Optimal threshold for maximum F-beta score (beta=3): 0.02257668599486351
# Maximum F-beta score: 0.9595300261096605

# %%
from sklearn.metrics import roc_auc_score, roc_curve, precision_score, recall_score, accuracy_score

batch_precisions = []
batch_accs = []
batch_recalls = []
all_labels = []
all_preds = []

for samples, labels in valid_loader:
    with torch.no_grad():
        y_pred = model_2(samples.to(DEVICE))
    labels = labels.view(-1, 1).float().to(DEVICE)
    
    all_labels.append(labels.cpu().numpy())
    all_preds.append(y_pred.cpu().numpy())

all_labels = np.concatenate(all_labels)
all_preds = np.concatenate(all_preds)

preds_binary = (all_preds >= optimal_threshold).astype(int)

precision = precision_score(all_labels, preds_binary)
recall = recall_score(all_labels, preds_binary)
accuracy = accuracy_score(all_labels, preds_binary)
roc_auc = roc_auc_score(all_labels, all_preds)

print(f'Accuracy at optimal threshold: {accuracy}')
print(f'Recall at optimal threshold: {recall}')
print(f'Precision at optimal threshold: {precision}')
print(f'ROC AUC: {roc_auc}')
# Out:
# Accuracy at optimal threshold: 0.8848484848484849
# Recall at optimal threshold: 0.98
# Precision at optimal threshold: 0.8076923076923077
# ROC AUC: 0.9735

# %%
torch.save(model_2.state_dict(), 'model_kudinov.pt')
